# %%
import os
import gc
import sys
import glob
import time
import math
import numpy as np
import uproot
import pandas
from functools import partial
from concurrent.futures import ThreadPoolExecutor

import tensorflow as tf
import keras
import keras.backend as K
from keras import regularizers
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Conv2D, Dropout, AlphaDropout, Activation, BatchNormalization, Flatten, \
                                    Concatenate, PReLU, TimeDistributed, LSTM, Masking, MaxPooling2D
from keras.callbacks import Callback, ModelCheckpoint, CSVLogger

sys.path.insert(0, "../../python")
from common import *
#from t_notify import Notify
from DataLoader import DataLoader, read_hdf_lock
# Out:
# Using TensorFlow backend.

# %%
class MaskedDense(Dense):
    def __init__(self, units, **kwargs):
        super(MaskedDense, self).__init__(units, **kwargs)
        
    def call(self, inputs, mask=None):
        base_out = super(MaskedDense, self).call(inputs)
        if mask is None:
            return base_out
        zeros = tf.zeros_like(base_out)
        return tf.where(mask, base_out, zeros)

# %%
class NetSetup:
    def __init__(self, activation, activation_shared_axes, dropout_rate, first_layer_size, last_layer_size, decay_factor,
                 kernel_regularizer, time_distributed):
        self.activation = activation
        self.activation_shared_axes = activation_shared_axes
        if activation == 'relu' or activation == 'PReLU' or activation == 'tanh':
            self.DropoutType = Dropout
            self.kernel_init = 'he_uniform'
            self.apply_batch_norm = True
        elif activation == 'selu':
            self.DropoutType = AlphaDropout
            self.kernel_init = 'lecun_normal'
            self.apply_batch_norm = False
        else:
            raise RuntimeError('Activation "{}" not supported.'.format(activation))
        self.dropout_rate = dropout_rate
        self.first_layer_size = first_layer_size
        self.last_layer_size = last_layer_size
        self.decay_factor = decay_factor
        self.kernel_regularizer = kernel_regularizer
        self.time_distributed = time_distributed
    
    def RecalcLayerSizes(self, n_input_features, width_factor, compression_factor, consider_dropout = True):
        drop_factor = 1 + self.dropout_rate if consider_dropout else 1
        self.first_layer_size = int(math.ceil(n_input_features * drop_factor * width_factor))
        self.last_layer_size = int(math.ceil(n_input_features * drop_factor * compression_factor))

# %%
def add_block_ending(net_setup, name_format, layer):
    if net_setup.apply_batch_norm:
        norm_layer = BatchNormalization(name=name_format.format('norm'))
        if net_setup.time_distributed:
            norm_layer = TimeDistributed(norm_layer, name=name_format.format('norm'))
        norm_layer = norm_layer(layer)
    else:
        norm_layer = layer
    if net_setup.activation == 'PReLU':
        activation_layer = PReLU(shared_axes=net_setup.activation_shared_axes,
                                 name=name_format.format('activation'))(norm_layer)
    else:
        activation_layer = Activation(net_setup.activation, name=name_format.format('activation'))(norm_layer)
    if net_setup.dropout_rate > 0:
        return net_setup.DropoutType(net_setup.dropout_rate, name=name_format.format('dropout'))(activation_layer)
    return activation_layer

# %%
def dense_block(prev_layer, kernel_size, net_setup, block_name, n):
    DenseType = MaskedDense if net_setup.time_distributed else Dense
    dense = DenseType(kernel_size, name="{}_dense_{}".format(block_name, n),
                      kernel_initializer=net_setup.kernel_init,
                      kernel_regularizer=net_setup.kernel_regularizer)
    if net_setup.time_distributed:
        dense = TimeDistributed(dense, name="{}_dense_{}".format(block_name, n))
    dense = dense(prev_layer)
    return add_block_ending(net_setup, '{}_{{}}_{}'.format(block_name, n), dense)

# %%
def reduce_n_features_1d(input_layer, net_setup, block_name):
    prev_layer = input_layer
    current_size = net_setup.first_layer_size
    n = 1
    while True:
        prev_layer = dense_block(prev_layer, current_size, net_setup, block_name, n)
        if current_size == net_setup.last_layer_size: break
        current_size = max(net_setup.last_layer_size, int(current_size / net_setup.decay_factor))
        n += 1
    return prev_layer

# %%
def dense_block_sequence(input_layer, net_setup, n_layers, block_name):
    prev_layer = input_layer
    current_size = net_setup.first_layer_size
    for n in range(n_layers):
        prev_layer = dense_block(prev_layer, current_size, net_setup, block_name, n+1)
    return prev_layer

# %%
def conv_block(prev_layer, filters, kernel_size, net_setup, padding, block_name, n):
    conv = Conv2D(filters, kernel_size, name="{}_conv_{}".format(block_name, n), padding=padding,
                  kernel_initializer=net_setup.kernel_init)(prev_layer)
    return add_block_ending(net_setup, '{}_{{}}_{}'.format(block_name, n), conv)

# %%
def reduce_n_features_2d(input_layer, net_setup, block_name):
    conv_kernel=(1, 1)
    prev_layer = input_layer
    current_size = net_setup.first_layer_size
    n = 1
    while True:
        prev_layer = conv_block(prev_layer, current_size, conv_kernel, net_setup, 'valid', block_name, n)
        if current_size == net_setup.last_layer_size: break
        current_size = max(net_setup.last_layer_size, int(current_size / net_setup.decay_factor))
        n += 1
    return prev_layer

# %%
def create_model(net_config):
    tau_net_setup = NetSetup('PReLU', None, 0.2, 128, 128, 1.4, None, False)
    comp_net_setup = NetSetup('PReLU', [1, 2], 0.2, 1024, 64, 1.6, None, False)
    #dense_net_setup = NetSetup('relu', 0, 512, 32, 1.4, keras.regularizers.l1(1e-5))
    dense_net_setup = NetSetup('PReLU', None, 0.2, 320, 64, 1.6, None, False)
            
    input_layers = []
    high_level_features = []

    if len(net_config.tau_branches) > 0:
        input_layer_tau = Input(name="input_tau", shape=(len(net_config.tau_branches),))
        input_layers.append(input_layer_tau)
        tau_net_setup.RecalcLayerSizes(len(net_config.tau_branches), 1.5, 1)
        processed_tau = reduce_n_features_1d(input_layer_tau, tau_net_setup, 'tau')
        #processed_tau = dense_block_sequence(input_layer_tau, tau_net_setup, 4, 'tau')
        high_level_features.append(processed_tau)
    
    for loc in net_config.cell_locations:
        reduced_inputs = []
        for comp_id in range(len(net_config.comp_names)):
            comp_name = net_config.comp_names[comp_id]
            n_comp_features = len(input_cell_external_branches) + len(net_config.comp_branches[comp_id])
            input_layer_comp = Input(name="input_{}_{}".format(loc, comp_name),
                                     shape=(n_cells_eta[loc], n_cells_phi[loc], n_comp_features))
            input_layers.append(input_layer_comp)
            comp_net_setup.RecalcLayerSizes(n_comp_features, 1.5, 1)
            #input_layer_comp_masked = Masking(name="input_{}_{}_masking".format(loc, comp_name))(input_layer_comp)
            #reduced_comp = dense_block_sequence(input_layer_comp_masked, comp_net_setup, 4, "{}_{}".format(loc, comp_name))
            #reduced_comp = reduce_n_features_1d(input_layer_comp_masked, comp_net_setup, "{}_{}".format(loc, comp_name))
            reduced_comp = reduce_n_features_2d(input_layer_comp, comp_net_setup, "{}_{}".format(loc, comp_name))
            reduced_inputs.append(reduced_comp)
        
        cell_output_size = 64
        if len(net_config.comp_names) > 1:
            conv_all_start = Concatenate(name="{}_cell_concat".format(loc), axis=3)(reduced_inputs)
            comp_net_setup.first_layer_size = conv_all_start.shape.as_list()[3]
            comp_net_setup.last_layer_size = 64
            prev_layer = reduce_n_features_2d(conv_all_start, comp_net_setup, "{}_all".format(loc))
        else:
            prev_layer = reduced_inputs[0]

        if n_cells_eta[loc] == 11:
            sequence = [ ['c', 64, 3, 2], ['p', 3], ['c', 96, 2, 2], ['p', 2], ['c', 128, 2, 1, 'valid'] ]
        elif n_cells_eta[loc] == 21:
            sequence = [ ['c', 64, 3, 2], ['p', 3], ['c', 96, 3, 2], ['p', 3], ['c', 128, 3, 1, 'valid'] ]
        else:
            raise RuntimeError("unsupported number of cells")
        
        conv_n = 1
        pool_n = 1

        for item in sequence:
            if item[0] == 'c':
                features = item[1]
                win_size = item[2]
                padding = item[4] if len(item) > 4 else 'same'
                for k in range(item[3]):
                    prev_layer = conv_block(prev_layer, features, win_size, comp_net_setup, padding,
                                            "{}_all_{}x{}".format(loc, win_size, win_size), conv_n)
                    conv_n += 1
            elif item[0] == 'p':
                win_size = item[1]
                prev_layer = MaxPooling2D(win_size, name="{}_all_{}x{}_pool_{}".format(loc, win_size, win_size, pool_n),
                                          padding='same')(prev_layer)
                pool_n += 1
            else:
                raise RuntimeError("unsupported item type")
           
        cells_flatten = Flatten(name="{}_cells_flatten".format(loc))(prev_layer)
        high_level_features.append(cells_flatten)
        
    if len(high_level_features) > 1:
        features_concat = Concatenate(name="features_concat", axis=1)(high_level_features)
    else:
        features_concat = high_level_features[0]
    if net_config.final:
        #print(features_concat.get_shape())
        #dense_net_setup.RecalcLayerSizes(128, 1, 0.5, False)
        final_dense = reduce_n_features_1d(features_concat, dense_net_setup, 'final')
        #final_dense = dense_block_sequence(features_concat, dense_net_setup, 4, 'final')
        output_layer = Dense(n_outputs, name="final_dense_last",
                             kernel_initializer=dense_net_setup.kernel_init)(final_dense)

    else:
        final_dense = dense_block(features_concat, 1024, dense_net_setup,
                                  'tmp_{}'.format(net_config.name), 1)
        output_layer = Dense(n_outputs, name="tmp_{}_dense_last".format(net_config.name),
                             kernel_initializer=dense_net_setup.kernel_init)(final_dense)
    softmax_output = Activation("softmax", name="main_output")(output_layer)
    
    model = Model(input_layers, softmax_output, name="DeepTau2017v2")
    return model

# %%
model_name = "DeepTau2017v2p7"
model = create_model(netConf_full)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\konst\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\konst\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_inner_egamma (InputLayer) (None, 11, 11, 86)   0
# __________________________________________________________________________________________________
# input_inner_muon (InputLayer)   (None, 11, 11, 64)   0
# __________________________________________________________________________________________________
# input_inner_hadrons (InputLayer (None, 11, 11, 38)   0
# __________________________________________________________________________________________________
# input_outer_egamma (InputLayer) (None, 21, 21, 86)   0
# __________________________________________________________________________________________________
# input_outer_muon (InputLayer)   (None, 21, 21, 64)   0
# __________________________________________________________________________________________________
# input_outer_hadrons (InputLayer (None, 21, 21, 38)   0
# __________________________________________________________________________________________________
# inner_egamma_conv_1 (Conv2D)    (None, 11, 11, 155)  13485       input_inner_egamma[0][0]
# __________________________________________________________________________________________________
# inner_muon_conv_1 (Conv2D)      (None, 11, 11, 116)  7540        input_inner_muon[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_conv_1 (Conv2D)   (None, 11, 11, 69)   2691        input_inner_hadrons[0][0]
# __________________________________________________________________________________________________
# outer_egamma_conv_1 (Conv2D)    (None, 21, 21, 155)  13485       input_outer_egamma[0][0]
# __________________________________________________________________________________________________
# outer_muon_conv_1 (Conv2D)      (None, 21, 21, 116)  7540        input_outer_muon[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_conv_1 (Conv2D)   (None, 21, 21, 69)   2691        input_outer_hadrons[0][0]
# __________________________________________________________________________________________________
# inner_egamma_norm_1 (BatchNorma (None, 11, 11, 155)  620         inner_egamma_conv_1[0][0]
# __________________________________________________________________________________________________
# inner_muon_norm_1 (BatchNormali (None, 11, 11, 116)  464         inner_muon_conv_1[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_norm_1 (BatchNorm (None, 11, 11, 69)   276         inner_hadrons_conv_1[0][0]
# __________________________________________________________________________________________________
# outer_egamma_norm_1 (BatchNorma (None, 21, 21, 155)  620         outer_egamma_conv_1[0][0]
# __________________________________________________________________________________________________
# outer_muon_norm_1 (BatchNormali (None, 21, 21, 116)  464         outer_muon_conv_1[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_norm_1 (BatchNorm (None, 21, 21, 69)   276         outer_hadrons_conv_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_activation_1 (PReL (None, 11, 11, 155)  155         inner_egamma_norm_1[0][0]
# __________________________________________________________________________________________________
# inner_muon_activation_1 (PReLU) (None, 11, 11, 116)  116         inner_muon_norm_1[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_activation_1 (PRe (None, 11, 11, 69)   69          inner_hadrons_norm_1[0][0]
# __________________________________________________________________________________________________
# outer_egamma_activation_1 (PReL (None, 21, 21, 155)  155         outer_egamma_norm_1[0][0]
# __________________________________________________________________________________________________
# outer_muon_activation_1 (PReLU) (None, 21, 21, 116)  116         outer_muon_norm_1[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_activation_1 (PRe (None, 21, 21, 69)   69          outer_hadrons_norm_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_dropout_1 (Dropout (None, 11, 11, 155)  0           inner_egamma_activation_1[0][0]
# __________________________________________________________________________________________________
# inner_muon_dropout_1 (Dropout)  (None, 11, 11, 116)  0           inner_muon_activation_1[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_dropout_1 (Dropou (None, 11, 11, 69)   0           inner_hadrons_activation_1[0][0]
# __________________________________________________________________________________________________
# outer_egamma_dropout_1 (Dropout (None, 21, 21, 155)  0           outer_egamma_activation_1[0][0]
# __________________________________________________________________________________________________
# outer_muon_dropout_1 (Dropout)  (None, 21, 21, 116)  0           outer_muon_activation_1[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_dropout_1 (Dropou (None, 21, 21, 69)   0           outer_hadrons_activation_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_conv_2 (Conv2D)    (None, 11, 11, 104)  16224       inner_egamma_dropout_1[0][0]
# __________________________________________________________________________________________________
# inner_muon_conv_2 (Conv2D)      (None, 11, 11, 77)   9009        inner_muon_dropout_1[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_conv_2 (Conv2D)   (None, 11, 11, 46)   3220        inner_hadrons_dropout_1[0][0]
# __________________________________________________________________________________________________
# outer_egamma_conv_2 (Conv2D)    (None, 21, 21, 104)  16224       outer_egamma_dropout_1[0][0]
# __________________________________________________________________________________________________
# outer_muon_conv_2 (Conv2D)      (None, 21, 21, 77)   9009        outer_muon_dropout_1[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_conv_2 (Conv2D)   (None, 21, 21, 46)   3220        outer_hadrons_dropout_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_norm_2 (BatchNorma (None, 11, 11, 104)  416         inner_egamma_conv_2[0][0]
# __________________________________________________________________________________________________
# inner_muon_norm_2 (BatchNormali (None, 11, 11, 77)   308         inner_muon_conv_2[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_norm_2 (BatchNorm (None, 11, 11, 46)   184         inner_hadrons_conv_2[0][0]
# __________________________________________________________________________________________________
# outer_egamma_norm_2 (BatchNorma (None, 21, 21, 104)  416         outer_egamma_conv_2[0][0]
# __________________________________________________________________________________________________
# outer_muon_norm_2 (BatchNormali (None, 21, 21, 77)   308         outer_muon_conv_2[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_norm_2 (BatchNorm (None, 21, 21, 46)   184         outer_hadrons_conv_2[0][0]
# __________________________________________________________________________________________________
# inner_egamma_activation_2 (PReL (None, 11, 11, 104)  104         inner_egamma_norm_2[0][0]
# __________________________________________________________________________________________________
# inner_muon_activation_2 (PReLU) (None, 11, 11, 77)   77          inner_muon_norm_2[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_activation_2 (PRe (None, 11, 11, 46)   46          inner_hadrons_norm_2[0][0]
# __________________________________________________________________________________________________
# outer_egamma_activation_2 (PReL (None, 21, 21, 104)  104         outer_egamma_norm_2[0][0]
# __________________________________________________________________________________________________
# outer_muon_activation_2 (PReLU) (None, 21, 21, 77)   77          outer_muon_norm_2[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_activation_2 (PRe (None, 21, 21, 46)   46          outer_hadrons_norm_2[0][0]
# __________________________________________________________________________________________________
# inner_egamma_dropout_2 (Dropout (None, 11, 11, 104)  0           inner_egamma_activation_2[0][0]
# __________________________________________________________________________________________________
# inner_muon_dropout_2 (Dropout)  (None, 11, 11, 77)   0           inner_muon_activation_2[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_dropout_2 (Dropou (None, 11, 11, 46)   0           inner_hadrons_activation_2[0][0]
# __________________________________________________________________________________________________
# outer_egamma_dropout_2 (Dropout (None, 21, 21, 104)  0           outer_egamma_activation_2[0][0]
# __________________________________________________________________________________________________
# outer_muon_dropout_2 (Dropout)  (None, 21, 21, 77)   0           outer_muon_activation_2[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_dropout_2 (Dropou (None, 21, 21, 46)   0           outer_hadrons_activation_2[0][0]
# __________________________________________________________________________________________________
# inner_cell_concat (Concatenate) (None, 11, 11, 227)  0           inner_egamma_dropout_2[0][0]
#                                                                  inner_muon_dropout_2[0][0]
#                                                                  inner_hadrons_dropout_2[0][0]
# __________________________________________________________________________________________________
# outer_cell_concat (Concatenate) (None, 21, 21, 227)  0           outer_egamma_dropout_2[0][0]
#                                                                  outer_muon_dropout_2[0][0]
#                                                                  outer_hadrons_dropout_2[0][0]
# __________________________________________________________________________________________________
# inner_all_conv_1 (Conv2D)       (None, 11, 11, 227)  51756       inner_cell_concat[0][0]
# __________________________________________________________________________________________________
# outer_all_conv_1 (Conv2D)       (None, 21, 21, 227)  51756       outer_cell_concat[0][0]
# __________________________________________________________________________________________________
# inner_all_norm_1 (BatchNormaliz (None, 11, 11, 227)  908         inner_all_conv_1[0][0]
# __________________________________________________________________________________________________
# outer_all_norm_1 (BatchNormaliz (None, 21, 21, 227)  908         outer_all_conv_1[0][0]
# __________________________________________________________________________________________________
# inner_all_activation_1 (PReLU)  (None, 11, 11, 227)  227         inner_all_norm_1[0][0]
# __________________________________________________________________________________________________
# outer_all_activation_1 (PReLU)  (None, 21, 21, 227)  227         outer_all_norm_1[0][0]
# __________________________________________________________________________________________________
# inner_all_dropout_1 (Dropout)   (None, 11, 11, 227)  0           inner_all_activation_1[0][0]
# __________________________________________________________________________________________________
# outer_all_dropout_1 (Dropout)   (None, 21, 21, 227)  0           outer_all_activation_1[0][0]
# __________________________________________________________________________________________________
# inner_all_conv_2 (Conv2D)       (None, 11, 11, 141)  32148       inner_all_dropout_1[0][0]
# __________________________________________________________________________________________________
# outer_all_conv_2 (Conv2D)       (None, 21, 21, 141)  32148       outer_all_dropout_1[0][0]
# __________________________________________________________________________________________________
# inner_all_norm_2 (BatchNormaliz (None, 11, 11, 141)  564         inner_all_conv_2[0][0]
# __________________________________________________________________________________________________
# outer_all_norm_2 (BatchNormaliz (None, 21, 21, 141)  564         outer_all_conv_2[0][0]
# __________________________________________________________________________________________________
# inner_all_activation_2 (PReLU)  (None, 11, 11, 141)  141         inner_all_norm_2[0][0]
# __________________________________________________________________________________________________
# outer_all_activation_2 (PReLU)  (None, 21, 21, 141)  141         outer_all_norm_2[0][0]
# __________________________________________________________________________________________________
# inner_all_dropout_2 (Dropout)   (None, 11, 11, 141)  0           inner_all_activation_2[0][0]
# __________________________________________________________________________________________________
# outer_all_dropout_2 (Dropout)   (None, 21, 21, 141)  0           outer_all_activation_2[0][0]
# __________________________________________________________________________________________________
# inner_all_conv_3 (Conv2D)       (None, 11, 11, 88)   12496       inner_all_dropout_2[0][0]
# __________________________________________________________________________________________________
# outer_all_conv_3 (Conv2D)       (None, 21, 21, 88)   12496       outer_all_dropout_2[0][0]
# __________________________________________________________________________________________________
# inner_all_norm_3 (BatchNormaliz (None, 11, 11, 88)   352         inner_all_conv_3[0][0]
# __________________________________________________________________________________________________
# outer_all_norm_3 (BatchNormaliz (None, 21, 21, 88)   352         outer_all_conv_3[0][0]
# __________________________________________________________________________________________________
# inner_all_activation_3 (PReLU)  (None, 11, 11, 88)   88          inner_all_norm_3[0][0]
# __________________________________________________________________________________________________
# outer_all_activation_3 (PReLU)  (None, 21, 21, 88)   88          outer_all_norm_3[0][0]
# __________________________________________________________________________________________________
# inner_all_dropout_3 (Dropout)   (None, 11, 11, 88)   0           inner_all_activation_3[0][0]
# __________________________________________________________________________________________________
# outer_all_dropout_3 (Dropout)   (None, 21, 21, 88)   0           outer_all_activation_3[0][0]
# __________________________________________________________________________________________________
# inner_all_conv_4 (Conv2D)       (None, 11, 11, 64)   5696        inner_all_dropout_3[0][0]
# __________________________________________________________________________________________________
# outer_all_conv_4 (Conv2D)       (None, 21, 21, 64)   5696        outer_all_dropout_3[0][0]
# __________________________________________________________________________________________________
# inner_all_norm_4 (BatchNormaliz (None, 11, 11, 64)   256         inner_all_conv_4[0][0]
# __________________________________________________________________________________________________
# outer_all_norm_4 (BatchNormaliz (None, 21, 21, 64)   256         outer_all_conv_4[0][0]
# __________________________________________________________________________________________________
# inner_all_activation_4 (PReLU)  (None, 11, 11, 64)   64          inner_all_norm_4[0][0]
# __________________________________________________________________________________________________
# outer_all_activation_4 (PReLU)  (None, 21, 21, 64)   64          outer_all_norm_4[0][0]
# __________________________________________________________________________________________________
# inner_all_dropout_4 (Dropout)   (None, 11, 11, 64)   0           inner_all_activation_4[0][0]
# __________________________________________________________________________________________________
# outer_all_dropout_4 (Dropout)   (None, 21, 21, 64)   0           outer_all_activation_4[0][0]
# __________________________________________________________________________________________________
# inner_all_3x3_conv_1 (Conv2D)   (None, 11, 11, 64)   36928       inner_all_dropout_4[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_conv_1 (Conv2D)   (None, 21, 21, 64)   36928       outer_all_dropout_4[0][0]
# __________________________________________________________________________________________________
# inner_all_3x3_norm_1 (BatchNorm (None, 11, 11, 64)   256         inner_all_3x3_conv_1[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_norm_1 (BatchNorm (None, 21, 21, 64)   256         outer_all_3x3_conv_1[0][0]
# __________________________________________________________________________________________________
# inner_all_3x3_activation_1 (PRe (None, 11, 11, 64)   64          inner_all_3x3_norm_1[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_activation_1 (PRe (None, 21, 21, 64)   64          outer_all_3x3_norm_1[0][0]
# __________________________________________________________________________________________________
# inner_all_3x3_dropout_1 (Dropou (None, 11, 11, 64)   0           inner_all_3x3_activation_1[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_dropout_1 (Dropou (None, 21, 21, 64)   0           outer_all_3x3_activation_1[0][0]
# __________________________________________________________________________________________________
# inner_all_3x3_conv_2 (Conv2D)   (None, 11, 11, 64)   36928       inner_all_3x3_dropout_1[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_conv_2 (Conv2D)   (None, 21, 21, 64)   36928       outer_all_3x3_dropout_1[0][0]
# __________________________________________________________________________________________________
# inner_all_3x3_norm_2 (BatchNorm (None, 11, 11, 64)   256         inner_all_3x3_conv_2[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_norm_2 (BatchNorm (None, 21, 21, 64)   256         outer_all_3x3_conv_2[0][0]
# __________________________________________________________________________________________________
# inner_all_3x3_activation_2 (PRe (None, 11, 11, 64)   64          inner_all_3x3_norm_2[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_activation_2 (PRe (None, 21, 21, 64)   64          outer_all_3x3_norm_2[0][0]
# __________________________________________________________________________________________________
# inner_all_3x3_dropout_2 (Dropou (None, 11, 11, 64)   0           inner_all_3x3_activation_2[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_dropout_2 (Dropou (None, 21, 21, 64)   0           outer_all_3x3_activation_2[0][0]
# __________________________________________________________________________________________________
# inner_all_3x3_pool_1 (MaxPoolin (None, 4, 4, 64)     0           inner_all_3x3_dropout_2[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_pool_1 (MaxPoolin (None, 7, 7, 64)     0           outer_all_3x3_dropout_2[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_conv_3 (Conv2D)   (None, 4, 4, 96)     24672       inner_all_3x3_pool_1[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_conv_3 (Conv2D)   (None, 7, 7, 96)     55392       outer_all_3x3_pool_1[0][0]
# __________________________________________________________________________________________________
# input_tau (InputLayer)          (None, 47)           0
# __________________________________________________________________________________________________
# inner_all_2x2_norm_3 (BatchNorm (None, 4, 4, 96)     384         inner_all_2x2_conv_3[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_norm_3 (BatchNorm (None, 7, 7, 96)     384         outer_all_3x3_conv_3[0][0]
# __________________________________________________________________________________________________
# tau_dense_1 (Dense)             (None, 85)           4080        input_tau[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_activation_3 (PRe (None, 4, 4, 96)     96          inner_all_2x2_norm_3[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_activation_3 (PRe (None, 7, 7, 96)     96          outer_all_3x3_norm_3[0][0]
# __________________________________________________________________________________________________
# tau_norm_1 (BatchNormalization) (None, 85)           340         tau_dense_1[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_dropout_3 (Dropou (None, 4, 4, 96)     0           inner_all_2x2_activation_3[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_dropout_3 (Dropou (None, 7, 7, 96)     0           outer_all_3x3_activation_3[0][0]
# __________________________________________________________________________________________________
# tau_activation_1 (PReLU)        (None, 85)           85          tau_norm_1[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_conv_4 (Conv2D)   (None, 4, 4, 96)     36960       inner_all_2x2_dropout_3[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_conv_4 (Conv2D)   (None, 7, 7, 96)     83040       outer_all_3x3_dropout_3[0][0]
# __________________________________________________________________________________________________
# tau_dropout_1 (Dropout)         (None, 85)           0           tau_activation_1[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_norm_4 (BatchNorm (None, 4, 4, 96)     384         inner_all_2x2_conv_4[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_norm_4 (BatchNorm (None, 7, 7, 96)     384         outer_all_3x3_conv_4[0][0]
# __________________________________________________________________________________________________
# tau_dense_2 (Dense)             (None, 60)           5160        tau_dropout_1[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_activation_4 (PRe (None, 4, 4, 96)     96          inner_all_2x2_norm_4[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_activation_4 (PRe (None, 7, 7, 96)     96          outer_all_3x3_norm_4[0][0]
# __________________________________________________________________________________________________
# tau_norm_2 (BatchNormalization) (None, 60)           240         tau_dense_2[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_dropout_4 (Dropou (None, 4, 4, 96)     0           inner_all_2x2_activation_4[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_dropout_4 (Dropou (None, 7, 7, 96)     0           outer_all_3x3_activation_4[0][0]
# __________________________________________________________________________________________________
# tau_activation_2 (PReLU)        (None, 60)           60          tau_norm_2[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_pool_2 (MaxPoolin (None, 2, 2, 96)     0           inner_all_2x2_dropout_4[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_pool_2 (MaxPoolin (None, 3, 3, 96)     0           outer_all_3x3_dropout_4[0][0]
# __________________________________________________________________________________________________
# tau_dropout_2 (Dropout)         (None, 60)           0           tau_activation_2[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_conv_5 (Conv2D)   (None, 1, 1, 128)    49280       inner_all_2x2_pool_2[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_conv_5 (Conv2D)   (None, 1, 1, 128)    110720      outer_all_3x3_pool_2[0][0]
# __________________________________________________________________________________________________
# tau_dense_3 (Dense)             (None, 57)           3477        tau_dropout_2[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_norm_5 (BatchNorm (None, 1, 1, 128)    512         inner_all_2x2_conv_5[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_norm_5 (BatchNorm (None, 1, 1, 128)    512         outer_all_3x3_conv_5[0][0]
# __________________________________________________________________________________________________
# tau_norm_3 (BatchNormalization) (None, 57)           228         tau_dense_3[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_activation_5 (PRe (None, 1, 1, 128)    128         inner_all_2x2_norm_5[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_activation_5 (PRe (None, 1, 1, 128)    128         outer_all_3x3_norm_5[0][0]
# __________________________________________________________________________________________________
# tau_activation_3 (PReLU)        (None, 57)           57          tau_norm_3[0][0]
# __________________________________________________________________________________________________
# inner_all_2x2_dropout_5 (Dropou (None, 1, 1, 128)    0           inner_all_2x2_activation_5[0][0]
# __________________________________________________________________________________________________
# outer_all_3x3_dropout_5 (Dropou (None, 1, 1, 128)    0           outer_all_3x3_activation_5[0][0]
# __________________________________________________________________________________________________
# tau_dropout_3 (Dropout)         (None, 57)           0           tau_activation_3[0][0]
# __________________________________________________________________________________________________
# inner_cells_flatten (Flatten)   (None, 128)          0           inner_all_2x2_dropout_5[0][0]
# __________________________________________________________________________________________________
# outer_cells_flatten (Flatten)   (None, 128)          0           outer_all_3x3_dropout_5[0][0]
# __________________________________________________________________________________________________
# features_concat (Concatenate)   (None, 313)          0           tau_dropout_3[0][0]
#                                                                  inner_cells_flatten[0][0]
#                                                                  outer_cells_flatten[0][0]
# __________________________________________________________________________________________________
# final_dense_1 (Dense)           (None, 320)          100480      features_concat[0][0]
# __________________________________________________________________________________________________
# final_norm_1 (BatchNormalizatio (None, 320)          1280        final_dense_1[0][0]
# __________________________________________________________________________________________________
# final_activation_1 (PReLU)      (None, 320)          320         final_norm_1[0][0]
# __________________________________________________________________________________________________
# final_dropout_1 (Dropout)       (None, 320)          0           final_activation_1[0][0]
# __________________________________________________________________________________________________
# final_dense_2 (Dense)           (None, 200)          64200       final_dropout_1[0][0]
# __________________________________________________________________________________________________
# final_norm_2 (BatchNormalizatio (None, 200)          800         final_dense_2[0][0]
# __________________________________________________________________________________________________
# final_activation_2 (PReLU)      (None, 200)          200         final_norm_2[0][0]
# __________________________________________________________________________________________________
# final_dropout_2 (Dropout)       (None, 200)          0           final_activation_2[0][0]
# __________________________________________________________________________________________________
# final_dense_3 (Dense)           (None, 125)          25125       final_dropout_2[0][0]
# __________________________________________________________________________________________________
# final_norm_3 (BatchNormalizatio (None, 125)          500         final_dense_3[0][0]
# __________________________________________________________________________________________________
# final_activation_3 (PReLU)      (None, 125)          125         final_norm_3[0][0]
# __________________________________________________________________________________________________
# final_dropout_3 (Dropout)       (None, 125)          0           final_activation_3[0][0]
# __________________________________________________________________________________________________
# final_dense_4 (Dense)           (None, 78)           9828        final_dropout_3[0][0]
# __________________________________________________________________________________________________
# final_norm_4 (BatchNormalizatio (None, 78)           312         final_dense_4[0][0]
# __________________________________________________________________________________________________
# final_activation_4 (PReLU)      (None, 78)           78          final_norm_4[0][0]
# __________________________________________________________________________________________________
# final_dropout_4 (Dropout)       (None, 78)           0           final_activation_4[0][0]
# __________________________________________________________________________________________________
# final_dense_5 (Dense)           (None, 64)           5056        final_dropout_4[0][0]
# __________________________________________________________________________________________________
# final_norm_5 (BatchNormalizatio (None, 64)           256         final_dense_5[0][0]
# __________________________________________________________________________________________________
# final_activation_5 (PReLU)      (None, 64)           64          final_norm_5[0][0]
# __________________________________________________________________________________________________
# final_dropout_5 (Dropout)       (None, 64)           0           final_activation_5[0][0]
# __________________________________________________________________________________________________
# final_dense_last (Dense)        (None, 4)            260         final_dropout_5[0][0]
# __________________________________________________________________________________________________
# main_output (Activation)        (None, 4)            0           final_dense_last[0][0]
# ==================================================================================================
# Total params: 1,054,267
# Trainable params: 1,046,149
# Non-trainable params: 8,118
# __________________________________________________________________________________________________

# %%
def compile_model(model, learning_rate):
    #opt = keras.optimizers.Adam(lr=learning_rate)
    opt = keras.optimizers.Nadam(lr=learning_rate, schedule_decay=1e-4)
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=["accuracy"])
    metrics = [
        "accuracy", TauLosses.tau_crossentropy, TauLosses.tau_crossentropy_v2,
        TauLosses.Le, TauLosses.Lmu, TauLosses.Ljet,
        TauLosses.He, TauLosses.Hmu, TauLosses.Htau, TauLosses.Hjet,
        TauLosses.Hcat_e, TauLosses.Hcat_mu, TauLosses.Hcat_jet, TauLosses.Hbin,
        TauLosses.Hcat_eInv, TauLosses.Hcat_muInv, TauLosses.Hcat_jetInv,
        TauLosses.Fe, TauLosses.Fmu, TauLosses.Fjet, TauLosses.Fcmb
    ]
    model.compile(loss=TauLosses.tau_crossentropy_v2, optimizer=opt, metrics=metrics, weighted_metrics=metrics)

def close_file(f_name):
    file_objs = [ obj for obj in gc.get_objects() if ("TextIOWrapper" in str(type(obj))) and (obj.name == f_name)]
    for obj in file_objs:
        obj.close()

class TimeCheckpoint(Callback):
    def __init__(self, time_interval, file_name_prefix):
        self.time_interval = time_interval
        self.file_name_prefix = file_name_prefix
        self.initial_time = time.time()
        self.last_check_time = self.initial_time

    def on_batch_end(self, batch, logs=None):
        if self.time_interval is None or batch % 100 != 0: return
        current_time = time.time()
        delta_t = current_time - self.last_check_time
        if delta_t >= self.time_interval:
            abs_delta_t_h = (current_time - self.initial_time) / 60. / 60.
            read_hdf_lock.acquire()
            self.model.save('{}_historic_b{}_{:.1f}h.h5'.format(self.file_name_prefix, batch, abs_delta_t_h))
            read_hdf_lock.release()
            self.last_check_time = current_time

    def on_epoch_end(self, epoch, logs=None):
        read_hdf_lock.acquire()
        self.model.save('{}_e{}.h5'.format(self.file_name_prefix, epoch))
        read_hdf_lock.release()
        #Notify("Epoch {} is ended.".format(epoch))

def run_training(train_suffix, model_name, data_loader, epoch, n_epochs):

    train_name = '%s_%s' % (model_name, train_suffix)
    log_name = "%s.log" % train_name
    if os.path.isfile(log_name):
        close_file(log_name)
        os.remove(log_name)
    csv_log = CSVLogger(log_name, append=True)

    time_checkpoint = TimeCheckpoint(12*60*60, train_name)
    callbacks = [time_checkpoint, csv_log]
    fit_hist = model.fit_generator(data_loader.generator(True), validation_data=data_loader.generator(False),
                                   steps_per_epoch=data_loader.steps_per_epoch, validation_steps=data_loader.validation_steps,
                                   callbacks=callbacks, epochs=n_epochs, initial_epoch=epoch, verbose=1)

    read_hdf_lock.acquire()
    model.save("%s_final.hdf5" % train_name)
    read_hdf_lock.release()
    return fit_hist

# %%
TauLosses.SetSFs(1, 2.5, 5, 1.5)
print(TauLosses.Le_sf, TauLosses.Lmu_sf, TauLosses.Ltau_sf, TauLosses.Ljet_sf)
compile_model(model, 1e-3)
# Out:
# 0.4 1.0 2.0 0.6000000000000001

# %%
loader = DataLoader('N:/tau-ml/tuples-v2-training-v2-t1/training/part_*.h5', netConf_full, 200, 2000,
                    validation_size=10000000, max_queue_size=20, n_passes=-1, return_grid=True)
print(loader.file_entries)
print(loader.total_size, loader.data_size, loader.validation_size)
# Out:
# [N:/tau-ml/tuples-v2-training-v2-t1/training/part_00.h5: size = 3000000, val_size = 10000000, N:/tau-ml/tuples-v2-training-v2-t1/training/part_01.h5: size = 13000000, val_size = 0, N:/tau-ml/tuples-v2-training-v2-t1/training/part_02.h5: size = 13000000, val_size = 0, N:/tau-ml/tuples-v2-training-v2-t1/training/part_03.h5: size = 13000000, val_size = 0, N:/tau-ml/tuples-v2-training-v2-t1/training/part_04.h5: size = 13000000, val_size = 0, N:/tau-ml/tuples-v2-training-v2-t1/training/part_05.h5: size = 13000000, val_size = 0, N:/tau-ml/tuples-v2-training-v2-t1/training/part_06.h5: size = 13000000, val_size = 0, N:/tau-ml/tuples-v2-training-v2-t1/training/part_07.h5: size = 13000000, val_size = 0, N:/tau-ml/tuples-v2-training-v2-t1/training/part_08.h5: size = 13000000, val_size = 0, N:/tau-ml/tuples-v2-training-v2-t1/training/part_09.h5: size = 13000000, val_size = 0, N:/tau-ml/tuples-v2-training-v2-t1/training/part_10.h5: size = 13000000, val_size = 0, N:/tau-ml/tuples-v2-training-v2-t1/training/part_11.h5: size = 9806949, val_size = 0]
# 152806949 142806949 10000000

# %%
fit_hist = run_training('step{}'.format(1), model_name, loader, 0, 10)
# Out:
# WARNING:tensorflow:From C:\Users\konst\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 714034/714035 [============================>.] - ETA: 0s - loss: 0.3183 - acc: 0.9131 - tau_crossentropy: 0.0831 - tau_crossentropy_v2: 0.2774 - Le: 0.0444 - Lmu: 0.0091 - Ljet: 0.0937 - He: 0.1023 - Hmu: 0.0420 - Htau: 0.0647 - Hjet: 0.1185 - Hcat_e: 0.0136 - Hcat_mu: 7.7928e-04 - Hcat_jet: 0.0281 - Hbin: 0.0551 - Hcat_eInv: 0.0887 - Hcat_muInv: 0.0412 - Hcat_jetInv: 0.0904 - Fe: 0.0111 - Fmu: 0.0010 - Fjet: 0.0184 - Fcmb: 0.0327 - weighted_acc: 0.8652 - weighted_tau_crossentropy: 0.1030 - weighted_tau_crossentropy_v2: 0.3183 - weighted_Le: 0.0665 - weighted_Lmu: 0.0158 - weighted_Ljet: 0.1012 - weighted_He: 0.1027 - weighted_Hmu: 0.0504 - weighted_Htau: 0.0994 - weighted_Hjet: 0.0784 - weighted_Hcat_e: 0.0150 - weighted_Hcat_mu: 8.5438e-04 - weighted_Hcat_jet: 0.0185 - weighted_Hbin: 0.0436 - weighted_Hcat_eInv: 0.0878 - weighted_Hcat_muInv: 0.0495 - weighted_Hcat_jetInv: 0.0598 - weighted_Fe: 0.0125 - weighted_Fmu: 0.0011 - weighted_Fjet: 0.0122 - weighted_Fcmb: 0.0261

# %%
fit_hist
