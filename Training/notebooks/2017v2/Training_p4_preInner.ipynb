# %%
import os
import gc
import sys
import glob
import time
import math
import numpy as np
import uproot
import pandas
from functools import partial
from concurrent.futures import ThreadPoolExecutor

import tensorflow as tf
import keras
import keras.backend as K
from keras import regularizers
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Conv2D, Dropout, AlphaDropout, Activation, BatchNormalization, Flatten, \
                                    Concatenate, PReLU, TimeDistributed, LSTM, Masking
from keras.callbacks import Callback, ModelCheckpoint, CSVLogger
from keras_tqdm import TQDMNotebookCallback

sys.path.insert(0, "../../python")
from common import *
from DataLoader import DataLoader, read_hdf_lock
# Out:
# Using TensorFlow backend.

# %%
class MaskedDense(Dense):
    def __init__(self, units, **kwargs):
        super(MaskedDense, self).__init__(units, **kwargs)
        
    def call(self, inputs, mask=None):
        base_out = super(MaskedDense, self).call(inputs)
        if mask is None:
            return base_out
        zeros = tf.zeros_like(base_out)
        return tf.where(mask, base_out, zeros)

# %%
class SafeModelCheckpoint(ModelCheckpoint):
    def __init__(self, filepath, **kwargs):
        super(SafeModelCheckpoint, self).__init__(filepath, **kwargs)
    
    def on_epoch_end(self, epoch, logs=None):
        read_hdf_lock.acquire()
        super(SafeModelCheckpoint, self).on_epoch_end(epoch, logs)
        read_hdf_lock.release()

# %%
class NetSetup:
    def __init__(self, activation, activation_shared_axes, dropout_rate, first_layer_size, last_layer_size, decay_factor,
                 kernel_regularizer, time_distributed):
        self.activation = activation
        self.activation_shared_axes = activation_shared_axes
        if activation == 'relu' or activation == 'PReLU' or activation == 'tanh':
            self.DropoutType = Dropout
            self.kernel_init = 'he_uniform'
            self.apply_batch_norm = True
        elif activation == 'selu':
            self.DropoutType = AlphaDropout
            self.kernel_init = 'lecun_normal'
            self.apply_batch_norm = False
        else:
            raise RuntimeError('Activation "{}" not supported.'.format(activation))
        self.dropout_rate = dropout_rate
        self.first_layer_size = first_layer_size
        self.last_layer_size = last_layer_size
        self.decay_factor = decay_factor
        self.kernel_regularizer = kernel_regularizer
        self.time_distributed = time_distributed
    
    def RecalcLayerSizes(self, n_input_features, width_factor, compression_factor, consider_dropout = True):
        drop_factor = 1 + self.dropout_rate if consider_dropout else 1
        self.first_layer_size = int(math.ceil(n_input_features * drop_factor * width_factor))
        self.last_layer_size = int(math.ceil(n_input_features * drop_factor * compression_factor))
    
def add_block_ending(net_setup, name_format, layer):
    if net_setup.apply_batch_norm:
        norm_layer = BatchNormalization(name=name_format.format('norm'))
        if net_setup.time_distributed:
            norm_layer = TimeDistributed(norm_layer, name=name_format.format('norm'))
        norm_layer = norm_layer(layer)
    else:
        norm_layer = layer
    if net_setup.activation == 'PReLU':
        activation_layer = PReLU(shared_axes=net_setup.activation_shared_axes,
                                 name=name_format.format('activation'))(norm_layer)
    else:
        activation_layer = Activation(net_setup.activation, name=name_format.format('activation'))(norm_layer)
    if net_setup.dropout_rate > 0:
        return net_setup.DropoutType(net_setup.dropout_rate, name=name_format.format('dropout'))(activation_layer)
    return activation_layer

def dense_block(prev_layer, kernel_size, net_setup, block_name, n):
    DenseType = MaskedDense if net_setup.time_distributed else Dense
    dense = DenseType(kernel_size, name="{}_dense_{}".format(block_name, n),
                      kernel_initializer=net_setup.kernel_init,
                      kernel_regularizer=net_setup.kernel_regularizer)
    if net_setup.time_distributed:
        dense = TimeDistributed(dense, name="{}_dense_{}".format(block_name, n))
    dense = dense(prev_layer)
    return add_block_ending(net_setup, '{}_{{}}_{}'.format(block_name, n), dense)

def reduce_n_features_1d(input_layer, net_setup, block_name):
    prev_layer = input_layer
    current_size = net_setup.first_layer_size
    n = 1
    while True:
        prev_layer = dense_block(prev_layer, current_size, net_setup, block_name, n)
        if current_size == net_setup.last_layer_size: break
        current_size = max(net_setup.last_layer_size, int(current_size / net_setup.decay_factor))
        n += 1
    return prev_layer

def dense_block_sequence(input_layer, net_setup, n_layers, block_name):
    prev_layer = input_layer
    current_size = net_setup.first_layer_size
    for n in range(n_layers):
        prev_layer = dense_block(prev_layer, current_size, net_setup, block_name, n+1)
    return prev_layer


def create_model(net_config):
    tau_net_setup = NetSetup('PReLU', None, 0.2, 128, 128, 1.4, None, False)
    comp_net_setup = NetSetup('PReLU', [1], 0.2, 1024, 64, 1.4, None, True)
    #dense_net_setup = NetSetup('relu', 0, 512, 32, 1.4, keras.regularizers.l1(1e-5))
    dense_net_setup = NetSetup('PReLU', None, 0.2, 512, 64, 1.4, None, False)
            
    input_layers = []
    high_level_features = []

    if len(net_config.tau_branches) > 0:
        input_layer_tau = Input(name="input_tau", shape=(len(net_config.tau_branches),))
        input_layers.append(input_layer_tau)
        tau_net_setup.RecalcLayerSizes(len(net_config.tau_branches), 2, 2)
        processed_tau = dense_block_sequence(input_layer_tau, tau_net_setup, 4, 'tau')
        high_level_features.append(processed_tau)
    
    for loc in net_config.cell_locations:
        reduced_inputs = []
        for comp_id in range(len(net_config.comp_names)):
            comp_name = net_config.comp_names[comp_id]
            n_comp_features = len(input_cell_external_branches) + len(net_config.comp_branches[comp_id])
            input_layer_comp = Input(name="input_{}_{}".format(loc, comp_name),
                                     shape=(n_cells_eta[loc] * n_cells_phi[loc], n_comp_features))
            input_layers.append(input_layer_comp)
            comp_net_setup.RecalcLayerSizes(n_comp_features, 2, 1)
            input_layer_comp_masked = Masking(name="input_{}_{}_masking".format(loc, comp_name))(input_layer_comp)
            #reduced_comp = dense_block_sequence(input_layer_comp_masked, comp_net_setup, 4, "{}_{}".format(loc, comp_name))
            reduced_comp = reduce_n_features_1d(input_layer_comp_masked, comp_net_setup, "{}_{}".format(loc, comp_name))
            reduced_inputs.append(reduced_comp)
            
        inner_n_units = 32
        last_n_units = 32
        if len(net_config.comp_names) > 1:
            #cmb_input = Concatenate(name="{}_cell_concat_0".format(loc), axis=2)(reduced_inputs)
            #comp_net_setup.RecalcLayerSizes(cmb_input.shape.as_list()[2], 1, 0.5, False)
            #cell_input = reduce_n_features_1d(cmb_input, comp_net_setup, "{}_cmb".format(loc))
            cell_input = Concatenate(name="{}_cell_concat_0".format(loc), axis=2)(reduced_inputs)
        else:
            cell_input = reduced_inputs[0]
        
        cell_lstm_1 = LSTM(units=inner_n_units, return_sequences=True, name='{}_lstm_1'.format(loc))(cell_input)
        cell_lstm_1_drop = Dropout(comp_net_setup.dropout_rate, name='{}_lstm_1_dropout'.format(loc))(cell_lstm_1)
        
        cell_input_1 = Concatenate(name="{}_cell_concat_1".format(loc), axis=2)([cell_input, cell_lstm_1_drop])
        cell_lstm_2 = LSTM(units=inner_n_units, return_sequences=True, name='{}_lstm_2'.format(loc))(cell_input_1)
        cell_lstm_2_drop = Dropout(comp_net_setup.dropout_rate, name='{}_lstm_2_dropout'.format(loc))(cell_lstm_2)

        cell_input_2 = Concatenate(name="{}_cell_concat_2".format(loc), axis=2)([cell_input, cell_lstm_2_drop])
        cell_lstm_3 = LSTM(units=last_n_units, return_sequences=False, name='{}_lstm_3'.format(loc))(cell_input_2)
        cell_lstm_3_drop = Dropout(comp_net_setup.dropout_rate, name='{}_lstm_3_dropout'.format(loc))(cell_lstm_3)

        high_level_features.append(cell_lstm_3_drop)
        
    if len(high_level_features) > 1:
        features_concat = Concatenate(name="features_concat", axis=1)(high_level_features)
    else:
        features_concat = high_level_features[0]
    if net_config.final:
        dense_net_setup.first_layer_size = features_concat.shape.as_list()[1]
        final_dense = dense_block_sequence(features_concat, dense_net_setup, 4, 'final')
        output_layer = Dense(n_outputs, name="final_dense_last",
                     kernel_initializer=dense_net_setup.kernel_init)(final_dense)

    else:
        final_dense = dense_block(features_concat, 1024, dense_net_setup,
                                  'tmp_{}'.format(net_config.name), 1)
        output_layer = Dense(n_outputs, name="tmp_{}_dense_last".format(net_config.name),
                             kernel_initializer=dense_net_setup.kernel_init)(final_dense)
    softmax_output = Activation("softmax", name="main_output")(output_layer)
    
    model = Model(input_layers, softmax_output, name="DeepTau2017v2")
    return model

# %%
def compile_model(model, learning_rate):
    opt = keras.optimizers.Adam(lr=learning_rate)
    #opt = keras.optimizers.Nadam(lr=learning_rate)
    #model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=["accuracy"])
    metrics = [ "accuracy", TauLosses.tau_crossentropy, TauLosses.tau_crossentropy_v2, TauLosses.Le, TauLosses.Lmu,
               TauLosses.Ljet, TauLosses.He, TauLosses.Hmu, TauLosses.Htau, TauLosses.Hjet ]
    model.compile(loss=TauLosses.tau_crossentropy_v2, optimizer=opt, metrics=metrics, weighted_metrics=metrics)

# %%
TauLosses.SetSFs(1, 1, 3, 1)
model_name = "DeepTau2017v2p4_preInner"
model = create_model(netConf_full)
compile_model(model, 1e-3)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_inner_egamma (InputLayer) (None, 121, 86)      0
# __________________________________________________________________________________________________
# input_inner_muon (InputLayer)   (None, 121, 64)      0
# __________________________________________________________________________________________________
# input_outer_egamma (InputLayer) (None, 121, 86)      0
# __________________________________________________________________________________________________
# input_outer_muon (InputLayer)   (None, 121, 64)      0
# __________________________________________________________________________________________________
# input_inner_egamma_masking (Mas (None, 121, 86)      0           input_inner_egamma[0][0]
# __________________________________________________________________________________________________
# input_inner_muon_masking (Maski (None, 121, 64)      0           input_inner_muon[0][0]
# __________________________________________________________________________________________________
# input_outer_egamma_masking (Mas (None, 121, 86)      0           input_outer_egamma[0][0]
# __________________________________________________________________________________________________
# input_outer_muon_masking (Maski (None, 121, 64)      0           input_outer_muon[0][0]
# __________________________________________________________________________________________________
# inner_egamma_dense_1 (TimeDistr (None, 121, 207)     18009       input_inner_egamma_masking[0][0]
# __________________________________________________________________________________________________
# inner_muon_dense_1 (TimeDistrib (None, 121, 154)     10010       input_inner_muon_masking[0][0]
# __________________________________________________________________________________________________
# outer_egamma_dense_1 (TimeDistr (None, 121, 207)     18009       input_outer_egamma_masking[0][0]
# __________________________________________________________________________________________________
# outer_muon_dense_1 (TimeDistrib (None, 121, 154)     10010       input_outer_muon_masking[0][0]
# __________________________________________________________________________________________________
# inner_egamma_norm_1 (TimeDistri (None, 121, 207)     828         inner_egamma_dense_1[0][0]
# __________________________________________________________________________________________________
# inner_muon_norm_1 (TimeDistribu (None, 121, 154)     616         inner_muon_dense_1[0][0]
# __________________________________________________________________________________________________
# outer_egamma_norm_1 (TimeDistri (None, 121, 207)     828         outer_egamma_dense_1[0][0]
# __________________________________________________________________________________________________
# outer_muon_norm_1 (TimeDistribu (None, 121, 154)     616         outer_muon_dense_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_activation_1 (PReL (None, 121, 207)     207         inner_egamma_norm_1[0][0]
# __________________________________________________________________________________________________
# inner_muon_activation_1 (PReLU) (None, 121, 154)     154         inner_muon_norm_1[0][0]
# __________________________________________________________________________________________________
# input_inner_hadrons (InputLayer (None, 121, 38)      0
# __________________________________________________________________________________________________
# outer_egamma_activation_1 (PReL (None, 121, 207)     207         outer_egamma_norm_1[0][0]
# __________________________________________________________________________________________________
# outer_muon_activation_1 (PReLU) (None, 121, 154)     154         outer_muon_norm_1[0][0]
# __________________________________________________________________________________________________
# input_outer_hadrons (InputLayer (None, 121, 38)      0
# __________________________________________________________________________________________________
# inner_egamma_dropout_1 (Dropout (None, 121, 207)     0           inner_egamma_activation_1[0][0]
# __________________________________________________________________________________________________
# inner_muon_dropout_1 (Dropout)  (None, 121, 154)     0           inner_muon_activation_1[0][0]
# __________________________________________________________________________________________________
# input_inner_hadrons_masking (Ma (None, 121, 38)      0           input_inner_hadrons[0][0]
# __________________________________________________________________________________________________
# outer_egamma_dropout_1 (Dropout (None, 121, 207)     0           outer_egamma_activation_1[0][0]
# __________________________________________________________________________________________________
# outer_muon_dropout_1 (Dropout)  (None, 121, 154)     0           outer_muon_activation_1[0][0]
# __________________________________________________________________________________________________
# input_outer_hadrons_masking (Ma (None, 121, 38)      0           input_outer_hadrons[0][0]
# __________________________________________________________________________________________________
# inner_egamma_dense_2 (TimeDistr (None, 121, 147)     30576       inner_egamma_dropout_1[0][0]
# __________________________________________________________________________________________________
# inner_muon_dense_2 (TimeDistrib (None, 121, 110)     17050       inner_muon_dropout_1[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_dense_1 (TimeDist (None, 121, 92)      3588        input_inner_hadrons_masking[0][0]
# __________________________________________________________________________________________________
# outer_egamma_dense_2 (TimeDistr (None, 121, 147)     30576       outer_egamma_dropout_1[0][0]
# __________________________________________________________________________________________________
# outer_muon_dense_2 (TimeDistrib (None, 121, 110)     17050       outer_muon_dropout_1[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_dense_1 (TimeDist (None, 121, 92)      3588        input_outer_hadrons_masking[0][0]
# __________________________________________________________________________________________________
# inner_egamma_norm_2 (TimeDistri (None, 121, 147)     588         inner_egamma_dense_2[0][0]
# __________________________________________________________________________________________________
# inner_muon_norm_2 (TimeDistribu (None, 121, 110)     440         inner_muon_dense_2[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_norm_1 (TimeDistr (None, 121, 92)      368         inner_hadrons_dense_1[0][0]
# __________________________________________________________________________________________________
# outer_egamma_norm_2 (TimeDistri (None, 121, 147)     588         outer_egamma_dense_2[0][0]
# __________________________________________________________________________________________________
# outer_muon_norm_2 (TimeDistribu (None, 121, 110)     440         outer_muon_dense_2[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_norm_1 (TimeDistr (None, 121, 92)      368         outer_hadrons_dense_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_activation_2 (PReL (None, 121, 147)     147         inner_egamma_norm_2[0][0]
# __________________________________________________________________________________________________
# inner_muon_activation_2 (PReLU) (None, 121, 110)     110         inner_muon_norm_2[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_activation_1 (PRe (None, 121, 92)      92          inner_hadrons_norm_1[0][0]
# __________________________________________________________________________________________________
# outer_egamma_activation_2 (PReL (None, 121, 147)     147         outer_egamma_norm_2[0][0]
# __________________________________________________________________________________________________
# outer_muon_activation_2 (PReLU) (None, 121, 110)     110         outer_muon_norm_2[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_activation_1 (PRe (None, 121, 92)      92          outer_hadrons_norm_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_dropout_2 (Dropout (None, 121, 147)     0           inner_egamma_activation_2[0][0]
# __________________________________________________________________________________________________
# inner_muon_dropout_2 (Dropout)  (None, 121, 110)     0           inner_muon_activation_2[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_dropout_1 (Dropou (None, 121, 92)      0           inner_hadrons_activation_1[0][0]
# __________________________________________________________________________________________________
# outer_egamma_dropout_2 (Dropout (None, 121, 147)     0           outer_egamma_activation_2[0][0]
# __________________________________________________________________________________________________
# outer_muon_dropout_2 (Dropout)  (None, 121, 110)     0           outer_muon_activation_2[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_dropout_1 (Dropou (None, 121, 92)      0           outer_hadrons_activation_1[0][0]
# __________________________________________________________________________________________________
# input_tau (InputLayer)          (None, 47)           0
# __________________________________________________________________________________________________
# inner_egamma_dense_3 (TimeDistr (None, 121, 105)     15540       inner_egamma_dropout_2[0][0]
# __________________________________________________________________________________________________
# inner_muon_dense_3 (TimeDistrib (None, 121, 78)      8658        inner_muon_dropout_2[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_dense_2 (TimeDist (None, 121, 65)      6045        inner_hadrons_dropout_1[0][0]
# __________________________________________________________________________________________________
# outer_egamma_dense_3 (TimeDistr (None, 121, 105)     15540       outer_egamma_dropout_2[0][0]
# __________________________________________________________________________________________________
# outer_muon_dense_3 (TimeDistrib (None, 121, 78)      8658        outer_muon_dropout_2[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_dense_2 (TimeDist (None, 121, 65)      6045        outer_hadrons_dropout_1[0][0]
# __________________________________________________________________________________________________
# tau_dense_1 (Dense)             (None, 113)          5424        input_tau[0][0]
# __________________________________________________________________________________________________
# inner_egamma_norm_3 (TimeDistri (None, 121, 105)     420         inner_egamma_dense_3[0][0]
# __________________________________________________________________________________________________
# inner_muon_norm_3 (TimeDistribu (None, 121, 78)      312         inner_muon_dense_3[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_norm_2 (TimeDistr (None, 121, 65)      260         inner_hadrons_dense_2[0][0]
# __________________________________________________________________________________________________
# outer_egamma_norm_3 (TimeDistri (None, 121, 105)     420         outer_egamma_dense_3[0][0]
# __________________________________________________________________________________________________
# outer_muon_norm_3 (TimeDistribu (None, 121, 78)      312         outer_muon_dense_3[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_norm_2 (TimeDistr (None, 121, 65)      260         outer_hadrons_dense_2[0][0]
# __________________________________________________________________________________________________
# tau_norm_1 (BatchNormalization) (None, 113)          452         tau_dense_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_activation_3 (PReL (None, 121, 105)     105         inner_egamma_norm_3[0][0]
# __________________________________________________________________________________________________
# inner_muon_activation_3 (PReLU) (None, 121, 78)      78          inner_muon_norm_3[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_activation_2 (PRe (None, 121, 65)      65          inner_hadrons_norm_2[0][0]
# __________________________________________________________________________________________________
# outer_egamma_activation_3 (PReL (None, 121, 105)     105         outer_egamma_norm_3[0][0]
# __________________________________________________________________________________________________
# outer_muon_activation_3 (PReLU) (None, 121, 78)      78          outer_muon_norm_3[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_activation_2 (PRe (None, 121, 65)      65          outer_hadrons_norm_2[0][0]
# __________________________________________________________________________________________________
# tau_activation_1 (PReLU)        (None, 113)          113         tau_norm_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_dropout_3 (Dropout (None, 121, 105)     0           inner_egamma_activation_3[0][0]
# __________________________________________________________________________________________________
# inner_muon_dropout_3 (Dropout)  (None, 121, 78)      0           inner_muon_activation_3[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_dropout_2 (Dropou (None, 121, 65)      0           inner_hadrons_activation_2[0][0]
# __________________________________________________________________________________________________
# outer_egamma_dropout_3 (Dropout (None, 121, 105)     0           outer_egamma_activation_3[0][0]
# __________________________________________________________________________________________________
# outer_muon_dropout_3 (Dropout)  (None, 121, 78)      0           outer_muon_activation_3[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_dropout_2 (Dropou (None, 121, 65)      0           outer_hadrons_activation_2[0][0]
# __________________________________________________________________________________________________
# tau_dropout_1 (Dropout)         (None, 113)          0           tau_activation_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_dense_4 (TimeDistr (None, 121, 104)     11024       inner_egamma_dropout_3[0][0]
# __________________________________________________________________________________________________
# inner_muon_dense_4 (TimeDistrib (None, 121, 77)      6083        inner_muon_dropout_3[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_dense_3 (TimeDist (None, 121, 46)      3036        inner_hadrons_dropout_2[0][0]
# __________________________________________________________________________________________________
# outer_egamma_dense_4 (TimeDistr (None, 121, 104)     11024       outer_egamma_dropout_3[0][0]
# __________________________________________________________________________________________________
# outer_muon_dense_4 (TimeDistrib (None, 121, 77)      6083        outer_muon_dropout_3[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_dense_3 (TimeDist (None, 121, 46)      3036        outer_hadrons_dropout_2[0][0]
# __________________________________________________________________________________________________
# tau_dense_2 (Dense)             (None, 113)          12882       tau_dropout_1[0][0]
# __________________________________________________________________________________________________
# inner_egamma_norm_4 (TimeDistri (None, 121, 104)     416         inner_egamma_dense_4[0][0]
# __________________________________________________________________________________________________
# inner_muon_norm_4 (TimeDistribu (None, 121, 77)      308         inner_muon_dense_4[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_norm_3 (TimeDistr (None, 121, 46)      184         inner_hadrons_dense_3[0][0]
# __________________________________________________________________________________________________
# outer_egamma_norm_4 (TimeDistri (None, 121, 104)     416         outer_egamma_dense_4[0][0]
# __________________________________________________________________________________________________
# outer_muon_norm_4 (TimeDistribu (None, 121, 77)      308         outer_muon_dense_4[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_norm_3 (TimeDistr (None, 121, 46)      184         outer_hadrons_dense_3[0][0]
# __________________________________________________________________________________________________
# tau_norm_2 (BatchNormalization) (None, 113)          452         tau_dense_2[0][0]
# __________________________________________________________________________________________________
# inner_egamma_activation_4 (PReL (None, 121, 104)     104         inner_egamma_norm_4[0][0]
# __________________________________________________________________________________________________
# inner_muon_activation_4 (PReLU) (None, 121, 77)      77          inner_muon_norm_4[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_activation_3 (PRe (None, 121, 46)      46          inner_hadrons_norm_3[0][0]
# __________________________________________________________________________________________________
# outer_egamma_activation_4 (PReL (None, 121, 104)     104         outer_egamma_norm_4[0][0]
# __________________________________________________________________________________________________
# outer_muon_activation_4 (PReLU) (None, 121, 77)      77          outer_muon_norm_4[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_activation_3 (PRe (None, 121, 46)      46          outer_hadrons_norm_3[0][0]
# __________________________________________________________________________________________________
# tau_activation_2 (PReLU)        (None, 113)          113         tau_norm_2[0][0]
# __________________________________________________________________________________________________
# inner_egamma_dropout_4 (Dropout (None, 121, 104)     0           inner_egamma_activation_4[0][0]
# __________________________________________________________________________________________________
# inner_muon_dropout_4 (Dropout)  (None, 121, 77)      0           inner_muon_activation_4[0][0]
# __________________________________________________________________________________________________
# inner_hadrons_dropout_3 (Dropou (None, 121, 46)      0           inner_hadrons_activation_3[0][0]
# __________________________________________________________________________________________________
# outer_egamma_dropout_4 (Dropout (None, 121, 104)     0           outer_egamma_activation_4[0][0]
# __________________________________________________________________________________________________
# outer_muon_dropout_4 (Dropout)  (None, 121, 77)      0           outer_muon_activation_4[0][0]
# __________________________________________________________________________________________________
# outer_hadrons_dropout_3 (Dropou (None, 121, 46)      0           outer_hadrons_activation_3[0][0]
# __________________________________________________________________________________________________
# tau_dropout_2 (Dropout)         (None, 113)          0           tau_activation_2[0][0]
# __________________________________________________________________________________________________
# inner_cell_concat_0 (Concatenat (None, 121, 227)     0           inner_egamma_dropout_4[0][0]
#                                                                  inner_muon_dropout_4[0][0]
#                                                                  inner_hadrons_dropout_3[0][0]
# __________________________________________________________________________________________________
# outer_cell_concat_0 (Concatenat (None, 121, 227)     0           outer_egamma_dropout_4[0][0]
#                                                                  outer_muon_dropout_4[0][0]
#                                                                  outer_hadrons_dropout_3[0][0]
# __________________________________________________________________________________________________
# tau_dense_3 (Dense)             (None, 113)          12882       tau_dropout_2[0][0]
# __________________________________________________________________________________________________
# inner_lstm_1 (LSTM)             (None, 121, 32)      33280       inner_cell_concat_0[0][0]
# __________________________________________________________________________________________________
# outer_lstm_1 (LSTM)             (None, 121, 32)      33280       outer_cell_concat_0[0][0]
# __________________________________________________________________________________________________
# tau_norm_3 (BatchNormalization) (None, 113)          452         tau_dense_3[0][0]
# __________________________________________________________________________________________________
# inner_lstm_1_dropout (Dropout)  (None, 121, 32)      0           inner_lstm_1[0][0]
# __________________________________________________________________________________________________
# outer_lstm_1_dropout (Dropout)  (None, 121, 32)      0           outer_lstm_1[0][0]
# __________________________________________________________________________________________________
# tau_activation_3 (PReLU)        (None, 113)          113         tau_norm_3[0][0]
# __________________________________________________________________________________________________
# inner_cell_concat_1 (Concatenat (None, 121, 259)     0           inner_cell_concat_0[0][0]
#                                                                  inner_lstm_1_dropout[0][0]
# __________________________________________________________________________________________________
# outer_cell_concat_1 (Concatenat (None, 121, 259)     0           outer_cell_concat_0[0][0]
#                                                                  outer_lstm_1_dropout[0][0]
# __________________________________________________________________________________________________
# tau_dropout_3 (Dropout)         (None, 113)          0           tau_activation_3[0][0]
# __________________________________________________________________________________________________
# inner_lstm_2 (LSTM)             (None, 121, 32)      37376       inner_cell_concat_1[0][0]
# __________________________________________________________________________________________________
# outer_lstm_2 (LSTM)             (None, 121, 32)      37376       outer_cell_concat_1[0][0]
# __________________________________________________________________________________________________
# tau_dense_4 (Dense)             (None, 113)          12882       tau_dropout_3[0][0]
# __________________________________________________________________________________________________
# inner_lstm_2_dropout (Dropout)  (None, 121, 32)      0           inner_lstm_2[0][0]
# __________________________________________________________________________________________________
# outer_lstm_2_dropout (Dropout)  (None, 121, 32)      0           outer_lstm_2[0][0]
# __________________________________________________________________________________________________
# tau_norm_4 (BatchNormalization) (None, 113)          452         tau_dense_4[0][0]
# __________________________________________________________________________________________________
# inner_cell_concat_2 (Concatenat (None, 121, 259)     0           inner_cell_concat_0[0][0]
#                                                                  inner_lstm_2_dropout[0][0]
# __________________________________________________________________________________________________
# outer_cell_concat_2 (Concatenat (None, 121, 259)     0           outer_cell_concat_0[0][0]
#                                                                  outer_lstm_2_dropout[0][0]
# __________________________________________________________________________________________________
# tau_activation_4 (PReLU)        (None, 113)          113         tau_norm_4[0][0]
# __________________________________________________________________________________________________
# inner_lstm_3 (LSTM)             (None, 32)           37376       inner_cell_concat_2[0][0]
# __________________________________________________________________________________________________
# outer_lstm_3 (LSTM)             (None, 32)           37376       outer_cell_concat_2[0][0]
# __________________________________________________________________________________________________
# tau_dropout_4 (Dropout)         (None, 113)          0           tau_activation_4[0][0]
# __________________________________________________________________________________________________
# inner_lstm_3_dropout (Dropout)  (None, 32)           0           inner_lstm_3[0][0]
# __________________________________________________________________________________________________
# outer_lstm_3_dropout (Dropout)  (None, 32)           0           outer_lstm_3[0][0]
# __________________________________________________________________________________________________
# features_concat (Concatenate)   (None, 177)          0           tau_dropout_4[0][0]
#                                                                  inner_lstm_3_dropout[0][0]
#                                                                  outer_lstm_3_dropout[0][0]
# __________________________________________________________________________________________________
# final_dense_1 (Dense)           (None, 177)          31506       features_concat[0][0]
# __________________________________________________________________________________________________
# final_norm_1 (BatchNormalizatio (None, 177)          708         final_dense_1[0][0]
# __________________________________________________________________________________________________
# final_activation_1 (PReLU)      (None, 177)          177         final_norm_1[0][0]
# __________________________________________________________________________________________________
# final_dropout_1 (Dropout)       (None, 177)          0           final_activation_1[0][0]
# __________________________________________________________________________________________________
# final_dense_2 (Dense)           (None, 177)          31506       final_dropout_1[0][0]
# __________________________________________________________________________________________________
# final_norm_2 (BatchNormalizatio (None, 177)          708         final_dense_2[0][0]
# __________________________________________________________________________________________________
# final_activation_2 (PReLU)      (None, 177)          177         final_norm_2[0][0]
# __________________________________________________________________________________________________
# final_dropout_2 (Dropout)       (None, 177)          0           final_activation_2[0][0]
# __________________________________________________________________________________________________
# final_dense_3 (Dense)           (None, 177)          31506       final_dropout_2[0][0]
# __________________________________________________________________________________________________
# final_norm_3 (BatchNormalizatio (None, 177)          708         final_dense_3[0][0]
# __________________________________________________________________________________________________
# final_activation_3 (PReLU)      (None, 177)          177         final_norm_3[0][0]
# __________________________________________________________________________________________________
# final_dropout_3 (Dropout)       (None, 177)          0           final_activation_3[0][0]
# __________________________________________________________________________________________________
# final_dense_4 (Dense)           (None, 177)          31506       final_dropout_3[0][0]
# __________________________________________________________________________________________________
# final_norm_4 (BatchNormalizatio (None, 177)          708         final_dense_4[0][0]
# __________________________________________________________________________________________________
# final_activation_4 (PReLU)      (None, 177)          177         final_norm_4[0][0]
# __________________________________________________________________________________________________
# final_dropout_4 (Dropout)       (None, 177)          0           final_activation_4[0][0]
# __________________________________________________________________________________________________
# final_dense_last (Dense)        (None, 4)            712         final_dropout_4[0][0]
# __________________________________________________________________________________________________
# main_output (Activation)        (None, 4)            0           final_dense_last[0][0]
# ==================================================================================================
# Total params: 663,758
# Trainable params: 656,698
# Non-trainable params: 7,060
# __________________________________________________________________________________________________

# %%
model.load_weights('DeepTau2017v2p4_preTau_step1_final.hdf5', by_name=True)

# %%
def GetNumberOfTrainableParams(model, exclude_prefix = 'tmp'):
    count = 0
    for w in model.trainable_weights:
        if not w.name.startswith(exclude_prefix):
            count += K.count_params(w)
    return count
GetNumberOfTrainableParams(model)
# Out:
# 241206

# %%
def close_file(f_name):
    file_objs = [ obj for obj in gc.get_objects() if ("TextIOWrapper" in str(type(obj))) and (obj.name == f_name)]
    for obj in file_objs:
        obj.close()

# %%
class TimeCheckpoint(Callback):
    def __init__(self, time_interval, file_name_prefix):
        self.time_interval = time_interval
        self.file_name_prefix = file_name_prefix
        self.initial_time = time.time()
        self.last_check_time = self.initial_time
    
    def on_batch_end(self, batch, logs=None):
        if batch % 100 != 0: return
        current_time = time.time()
        delta_t = current_time - self.last_check_time
        if delta_t >= self.time_interval:
            abs_delta_t_h = (current_time - self.initial_time) / 60. / 60.
            read_hdf_lock.acquire()
            self.model.save('{}_b{}_{:.1f}h.h5'.format(self.file_name_prefix, batch, abs_delta_t_h))
            read_hdf_lock.release()
            self.last_check_time = current_time

# %%
def run_training(train_suffix, model_name, data_loader, epoch, n_epochs):

    train_name = '%s_%s' % (model_name, train_suffix)
    
    cb_acc = []
    for acc_name in ["acc", "weighted_acc"]:
        cb_acc.append(SafeModelCheckpoint("%s_acc.hdf5" % train_name, monitor="val_%s" % acc_name, save_best_only=True,
                                          save_weights_only=False, mode="max", verbose=1))
    
    losses_names = [ "loss" ]
    for w_suffix in [ "", "weighted_" ]:
        for l_name in [ "tau_crossentropy", "tau_crossentropy_v2", "Le", "Lmu", "Ljet", "He", "Hmu", "Htau", "Hjet" ]:
            losses_names.append(w_suffix + l_name)
    cb_losses = []
    for loss_name in losses_names:
        cb_losses.append(ModelCheckpoint("%s_%s.hdf5" % (train_name, loss_name), monitor="val_%s" % loss_name,
                                         save_best_only=True, save_weights_only=False, mode="min", verbose=1))

    log_name = "%s.log" % train_name
    if os.path.isfile(log_name):
        close_file(log_name)
        os.remove(log_name)
    csv_log = CSVLogger(log_name, append=True)

    time_checkpoint = TimeCheckpoint(4*60*60, '{}_historic'.format(train_name))
    pbar = TQDMNotebookCallback(leave_outer=True, show_outer=True, leave_inner = True)
    callbacks = [pbar, time_checkpoint, csv_log, *cb_acc, *cb_losses]
    fit_hist = model.fit_generator(data_loader.generator(True), validation_data=data_loader.generator(False),
                                   steps_per_epoch=data_loader.steps_per_epoch, validation_steps=data_loader.validation_steps,
                                   callbacks=callbacks, epochs=n_epochs, initial_epoch=epoch, verbose=0)

    model.save("%s_final.hdf5" % train_name)
    return fit_hist

# %%
loader = DataLoader('N:/tau-ml/tuples-v2-t3/training/part_*.h5', netConf_full, 500, 10000, validation_size=6100000,
                    max_queue_size=40, n_passes=-1, return_grid=False)

print(loader.total_size, loader.data_size, loader.validation_size)
# Out:
# 72491602 66391602 6100000

# %%
fit_hist = run_training('step{}'.format(1), model_name, loader, 0, 2)
# Out:
# HBox(children=(IntProgress(value=0, description='Training', max=2, style=ProgressStyle(description_width='init…
# HBox(children=(IntProgress(value=0, description='Epoch 0', max=132784, style=ProgressStyle(description_width='…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-55a2bf856b64> in <module>
# ----> 1 fit_hist = run_training('step{}'.format(1), model_name, loader, 0, 2)
#
# <ipython-input-10-6d3af44b2d66> in run_training(train_suffix, model_name, data_loader, epoch, n_epochs)
#      28     fit_hist = model.fit_generator(data_loader.generator(True), validation_data=data_loader.generator(False),
#      29                                    steps_per_epoch=data_loader.steps_per_epoch, validation_steps=data_loader.validation_steps,
# ---> 30                                    callbacks=callbacks, epochs=n_epochs, initial_epoch=epoch, verbose=0)
#      31
#      32     model.save("%s_final.hdf5" % train_name)
#
# ~\AppData\Roaming\Python\Python36\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\AppData\Roaming\Python\Python36\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\AppData\Roaming\Python\Python36\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~\AppData\Roaming\Python\Python36\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\AppData\Roaming\Python\Python36\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
