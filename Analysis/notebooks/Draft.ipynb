# %%
import math

# %%
t = 300
math.sqrt(1-0.999 ** t)/(1-0.99 ** t)
# Out:
# 0.5354680071307059

# %%
1e7/1e4
# Out:
# 1000.0

# %%
200*200*6*4*3*500*4*2 / 1e9
# Out:
# 11.52

# %%
import tensorflow as tf
# Out:
# C:\Users\konst\AppData\Roaming\Python\Python36\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def load_graph(graph_filename):
    with tf.gfile.GFile(graph_filename, 'rb') as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())

    with tf.Graph().as_default() as graph:
        tf.import_graph_def(graph_def, name="")
    return graph

# %%
graph = load_graph("..\models\deepTau_2017v1_20L1024N.pb")
sess = tf.Session(graph=graph)

# %%
graph.get_operations()
# Out:
# [<tf.Operation 'dense_1_input' type=Placeholder>,
#  <tf.Operation 'dense_1/kernel' type=Const>,
#  <tf.Operation 'dense_1/kernel/read' type=Identity>,
#  <tf.Operation 'dense_1/bias' type=Const>,
#  <tf.Operation 'dense_1/bias/read' type=Identity>,
#  <tf.Operation 'dense_1/MatMul' type=MatMul>,
#  <tf.Operation 'dense_1/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_1/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_1/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/beta' type=Const>,
#  <tf.Operation 'batch_normalization_1/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_1/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_1/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_1/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_1/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_1/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_1/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_1/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_1/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_1/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_1/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_1/Relu' type=Relu>,
#  <tf.Operation 'dropout_1/Identity' type=Identity>,
#  <tf.Operation 'dense_2/kernel' type=Const>,
#  <tf.Operation 'dense_2/kernel/read' type=Identity>,
#  <tf.Operation 'dense_2/bias' type=Const>,
#  <tf.Operation 'dense_2/bias/read' type=Identity>,
#  <tf.Operation 'dense_2/MatMul' type=MatMul>,
#  <tf.Operation 'dense_2/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_2/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_2/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/beta' type=Const>,
#  <tf.Operation 'batch_normalization_2/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_2/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_2/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_2/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_2/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_2/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_2/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_2/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_2/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_2/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_2/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_2/Relu' type=Relu>,
#  <tf.Operation 'dropout_2/Identity' type=Identity>,
#  <tf.Operation 'dense_3/kernel' type=Const>,
#  <tf.Operation 'dense_3/kernel/read' type=Identity>,
#  <tf.Operation 'dense_3/bias' type=Const>,
#  <tf.Operation 'dense_3/bias/read' type=Identity>,
#  <tf.Operation 'dense_3/MatMul' type=MatMul>,
#  <tf.Operation 'dense_3/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_3/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_3/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/beta' type=Const>,
#  <tf.Operation 'batch_normalization_3/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_3/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_3/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_3/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_3/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_3/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_3/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_3/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_3/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_3/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_3/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_3/Relu' type=Relu>,
#  <tf.Operation 'dropout_3/Identity' type=Identity>,
#  <tf.Operation 'dense_4/kernel' type=Const>,
#  <tf.Operation 'dense_4/kernel/read' type=Identity>,
#  <tf.Operation 'dense_4/bias' type=Const>,
#  <tf.Operation 'dense_4/bias/read' type=Identity>,
#  <tf.Operation 'dense_4/MatMul' type=MatMul>,
#  <tf.Operation 'dense_4/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_4/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_4/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/beta' type=Const>,
#  <tf.Operation 'batch_normalization_4/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_4/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_4/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_4/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_4/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_4/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_4/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_4/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_4/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_4/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_4/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_4/Relu' type=Relu>,
#  <tf.Operation 'dropout_4/Identity' type=Identity>,
#  <tf.Operation 'dense_5/kernel' type=Const>,
#  <tf.Operation 'dense_5/kernel/read' type=Identity>,
#  <tf.Operation 'dense_5/bias' type=Const>,
#  <tf.Operation 'dense_5/bias/read' type=Identity>,
#  <tf.Operation 'dense_5/MatMul' type=MatMul>,
#  <tf.Operation 'dense_5/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_5/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_5/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_5/beta' type=Const>,
#  <tf.Operation 'batch_normalization_5/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_5/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_5/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_5/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_5/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_5/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_5/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_5/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_5/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_5/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_5/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_5/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_5/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_5/Relu' type=Relu>,
#  <tf.Operation 'dropout_5/Identity' type=Identity>,
#  <tf.Operation 'dense_6/kernel' type=Const>,
#  <tf.Operation 'dense_6/kernel/read' type=Identity>,
#  <tf.Operation 'dense_6/bias' type=Const>,
#  <tf.Operation 'dense_6/bias/read' type=Identity>,
#  <tf.Operation 'dense_6/MatMul' type=MatMul>,
#  <tf.Operation 'dense_6/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_6/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_6/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_6/beta' type=Const>,
#  <tf.Operation 'batch_normalization_6/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_6/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_6/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_6/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_6/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_6/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_6/Relu' type=Relu>,
#  <tf.Operation 'dropout_6/Identity' type=Identity>,
#  <tf.Operation 'dense_7/kernel' type=Const>,
#  <tf.Operation 'dense_7/kernel/read' type=Identity>,
#  <tf.Operation 'dense_7/bias' type=Const>,
#  <tf.Operation 'dense_7/bias/read' type=Identity>,
#  <tf.Operation 'dense_7/MatMul' type=MatMul>,
#  <tf.Operation 'dense_7/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_7/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_7/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_7/beta' type=Const>,
#  <tf.Operation 'batch_normalization_7/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_7/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_7/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_7/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_7/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_7/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_7/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_7/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_7/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_7/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_7/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_7/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_7/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_7/Relu' type=Relu>,
#  <tf.Operation 'dropout_7/Identity' type=Identity>,
#  <tf.Operation 'dense_8/kernel' type=Const>,
#  <tf.Operation 'dense_8/kernel/read' type=Identity>,
#  <tf.Operation 'dense_8/bias' type=Const>,
#  <tf.Operation 'dense_8/bias/read' type=Identity>,
#  <tf.Operation 'dense_8/MatMul' type=MatMul>,
#  <tf.Operation 'dense_8/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_8/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_8/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_8/beta' type=Const>,
#  <tf.Operation 'batch_normalization_8/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_8/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_8/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_8/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_8/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_8/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_8/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_8/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_8/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_8/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_8/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_8/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_8/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_8/Relu' type=Relu>,
#  <tf.Operation 'dropout_8/Identity' type=Identity>,
#  <tf.Operation 'dense_9/kernel' type=Const>,
#  <tf.Operation 'dense_9/kernel/read' type=Identity>,
#  <tf.Operation 'dense_9/bias' type=Const>,
#  <tf.Operation 'dense_9/bias/read' type=Identity>,
#  <tf.Operation 'dense_9/MatMul' type=MatMul>,
#  <tf.Operation 'dense_9/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_9/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_9/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_9/beta' type=Const>,
#  <tf.Operation 'batch_normalization_9/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_9/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_9/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_9/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_9/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_9/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_9/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_9/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_9/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_9/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_9/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_9/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_9/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_9/Relu' type=Relu>,
#  <tf.Operation 'dropout_9/Identity' type=Identity>,
#  <tf.Operation 'dense_10/kernel' type=Const>,
#  <tf.Operation 'dense_10/kernel/read' type=Identity>,
#  <tf.Operation 'dense_10/bias' type=Const>,
#  <tf.Operation 'dense_10/bias/read' type=Identity>,
#  <tf.Operation 'dense_10/MatMul' type=MatMul>,
#  <tf.Operation 'dense_10/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_10/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_10/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_10/beta' type=Const>,
#  <tf.Operation 'batch_normalization_10/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_10/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_10/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_10/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_10/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_10/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_10/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_10/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_10/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_10/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_10/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_10/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_10/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_10/Relu' type=Relu>,
#  <tf.Operation 'dropout_10/Identity' type=Identity>,
#  <tf.Operation 'dense_11/kernel' type=Const>,
#  <tf.Operation 'dense_11/kernel/read' type=Identity>,
#  <tf.Operation 'dense_11/bias' type=Const>,
#  <tf.Operation 'dense_11/bias/read' type=Identity>,
#  <tf.Operation 'dense_11/MatMul' type=MatMul>,
#  <tf.Operation 'dense_11/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_11/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_11/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_11/beta' type=Const>,
#  <tf.Operation 'batch_normalization_11/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_11/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_11/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_11/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_11/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_11/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_11/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_11/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_11/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_11/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_11/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_11/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_11/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_11/Relu' type=Relu>,
#  <tf.Operation 'dropout_11/Identity' type=Identity>,
#  <tf.Operation 'dense_12/kernel' type=Const>,
#  <tf.Operation 'dense_12/kernel/read' type=Identity>,
#  <tf.Operation 'dense_12/bias' type=Const>,
#  <tf.Operation 'dense_12/bias/read' type=Identity>,
#  <tf.Operation 'dense_12/MatMul' type=MatMul>,
#  <tf.Operation 'dense_12/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_12/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_12/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_12/beta' type=Const>,
#  <tf.Operation 'batch_normalization_12/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_12/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_12/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_12/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_12/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_12/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_12/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_12/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_12/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_12/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_12/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_12/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_12/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_12/Relu' type=Relu>,
#  <tf.Operation 'dropout_12/Identity' type=Identity>,
#  <tf.Operation 'dense_13/kernel' type=Const>,
#  <tf.Operation 'dense_13/kernel/read' type=Identity>,
#  <tf.Operation 'dense_13/bias' type=Const>,
#  <tf.Operation 'dense_13/bias/read' type=Identity>,
#  <tf.Operation 'dense_13/MatMul' type=MatMul>,
#  <tf.Operation 'dense_13/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_13/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_13/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_13/beta' type=Const>,
#  <tf.Operation 'batch_normalization_13/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_13/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_13/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_13/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_13/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_13/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_13/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_13/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_13/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_13/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_13/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_13/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_13/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_13/Relu' type=Relu>,
#  <tf.Operation 'dropout_13/Identity' type=Identity>,
#  <tf.Operation 'dense_14/kernel' type=Const>,
#  <tf.Operation 'dense_14/kernel/read' type=Identity>,
#  <tf.Operation 'dense_14/bias' type=Const>,
#  <tf.Operation 'dense_14/bias/read' type=Identity>,
#  <tf.Operation 'dense_14/MatMul' type=MatMul>,
#  <tf.Operation 'dense_14/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_14/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_14/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_14/beta' type=Const>,
#  <tf.Operation 'batch_normalization_14/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_14/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_14/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_14/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_14/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_14/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_14/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_14/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_14/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_14/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_14/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_14/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_14/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_14/Relu' type=Relu>,
#  <tf.Operation 'dropout_14/Identity' type=Identity>,
#  <tf.Operation 'dense_15/kernel' type=Const>,
#  <tf.Operation 'dense_15/kernel/read' type=Identity>,
#  <tf.Operation 'dense_15/bias' type=Const>,
#  <tf.Operation 'dense_15/bias/read' type=Identity>,
#  <tf.Operation 'dense_15/MatMul' type=MatMul>,
#  <tf.Operation 'dense_15/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_15/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_15/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_15/beta' type=Const>,
#  <tf.Operation 'batch_normalization_15/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_15/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_15/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_15/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_15/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_15/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_15/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_15/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_15/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_15/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_15/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_15/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_15/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_15/Relu' type=Relu>,
#  <tf.Operation 'dropout_15/Identity' type=Identity>,
#  <tf.Operation 'dense_16/kernel' type=Const>,
#  <tf.Operation 'dense_16/kernel/read' type=Identity>,
#  <tf.Operation 'dense_16/bias' type=Const>,
#  <tf.Operation 'dense_16/bias/read' type=Identity>,
#  <tf.Operation 'dense_16/MatMul' type=MatMul>,
#  <tf.Operation 'dense_16/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_16/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_16/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_16/beta' type=Const>,
#  <tf.Operation 'batch_normalization_16/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_16/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_16/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_16/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_16/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_16/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_16/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_16/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_16/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_16/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_16/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_16/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_16/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_16/Relu' type=Relu>,
#  <tf.Operation 'dropout_16/Identity' type=Identity>,
#  <tf.Operation 'dense_17/kernel' type=Const>,
#  <tf.Operation 'dense_17/kernel/read' type=Identity>,
#  <tf.Operation 'dense_17/bias' type=Const>,
#  <tf.Operation 'dense_17/bias/read' type=Identity>,
#  <tf.Operation 'dense_17/MatMul' type=MatMul>,
#  <tf.Operation 'dense_17/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_17/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_17/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_17/beta' type=Const>,
#  <tf.Operation 'batch_normalization_17/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_17/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_17/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_17/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_17/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_17/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_17/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_17/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_17/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_17/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_17/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_17/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_17/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_17/Relu' type=Relu>,
#  <tf.Operation 'dropout_17/Identity' type=Identity>,
#  <tf.Operation 'dense_18/kernel' type=Const>,
#  <tf.Operation 'dense_18/kernel/read' type=Identity>,
#  <tf.Operation 'dense_18/bias' type=Const>,
#  <tf.Operation 'dense_18/bias/read' type=Identity>,
#  <tf.Operation 'dense_18/MatMul' type=MatMul>,
#  <tf.Operation 'dense_18/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_18/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_18/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_18/beta' type=Const>,
#  <tf.Operation 'batch_normalization_18/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_18/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_18/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_18/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_18/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_18/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_18/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_18/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_18/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_18/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_18/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_18/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_18/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_18/Relu' type=Relu>,
#  <tf.Operation 'dropout_18/Identity' type=Identity>,
#  <tf.Operation 'dense_19/kernel' type=Const>,
#  <tf.Operation 'dense_19/kernel/read' type=Identity>,
#  <tf.Operation 'dense_19/bias' type=Const>,
#  <tf.Operation 'dense_19/bias/read' type=Identity>,
#  <tf.Operation 'dense_19/MatMul' type=MatMul>,
#  <tf.Operation 'dense_19/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_19/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_19/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_19/beta' type=Const>,
#  <tf.Operation 'batch_normalization_19/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_19/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_19/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_19/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_19/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_19/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_19/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_19/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_19/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_19/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_19/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_19/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_19/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_19/Relu' type=Relu>,
#  <tf.Operation 'dropout_19/Identity' type=Identity>,
#  <tf.Operation 'dense_20/kernel' type=Const>,
#  <tf.Operation 'dense_20/kernel/read' type=Identity>,
#  <tf.Operation 'dense_20/bias' type=Const>,
#  <tf.Operation 'dense_20/bias/read' type=Identity>,
#  <tf.Operation 'dense_20/MatMul' type=MatMul>,
#  <tf.Operation 'dense_20/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_20/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_20/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_20/beta' type=Const>,
#  <tf.Operation 'batch_normalization_20/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_20/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_20/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_20/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_20/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_20/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_20/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_20/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_20/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_20/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_20/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_20/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_20/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_20/Relu' type=Relu>,
#  <tf.Operation 'dropout_20/Identity' type=Identity>,
#  <tf.Operation 'dense_21/kernel' type=Const>,
#  <tf.Operation 'dense_21/kernel/read' type=Identity>,
#  <tf.Operation 'dense_21/bias' type=Const>,
#  <tf.Operation 'dense_21/bias/read' type=Identity>,
#  <tf.Operation 'dense_21/MatMul' type=MatMul>,
#  <tf.Operation 'dense_21/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'batch_normalization_21/gamma' type=Const>,
#  <tf.Operation 'batch_normalization_21/gamma/read' type=Identity>,
#  <tf.Operation 'batch_normalization_21/beta' type=Const>,
#  <tf.Operation 'batch_normalization_21/beta/read' type=Identity>,
#  <tf.Operation 'batch_normalization_21/moving_mean' type=Const>,
#  <tf.Operation 'batch_normalization_21/moving_mean/read' type=Identity>,
#  <tf.Operation 'batch_normalization_21/moving_variance' type=Const>,
#  <tf.Operation 'batch_normalization_21/moving_variance/read' type=Identity>,
#  <tf.Operation 'batch_normalization_21/batchnorm_1/add/y' type=Const>,
#  <tf.Operation 'batch_normalization_21/batchnorm_1/add' type=Add>,
#  <tf.Operation 'batch_normalization_21/batchnorm_1/Rsqrt' type=Rsqrt>,
#  <tf.Operation 'batch_normalization_21/batchnorm_1/mul' type=Mul>,
#  <tf.Operation 'batch_normalization_21/batchnorm_1/mul_1' type=Mul>,
#  <tf.Operation 'batch_normalization_21/batchnorm_1/mul_2' type=Mul>,
#  <tf.Operation 'batch_normalization_21/batchnorm_1/sub' type=Sub>,
#  <tf.Operation 'batch_normalization_21/batchnorm_1/add_1' type=Add>,
#  <tf.Operation 'activation_21/Relu' type=Relu>,
#  <tf.Operation 'dropout_21/Identity' type=Identity>,
#  <tf.Operation 'dense_22/kernel' type=Const>,
#  <tf.Operation 'dense_22/kernel/read' type=Identity>,
#  <tf.Operation 'dense_22/bias' type=Const>,
#  <tf.Operation 'dense_22/bias/read' type=Identity>,
#  <tf.Operation 'dense_22/MatMul' type=MatMul>,
#  <tf.Operation 'dense_22/BiasAdd' type=BiasAdd>,
#  <tf.Operation 'activation_22/Softmax' type=Softmax>,
#  <tf.Operation 'output_node0' type=Identity>,
#  <tf.Operation 'strided_slice/stack' type=Const>,
#  <tf.Operation 'strided_slice/stack_1' type=Const>,
#  <tf.Operation 'strided_slice/stack_2' type=Const>,
#  <tf.Operation 'strided_slice' type=StridedSlice>,
#  <tf.Operation 'strided_slice_1/stack' type=Const>,
#  <tf.Operation 'strided_slice_1/stack_1' type=Const>,
#  <tf.Operation 'strided_slice_1/stack_2' type=Const>,
#  <tf.Operation 'strided_slice_1' type=StridedSlice>,
#  <tf.Operation 'strided_slice_2/stack' type=Const>,
#  <tf.Operation 'strided_slice_2/stack_1' type=Const>,
#  <tf.Operation 'strided_slice_2/stack_2' type=Const>,
#  <tf.Operation 'strided_slice_2' type=StridedSlice>,
#  <tf.Operation 'Reshape/tensor' type=Pack>,
#  <tf.Operation 'Reshape/shape' type=Const>,
#  <tf.Operation 'Reshape' type=Reshape>,
#  <tf.Operation 'Reshape_1/tensor' type=Pack>,
#  <tf.Operation 'Reshape_1/shape' type=Const>,
#  <tf.Operation 'Reshape_1' type=Reshape>,
#  <tf.Operation 'Reshape_2/tensor' type=Pack>,
#  <tf.Operation 'Reshape_2/shape' type=Const>,
#  <tf.Operation 'Reshape_2' type=Reshape>,
#  <tf.Operation 'Reshape_3/tensor' type=Pack>,
#  <tf.Operation 'Reshape_3/shape' type=Const>,
#  <tf.Operation 'Reshape_3' type=Reshape>,
#  <tf.Operation 'Reshape_4/tensor' type=Pack>,
#  <tf.Operation 'Reshape_4/shape' type=Const>,
#  <tf.Operation 'Reshape_4' type=Reshape>,
#  <tf.Operation 'Reshape_5/tensor' type=Pack>,
#  <tf.Operation 'Reshape_5/shape' type=Const>,
#  <tf.Operation 'Reshape_5' type=Reshape>,
#  <tf.Operation 'Reshape_6/tensor' type=Pack>,
#  <tf.Operation 'Reshape_6/shape' type=Const>,
#  <tf.Operation 'Reshape_6' type=Reshape>,
#  <tf.Operation 'Reshape_7/tensor' type=Pack>,
#  <tf.Operation 'Reshape_7/shape' type=Const>,
#  <tf.Operation 'Reshape_7' type=Reshape>,
#  <tf.Operation 'Reshape_8/tensor' type=Pack>,
#  <tf.Operation 'Reshape_8/shape' type=Const>,
#  <tf.Operation 'Reshape_8' type=Reshape>,
#  <tf.Operation 'Reshape_9/tensor' type=Pack>,
#  <tf.Operation 'Reshape_9/shape' type=Const>,
#  <tf.Operation 'Reshape_9' type=Reshape>,
#  <tf.Operation 'Reshape_10/tensor' type=Pack>,
#  <tf.Operation 'Reshape_10/shape' type=Const>,
#  <tf.Operation 'Reshape_10' type=Reshape>,
#  <tf.Operation 'Reshape_11/tensor' type=Pack>,
#  <tf.Operation 'Reshape_11/shape' type=Const>,
#  <tf.Operation 'Reshape_11' type=Reshape>,
#  <tf.Operation 'Reshape_12/tensor' type=Pack>,
#  <tf.Operation 'Reshape_12/shape' type=Const>,
#  <tf.Operation 'Reshape_12' type=Reshape>,
#  <tf.Operation 'Reshape_13/tensor' type=Pack>,
#  <tf.Operation 'Reshape_13/shape' type=Const>,
#  <tf.Operation 'Reshape_13' type=Reshape>,
#  <tf.Operation 'Reshape_14/tensor' type=Pack>,
#  <tf.Operation 'Reshape_14/shape' type=Const>,
#  <tf.Operation 'Reshape_14' type=Reshape>,
#  <tf.Operation 'Reshape_15/tensor' type=Pack>,
#  <tf.Operation 'Reshape_15/shape' type=Const>,
#  <tf.Operation 'Reshape_15' type=Reshape>,
#  <tf.Operation 'Reshape_16/tensor' type=Pack>,
#  <tf.Operation 'Reshape_16/shape' type=Const>,
#  <tf.Operation 'Reshape_16' type=Reshape>,
#  <tf.Operation 'Reshape_17/tensor' type=Pack>,
#  <tf.Operation 'Reshape_17/shape' type=Const>,
#  <tf.Operation 'Reshape_17' type=Reshape>,
#  <tf.Operation 'Reshape_18/tensor' type=Pack>,
#  <tf.Operation 'Reshape_18/shape' type=Const>,
#  <tf.Operation 'Reshape_18' type=Reshape>,
#  <tf.Operation 'Reshape_19/tensor' type=Pack>,
#  <tf.Operation 'Reshape_19/shape' type=Const>,
#  <tf.Operation 'Reshape_19' type=Reshape>,
#  <tf.Operation 'Reshape_20/tensor' type=Pack>,
#  <tf.Operation 'Reshape_20/shape' type=Const>,
#  <tf.Operation 'Reshape_20' type=Reshape>,
#  <tf.Operation 'Reshape_21/tensor' type=Pack>,
#  <tf.Operation 'Reshape_21/shape' type=Const>,
#  <tf.Operation 'Reshape_21' type=Reshape>]

# %%
w = sess.run(tf.reshape(graph.get_operation_by_name('dense_1/kernel').values(), [-1]))

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.hist(w, bins=20)
plt.yscale('log')

# %%
# Out:
# -1.1419796
