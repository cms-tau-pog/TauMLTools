# %%
import sys
import keras
from keras import backend as K
import tensorflow as tf
import numpy as np
sys.path.insert(0, "../../python")
from common import *

# %%
model = LoadModel('../../../../output/networks/2017v2p2/DeepTau2017v2p2_step1_historic_1.0h.h5')

# %%
# !ls ../../../../output/networks/2017v2p2/p2_try2.h5
# Out:
# DeepTau2017v2p2_step1_final.hdf5 p2_try1.pb
# DeepTau2017v2p2_step1_final.pb   p2_try2.h5
# p2_try1.h5

# %%
sess = K.get_session()

# %%
n = 0
for layer in model.layers:
    for weight in layer.weights:
        w = sess.run(tf.reshape(weight.value(), [-1]))
        has_nans = np.any(np.isnan(w))
        amin = np.amin(w)
        amax = np.amax(w)
        print("{:<30}{:<45}{:<10}{:<15.5f}{:<15.5f}".format(layer.name, weight.name, str(has_nans), amin, amax))
        
    n += 1
# Out:
# input_inner_pfCand_norm       input_inner_pfCand_norm/gamma:0         False     0.81909        1.28226
# input_inner_pfCand_norm       input_inner_pfCand_norm/beta:0          False     -0.01210       0.01037
# input_inner_pfCand_norm       input_inner_pfCand_norm/moving_mean:0   False     -4.78350       2.48810
# input_inner_pfCand_norm       input_inner_pfCand_norm/moving_variance:0False     0.00011        4781.91455
# input_inner_ele_norm          input_inner_ele_norm/gamma:0            False     0.90220        1.09197
# input_inner_ele_norm          input_inner_ele_norm/beta:0             False     -0.01066       0.00757
# input_inner_ele_norm          input_inner_ele_norm/moving_mean:0      False     -0.00640       2.48810
# input_inner_ele_norm          input_inner_ele_norm/moving_variance:0  False     0.00000        1084.20435
# input_inner_muon_norm         input_inner_muon_norm/gamma:0           False     0.85583        1.15703
# input_inner_muon_norm         input_inner_muon_norm/beta:0            False     -0.00781       0.00909
# input_inner_muon_norm         input_inner_muon_norm/moving_mean:0     False     -0.31644       2.48810
# input_inner_muon_norm         input_inner_muon_norm/moving_variance:0 False     0.00000        871630.37500
# inner_pfCand_conv_1           inner_pfCand_conv_1_3/kernel:0          False     -0.56054       0.59992
# inner_pfCand_conv_1           inner_pfCand_conv_1_3/bias:0            False     -0.01061       0.01215
# inner_ele_conv_1              inner_ele_conv_1_3/kernel:0             False     -0.52357       0.49876
# inner_ele_conv_1              inner_ele_conv_1_3/bias:0               False     -0.00872       0.00914
# inner_muon_conv_1             inner_muon_conv_1_3/kernel:0            False     -0.56759       0.54879
# inner_muon_conv_1             inner_muon_conv_1_3/bias:0              False     -0.00812       0.00978
# inner_pfCand_norm_1           inner_pfCand_norm_1_1/gamma:0           False     0.85190        1.17288
# inner_pfCand_norm_1           inner_pfCand_norm_1_1/beta:0            False     -0.14018       0.10837
# inner_pfCand_norm_1           inner_pfCand_norm_1_1/moving_mean:0     False     -0.02425       0.01788
# inner_pfCand_norm_1           inner_pfCand_norm_1_1/moving_variance:0 False     0.73706        6.32155
# inner_ele_norm_1              inner_ele_norm_1_1/gamma:0              False     0.88199        1.27826
# inner_ele_norm_1              inner_ele_norm_1_1/beta:0               False     -0.16326       0.12580
# inner_ele_norm_1              inner_ele_norm_1_1/moving_mean:0        False     -0.01590       0.01689
# inner_ele_norm_1              inner_ele_norm_1_1/moving_variance:0    False     0.52794        9.57571
# inner_muon_norm_1             inner_muon_norm_1_1/gamma:0             False     0.91733        1.15386
# inner_muon_norm_1             inner_muon_norm_1_1/beta:0              False     -0.08917       0.08358
# inner_muon_norm_1             inner_muon_norm_1_1/moving_mean:0       False     -0.01300       0.02350
# inner_muon_norm_1             inner_muon_norm_1_1/moving_variance:0   False     0.44610        6.68945
# inner_pfCand_conv_2           inner_pfCand_conv_2_3/kernel:0          False     -0.39953       0.38511
# inner_pfCand_conv_2           inner_pfCand_conv_2_3/bias:0            False     -0.00376       0.00407
# inner_ele_conv_2              inner_ele_conv_2_3/kernel:0             False     -0.34294       0.38628
# inner_ele_conv_2              inner_ele_conv_2_3/bias:0               False     -0.00412       0.00316
# inner_muon_conv_2             inner_muon_conv_2_3/kernel:0            False     -0.35459       0.42013
# inner_muon_conv_2             inner_muon_conv_2_3/bias:0              False     -0.00254       0.00348
# inner_pfCand_norm_2           inner_pfCand_norm_2_1/gamma:0           False     0.88946        1.28202
# inner_pfCand_norm_2           inner_pfCand_norm_2_1/beta:0            False     -0.10191       0.08583
# inner_pfCand_norm_2           inner_pfCand_norm_2_1/moving_mean:0     False     -0.45459       0.39681
# inner_pfCand_norm_2           inner_pfCand_norm_2_1/moving_variance:0 False     0.97308        11.78701
# inner_ele_norm_2              inner_ele_norm_2_1/gamma:0              False     0.93612        1.20670
# inner_ele_norm_2              inner_ele_norm_2_1/beta:0               False     -0.09461       0.08116
# inner_ele_norm_2              inner_ele_norm_2_1/moving_mean:0        False     -0.20325       0.24444
# inner_ele_norm_2              inner_ele_norm_2_1/moving_variance:0    False     1.05266        8.72641
# inner_muon_norm_2             inner_muon_norm_2_1/gamma:0             False     0.93141        1.15781
# inner_muon_norm_2             inner_muon_norm_2_1/beta:0              False     -0.07937       0.11660
# inner_muon_norm_2             inner_muon_norm_2_1/moving_mean:0       False     -0.17701       0.19418
# inner_muon_norm_2             inner_muon_norm_2_1/moving_variance:0   False     1.07130        11.95794
# inner_pfCand_conv_3           inner_pfCand_conv_3_3/kernel:0          False     -0.36724       0.42323
# inner_pfCand_conv_3           inner_pfCand_conv_3_3/bias:0            False     -0.00318       0.00301
# inner_ele_conv_3              inner_ele_conv_3_3/kernel:0             False     -0.36142       0.44995
# inner_ele_conv_3              inner_ele_conv_3_3/bias:0               False     -0.00247       0.00214
# inner_muon_conv_3             inner_muon_conv_3_3/kernel:0            False     -0.35316       0.41946
# inner_muon_conv_3             inner_muon_conv_3_3/bias:0              False     -0.00269       0.00287
# inner_pfCand_norm_3           inner_pfCand_norm_3_1/gamma:0           False     0.91419        1.30205
# inner_pfCand_norm_3           inner_pfCand_norm_3_1/beta:0            False     -0.11751       0.09896
# inner_pfCand_norm_3           inner_pfCand_norm_3_1/moving_mean:0     False     -0.36135       0.42910
# inner_pfCand_norm_3           inner_pfCand_norm_3_1/moving_variance:0 False     1.32465        11.94118
# inner_ele_norm_3              inner_ele_norm_3_1/gamma:0              False     0.90794        1.18882
# inner_ele_norm_3              inner_ele_norm_3_1/beta:0               False     -0.08207       0.12015
# inner_ele_norm_3              inner_ele_norm_3_1/moving_mean:0        False     -0.19542       0.14592
# inner_ele_norm_3              inner_ele_norm_3_1/moving_variance:0    False     0.78001        7.63694
# inner_muon_norm_3             inner_muon_norm_3_1/gamma:0             False     0.90568        1.13296
# inner_muon_norm_3             inner_muon_norm_3_1/beta:0              False     -0.11172       0.12011
# inner_muon_norm_3             inner_muon_norm_3_1/moving_mean:0       False     -0.25317       0.18978
# inner_muon_norm_3             inner_muon_norm_3_1/moving_variance:0   False     0.98063        15.13184
# input_outer_pfCand_norm       input_outer_pfCand_norm/gamma:0         False     0.89132        1.21606
# input_outer_pfCand_norm       input_outer_pfCand_norm/beta:0          False     -0.01184       0.01083
# input_outer_pfCand_norm       input_outer_pfCand_norm/moving_mean:0   False     -57.30127      19.51199
# input_outer_pfCand_norm       input_outer_pfCand_norm/moving_variance:0False     0.00031        54121.14062
# input_outer_ele_norm          input_outer_ele_norm/gamma:0            False     0.83632        1.21368
# input_outer_ele_norm          input_outer_ele_norm/beta:0             False     -0.00628       0.00660
# input_outer_ele_norm          input_outer_ele_norm/moving_mean:0      False     -0.02452       19.51199
# input_outer_ele_norm          input_outer_ele_norm/moving_variance:0  False     0.00000        7666.81055
# input_outer_muon_norm         input_outer_muon_norm/gamma:0           False     0.87370        1.33639
# input_outer_muon_norm         input_outer_muon_norm/beta:0            False     -0.00804       0.00577
# input_outer_muon_norm         input_outer_muon_norm/moving_mean:0     False     -0.87007       19.51199
# input_outer_muon_norm         input_outer_muon_norm/moving_variance:0 False     0.00001        2276953.75000
# inner_pfCand_conv_4           inner_pfCand_conv_4_3/kernel:0          False     -0.38745       0.49436
# inner_pfCand_conv_4           inner_pfCand_conv_4_3/bias:0            False     -0.00287       0.00227
# inner_ele_conv_4              inner_ele_conv_4_3/kernel:0             False     -0.45496       0.44031
# inner_ele_conv_4              inner_ele_conv_4_3/bias:0               False     -0.00261       0.00151
# inner_muon_conv_4             inner_muon_conv_4_3/kernel:0            False     -0.38103       0.41536
# inner_muon_conv_4             inner_muon_conv_4_3/bias:0              False     -0.00413       0.00316
# outer_pfCand_conv_1           outer_pfCand_conv_1_3/kernel:0          False     -0.50467       0.70670
# outer_pfCand_conv_1           outer_pfCand_conv_1_3/bias:0            False     -0.00510       0.00661
# outer_ele_conv_1              outer_ele_conv_1_3/kernel:0             False     -0.54642       0.55471
# outer_ele_conv_1              outer_ele_conv_1_3/bias:0               False     -0.00630       0.00427
# outer_muon_conv_1             outer_muon_conv_1_3/kernel:0            False     -0.53670       0.66531
# outer_muon_conv_1             outer_muon_conv_1_3/bias:0              False     -0.00414       0.00535
# inner_pfCand_norm_4           inner_pfCand_norm_4_1/gamma:0           False     0.89685        1.14576
# inner_pfCand_norm_4           inner_pfCand_norm_4_1/beta:0            False     -0.09963       0.06242
# inner_pfCand_norm_4           inner_pfCand_norm_4_1/moving_mean:0     False     -0.37417       0.30762
# inner_pfCand_norm_4           inner_pfCand_norm_4_1/moving_variance:0 False     0.83610        9.44690
# inner_ele_norm_4              inner_ele_norm_4_1/gamma:0              False     0.90790        1.09713
# inner_ele_norm_4              inner_ele_norm_4_1/beta:0               False     -0.09571       0.10616
# inner_ele_norm_4              inner_ele_norm_4_1/moving_mean:0        False     -0.19913       0.20324
# inner_ele_norm_4              inner_ele_norm_4_1/moving_variance:0    False     0.93176        9.76718
# inner_muon_norm_4             inner_muon_norm_4_1/gamma:0             False     0.91292        1.10610
# inner_muon_norm_4             inner_muon_norm_4_1/beta:0              False     -0.10430       0.08568
# inner_muon_norm_4             inner_muon_norm_4_1/moving_mean:0       False     -0.11440       0.22456
# inner_muon_norm_4             inner_muon_norm_4_1/moving_variance:0   False     0.65852        5.99477
# outer_pfCand_norm_1           outer_pfCand_norm_1_1/gamma:0           False     0.89418        1.19619
# outer_pfCand_norm_1           outer_pfCand_norm_1_1/beta:0            False     -0.09127       0.09513
# outer_pfCand_norm_1           outer_pfCand_norm_1_1/moving_mean:0     False     -0.01627       0.02398
# outer_pfCand_norm_1           outer_pfCand_norm_1_1/moving_variance:0 False     0.59763        4.23722
# outer_ele_norm_1              outer_ele_norm_1_1/gamma:0              False     0.85943        1.19128
# outer_ele_norm_1              outer_ele_norm_1_1/beta:0               False     -0.11426       0.11487
# outer_ele_norm_1              outer_ele_norm_1_1/moving_mean:0        False     -0.01079       0.01350
# outer_ele_norm_1              outer_ele_norm_1_1/moving_variance:0    False     0.64029        7.18846
# outer_muon_norm_1             outer_muon_norm_1_1/gamma:0             False     0.85183        1.23612
# outer_muon_norm_1             outer_muon_norm_1_1/beta:0              False     -0.16553       0.09120
# outer_muon_norm_1             outer_muon_norm_1_1/moving_mean:0       False     -0.01489       0.01406
# outer_muon_norm_1             outer_muon_norm_1_1/moving_variance:0   False     0.58483        11.82697
# inner_pfCand_conv_5           inner_pfCand_conv_5_2/kernel:0          False     -0.46275       0.45580
# inner_pfCand_conv_5           inner_pfCand_conv_5_2/bias:0            False     -0.00307       0.00366
# inner_ele_conv_5              inner_ele_conv_5_2/kernel:0             False     -0.43629       0.44949
# inner_ele_conv_5              inner_ele_conv_5_2/bias:0               False     -0.00305       0.00294
# inner_muon_conv_5             inner_muon_conv_5_2/kernel:0            False     -0.45688       0.43737
# inner_muon_conv_5             inner_muon_conv_5_2/bias:0              False     -0.00333       0.00268
# outer_pfCand_conv_2           outer_pfCand_conv_2_3/kernel:0          False     -0.37801       0.42080
# outer_pfCand_conv_2           outer_pfCand_conv_2_3/bias:0            False     -0.00436       0.00223
# outer_ele_conv_2              outer_ele_conv_2_3/kernel:0             False     -0.33801       0.41282
# outer_ele_conv_2              outer_ele_conv_2_3/bias:0               False     -0.00298       0.00414
# outer_muon_conv_2             outer_muon_conv_2_3/kernel:0            False     -0.45598       0.39872
# outer_muon_conv_2             outer_muon_conv_2_3/bias:0              False     -0.00196       0.00239
# inner_pfCand_norm_5           inner_pfCand_norm_5_1/gamma:0           False     0.89656        1.16941
# inner_pfCand_norm_5           inner_pfCand_norm_5_1/beta:0            False     -0.12183       0.06632
# inner_pfCand_norm_5           inner_pfCand_norm_5_1/moving_mean:0     False     -0.24260       0.23315
# inner_pfCand_norm_5           inner_pfCand_norm_5_1/moving_variance:0 False     0.80395        11.01727
# inner_ele_norm_5              inner_ele_norm_5_1/gamma:0              False     0.92960        1.11370
# inner_ele_norm_5              inner_ele_norm_5_1/beta:0               False     -0.09740       0.08851
# inner_ele_norm_5              inner_ele_norm_5_1/moving_mean:0        False     -0.18315       0.18302
# inner_ele_norm_5              inner_ele_norm_5_1/moving_variance:0    False     0.82745        8.43676
# inner_muon_norm_5             inner_muon_norm_5_1/gamma:0             False     0.90210        1.09254
# inner_muon_norm_5             inner_muon_norm_5_1/beta:0              False     -0.14129       0.08042
# inner_muon_norm_5             inner_muon_norm_5_1/moving_mean:0       False     -0.12865       0.15806
# inner_muon_norm_5             inner_muon_norm_5_1/moving_variance:0   False     0.89064        7.43060
# outer_pfCand_norm_2           outer_pfCand_norm_2_1/gamma:0           False     0.89992        1.13200
# outer_pfCand_norm_2           outer_pfCand_norm_2_1/beta:0            False     -0.08622       0.08540
# outer_pfCand_norm_2           outer_pfCand_norm_2_1/moving_mean:0     False     -0.94173       0.93149
# outer_pfCand_norm_2           outer_pfCand_norm_2_1/moving_variance:0 False     0.91359        8.04719
# outer_ele_norm_2              outer_ele_norm_2_1/gamma:0              False     0.89474        1.14648
# outer_ele_norm_2              outer_ele_norm_2_1/beta:0               False     -0.08746       0.10837
# outer_ele_norm_2              outer_ele_norm_2_1/moving_mean:0        False     -0.42593       0.51116
# outer_ele_norm_2              outer_ele_norm_2_1/moving_variance:0    False     1.07294        6.57778
# outer_muon_norm_2             outer_muon_norm_2_1/gamma:0             False     0.85762        1.29540
# outer_muon_norm_2             outer_muon_norm_2_1/beta:0              False     -0.11383       0.09470
# outer_muon_norm_2             outer_muon_norm_2_1/moving_mean:0       False     -0.44069       0.52535
# outer_muon_norm_2             outer_muon_norm_2_1/moving_variance:0   False     1.13578        14.24145
# inner_pfCand_conv_6           inner_pfCand_conv_6_2/kernel:0          False     -0.47243       0.54779
# inner_pfCand_conv_6           inner_pfCand_conv_6_2/bias:0            False     -0.00289       0.00527
# inner_ele_conv_6              inner_ele_conv_6_2/kernel:0             False     -0.50458       0.49316
# inner_ele_conv_6              inner_ele_conv_6_2/bias:0               False     -0.00213       0.00224
# inner_muon_conv_6             inner_muon_conv_6_2/kernel:0            False     -0.50099       0.56611
# inner_muon_conv_6             inner_muon_conv_6_2/bias:0              False     -0.00317       0.00230
# outer_pfCand_conv_3           outer_pfCand_conv_3_3/kernel:0          False     -0.38423       0.41692
# outer_pfCand_conv_3           outer_pfCand_conv_3_3/bias:0            False     -0.00279       0.00311
# outer_ele_conv_3              outer_ele_conv_3_3/kernel:0             False     -0.35485       0.41777
# outer_ele_conv_3              outer_ele_conv_3_3/bias:0               False     -0.00305       0.00191
# outer_muon_conv_3             outer_muon_conv_3_3/kernel:0            False     -0.39484       0.41272
# outer_muon_conv_3             outer_muon_conv_3_3/bias:0              False     -0.00168       0.00327
# inner_pfCand_norm_6           inner_pfCand_norm_6_1/gamma:0           False     0.95761        1.07362
# inner_pfCand_norm_6           inner_pfCand_norm_6_1/beta:0            False     -0.09491       0.07806
# inner_pfCand_norm_6           inner_pfCand_norm_6_1/moving_mean:0     False     -0.23478       0.24932
# inner_pfCand_norm_6           inner_pfCand_norm_6_1/moving_variance:0 False     0.88437        9.86551
# inner_ele_norm_6              inner_ele_norm_6_1/gamma:0              False     0.92559        1.06488
# inner_ele_norm_6              inner_ele_norm_6_1/beta:0               False     -0.11775       0.08152
# inner_ele_norm_6              inner_ele_norm_6_1/moving_mean:0        False     -0.13244       0.11614
# inner_ele_norm_6              inner_ele_norm_6_1/moving_variance:0    False     0.80114        3.42948
# inner_muon_norm_6             inner_muon_norm_6_1/gamma:0             False     0.90868        1.08577
# inner_muon_norm_6             inner_muon_norm_6_1/beta:0              False     -0.07880       0.05311
# inner_muon_norm_6             inner_muon_norm_6_1/moving_mean:0       False     -0.13317       0.07874
# inner_muon_norm_6             inner_muon_norm_6_1/moving_variance:0   False     0.57763        4.88761
# outer_pfCand_norm_3           outer_pfCand_norm_3_1/gamma:0           False     0.90675        1.13463
# outer_pfCand_norm_3           outer_pfCand_norm_3_1/beta:0            False     -0.09236       0.12215
# outer_pfCand_norm_3           outer_pfCand_norm_3_1/moving_mean:0     False     -1.02609       0.85639
# outer_pfCand_norm_3           outer_pfCand_norm_3_1/moving_variance:0 False     1.08942        10.53831
# outer_ele_norm_3              outer_ele_norm_3_1/gamma:0              False     0.91198        1.19533
# outer_ele_norm_3              outer_ele_norm_3_1/beta:0               False     -0.08791       0.11858
# outer_ele_norm_3              outer_ele_norm_3_1/moving_mean:0        False     -0.35920       0.32133
# outer_ele_norm_3              outer_ele_norm_3_1/moving_variance:0    False     1.23004        11.72325
# outer_muon_norm_3             outer_muon_norm_3_1/gamma:0             False     0.89919        1.17100
# outer_muon_norm_3             outer_muon_norm_3_1/beta:0              False     -0.14670       0.15374
# outer_muon_norm_3             outer_muon_norm_3_1/moving_mean:0       False     -0.50936       0.49686
# outer_muon_norm_3             outer_muon_norm_3_1/moving_variance:0   False     1.06695        15.37648
# inner_pfCand_conv_7           inner_pfCand_conv_7_2/kernel:0          False     -0.55355       0.58713
# inner_pfCand_conv_7           inner_pfCand_conv_7_2/bias:0            False     -0.00299       0.00424
# inner_ele_conv_7              inner_ele_conv_7_2/kernel:0             False     -0.57078       0.59930
# inner_ele_conv_7              inner_ele_conv_7_2/bias:0               False     -0.00313       0.00102
# inner_muon_conv_7             inner_muon_conv_7_2/kernel:0            False     -0.58343       0.57242
# inner_muon_conv_7             inner_muon_conv_7_2/bias:0              False     -0.00378       0.00399
# outer_pfCand_conv_4           outer_pfCand_conv_4_3/kernel:0          False     -0.43431       0.45884
# outer_pfCand_conv_4           outer_pfCand_conv_4_3/bias:0            False     -0.00340       0.00258
# outer_ele_conv_4              outer_ele_conv_4_3/kernel:0             False     -0.38039       0.48975
# outer_ele_conv_4              outer_ele_conv_4_3/bias:0               False     -0.00404       0.00218
# outer_muon_conv_4             outer_muon_conv_4_3/kernel:0            False     -0.45257       0.51737
# outer_muon_conv_4             outer_muon_conv_4_3/bias:0              False     -0.00261       0.00202
# inner_pfCand_norm_7           inner_pfCand_norm_7_1/gamma:0           False     0.92054        1.15908
# inner_pfCand_norm_7           inner_pfCand_norm_7_1/beta:0            False     -0.07481       0.05516
# inner_pfCand_norm_7           inner_pfCand_norm_7_1/moving_mean:0     False     -0.22758       0.25079
# inner_pfCand_norm_7           inner_pfCand_norm_7_1/moving_variance:0 False     0.85922        11.22728
# inner_ele_norm_7              inner_ele_norm_7_1/gamma:0              False     0.94894        1.18251
# inner_ele_norm_7              inner_ele_norm_7_1/beta:0               False     -0.10289       0.08874
# inner_ele_norm_7              inner_ele_norm_7_1/moving_mean:0        False     -0.13307       0.06203
# inner_ele_norm_7              inner_ele_norm_7_1/moving_variance:0    False     0.82139        5.50874
# inner_muon_norm_7             inner_muon_norm_7_1/gamma:0             False     0.90599        1.01256
# inner_muon_norm_7             inner_muon_norm_7_1/beta:0              False     -0.09025       0.07557
# inner_muon_norm_7             inner_muon_norm_7_1/moving_mean:0       False     -0.12169       0.12195
# inner_muon_norm_7             inner_muon_norm_7_1/moving_variance:0   False     0.67841        6.06383
# outer_pfCand_norm_4           outer_pfCand_norm_4_1/gamma:0           False     0.92348        1.12956
# outer_pfCand_norm_4           outer_pfCand_norm_4_1/beta:0            False     -0.07835       0.12559
# outer_pfCand_norm_4           outer_pfCand_norm_4_1/moving_mean:0     False     -1.06738       0.46076
# outer_pfCand_norm_4           outer_pfCand_norm_4_1/moving_variance:0 False     0.97582        4.96295
# outer_ele_norm_4              outer_ele_norm_4_1/gamma:0              False     0.82241        1.17914
# outer_ele_norm_4              outer_ele_norm_4_1/beta:0               False     -0.07166       0.15592
# outer_ele_norm_4              outer_ele_norm_4_1/moving_mean:0        False     -0.28722       0.29125
# outer_ele_norm_4              outer_ele_norm_4_1/moving_variance:0    False     1.42573        10.44514
# outer_muon_norm_4             outer_muon_norm_4_1/gamma:0             False     0.91228        1.15786
# outer_muon_norm_4             outer_muon_norm_4_1/beta:0              False     -0.12405       0.17218
# outer_muon_norm_4             outer_muon_norm_4_1/moving_mean:0       False     -0.41171       0.29200
# outer_muon_norm_4             outer_muon_norm_4_1/moving_variance:0   False     1.71988        13.73699
# outer_pfCand_conv_5           outer_pfCand_conv_5_2/kernel:0          False     -0.48178       0.46604
# outer_pfCand_conv_5           outer_pfCand_conv_5_2/bias:0            False     -0.00210       0.00407
# outer_ele_conv_5              outer_ele_conv_5_2/kernel:0             False     -0.44896       0.49178
# outer_ele_conv_5              outer_ele_conv_5_2/bias:0               False     -0.00369       0.00293
# outer_muon_conv_5             outer_muon_conv_5_2/kernel:0            False     -0.47411       0.49357
# outer_muon_conv_5             outer_muon_conv_5_2/bias:0              False     -0.00210       0.00292
# inner_all_conv_1              inner_all_conv_1_3/kernel:0             False     -0.42462       0.52743
# inner_all_conv_1              inner_all_conv_1_3/bias:0               False     -0.00462       0.00531
# outer_pfCand_norm_5           outer_pfCand_norm_5_1/gamma:0           False     0.88672        1.10708
# outer_pfCand_norm_5           outer_pfCand_norm_5_1/beta:0            False     -0.07336       0.12242
# outer_pfCand_norm_5           outer_pfCand_norm_5_1/moving_mean:0     False     -0.56539       0.44690
# outer_pfCand_norm_5           outer_pfCand_norm_5_1/moving_variance:0 False     0.74012        4.69504
# outer_ele_norm_5              outer_ele_norm_5_1/gamma:0              False     0.87107        1.13270
# outer_ele_norm_5              outer_ele_norm_5_1/beta:0               False     -0.09444       0.07016
# outer_ele_norm_5              outer_ele_norm_5_1/moving_mean:0        False     -0.16983       0.27240
# outer_ele_norm_5              outer_ele_norm_5_1/moving_variance:0    False     0.75585        9.76381
# outer_muon_norm_5             outer_muon_norm_5_1/gamma:0             False     0.91155        1.15577
# outer_muon_norm_5             outer_muon_norm_5_1/beta:0              False     -0.18704       0.06820
# outer_muon_norm_5             outer_muon_norm_5_1/moving_mean:0       False     -0.23283       0.30234
# outer_muon_norm_5             outer_muon_norm_5_1/moving_variance:0   False     0.78992        11.40165
# inner_all_norm_1              inner_all_norm_1_1/gamma:0              False     0.93598        1.13938
# inner_all_norm_1              inner_all_norm_1_1/beta:0               False     -0.06983       0.12802
# inner_all_norm_1              inner_all_norm_1_1/moving_mean:0        False     -0.14223       0.19964
# inner_all_norm_1              inner_all_norm_1_1/moving_variance:0    False     1.22316        4.33931
# outer_pfCand_conv_6           outer_pfCand_conv_6_2/kernel:0          False     -0.57650       0.49444
# outer_pfCand_conv_6           outer_pfCand_conv_6_2/bias:0            False     -0.00384       0.00351
# outer_ele_conv_6              outer_ele_conv_6_2/kernel:0             False     -0.49795       0.57340
# outer_ele_conv_6              outer_ele_conv_6_2/bias:0               False     -0.00304       0.00340
# outer_muon_conv_6             outer_muon_conv_6_2/kernel:0            False     -0.49771       0.51024
# outer_muon_conv_6             outer_muon_conv_6_2/bias:0              False     -0.00380       0.00302
# inner_all_4x4_conv_1          inner_all_4x4_conv_1_3/kernel:0         False     -0.22164       0.26275
# inner_all_4x4_conv_1          inner_all_4x4_conv_1_3/bias:0           False     -0.00427       0.00392
# outer_pfCand_norm_6           outer_pfCand_norm_6_1/gamma:0           False     0.88606        1.10460
# outer_pfCand_norm_6           outer_pfCand_norm_6_1/beta:0            False     -0.09695       0.12116
# outer_pfCand_norm_6           outer_pfCand_norm_6_1/moving_mean:0     False     -0.62961       0.52612
# outer_pfCand_norm_6           outer_pfCand_norm_6_1/moving_variance:0 False     0.82467        6.41594
# outer_ele_norm_6              outer_ele_norm_6_1/gamma:0              False     0.87337        1.12889
# outer_ele_norm_6              outer_ele_norm_6_1/beta:0               False     -0.13399       0.06910
# outer_ele_norm_6              outer_ele_norm_6_1/moving_mean:0        False     -0.12953       0.13299
# outer_ele_norm_6              outer_ele_norm_6_1/moving_variance:0    False     0.68128        12.97995
# outer_muon_norm_6             outer_muon_norm_6_1/gamma:0             False     0.89996        1.13189
# outer_muon_norm_6             outer_muon_norm_6_1/beta:0              False     -0.21120       0.07482
# outer_muon_norm_6             outer_muon_norm_6_1/moving_mean:0       False     -0.13855       0.18626
# outer_muon_norm_6             outer_muon_norm_6_1/moving_variance:0   False     0.66535        9.30588
# inner_all_4x4_norm_1          inner_all_4x4_norm_1_1/gamma:0          False     0.93231        1.07642
# inner_all_4x4_norm_1          inner_all_4x4_norm_1_1/beta:0           False     -0.07275       0.14902
# inner_all_4x4_norm_1          inner_all_4x4_norm_1_1/moving_mean:0    False     -0.27160       0.51910
# inner_all_4x4_norm_1          inner_all_4x4_norm_1_1/moving_variance:0False     3.69542        7.27000
# outer_pfCand_conv_7           outer_pfCand_conv_7_2/kernel:0          False     -0.61401       0.56300
# outer_pfCand_conv_7           outer_pfCand_conv_7_2/bias:0            False     -0.00306       0.00278
# outer_ele_conv_7              outer_ele_conv_7_2/kernel:0             False     -0.55681       0.58989
# outer_ele_conv_7              outer_ele_conv_7_2/bias:0               False     -0.00459       0.00498
# outer_muon_conv_7             outer_muon_conv_7_2/kernel:0            False     -0.51033       0.60885
# outer_muon_conv_7             outer_muon_conv_7_2/bias:0              False     -0.00263       0.00179
# inner_all_4x4_conv_2          inner_all_4x4_conv_2_3/kernel:0         False     -0.20924       0.23454
# inner_all_4x4_conv_2          inner_all_4x4_conv_2_3/bias:0           False     -0.00363       0.00459
# outer_pfCand_norm_7           outer_pfCand_norm_7_1/gamma:0           False     0.83994        1.01082
# outer_pfCand_norm_7           outer_pfCand_norm_7_1/beta:0            False     -0.15055       0.05162
# outer_pfCand_norm_7           outer_pfCand_norm_7_1/moving_mean:0     False     -0.43043       0.40402
# outer_pfCand_norm_7           outer_pfCand_norm_7_1/moving_variance:0 False     1.14283        3.95232
# outer_ele_norm_7              outer_ele_norm_7_1/gamma:0              False     0.91251        1.10043
# outer_ele_norm_7              outer_ele_norm_7_1/beta:0               False     -0.07072       0.06795
# outer_ele_norm_7              outer_ele_norm_7_1/moving_mean:0        False     -0.05986       0.11100
# outer_ele_norm_7              outer_ele_norm_7_1/moving_variance:0    False     0.70198        9.01639
# outer_muon_norm_7             outer_muon_norm_7_1/gamma:0             False     0.94219        1.14039
# outer_muon_norm_7             outer_muon_norm_7_1/beta:0              False     -0.13149       0.09171
# outer_muon_norm_7             outer_muon_norm_7_1/moving_mean:0       False     -0.08508       0.12035
# outer_muon_norm_7             outer_muon_norm_7_1/moving_variance:0   False     0.40697        5.66867
# inner_all_4x4_norm_2          inner_all_4x4_norm_2_1/gamma:0          False     0.93638        1.06863
# inner_all_4x4_norm_2          inner_all_4x4_norm_2_1/beta:0           False     -0.07993       0.15572
# inner_all_4x4_norm_2          inner_all_4x4_norm_2_1/moving_mean:0    False     -1.39603       0.96810
# inner_all_4x4_norm_2          inner_all_4x4_norm_2_1/moving_variance:0False     3.94200        13.45403
# inner_all_4x4_conv_3          inner_all_4x4_conv_3_3/kernel:0         False     -0.21563       0.20606
# inner_all_4x4_conv_3          inner_all_4x4_conv_3_3/bias:0           False     -0.00355       0.00387
# outer_all_conv_1              outer_all_conv_1_3/kernel:0             False     -0.45977       0.52645
# outer_all_conv_1              outer_all_conv_1_3/bias:0               False     -0.00330       0.00351
# inner_all_4x4_norm_3          inner_all_4x4_norm_3_1/gamma:0          False     0.93295        1.13780
# inner_all_4x4_norm_3          inner_all_4x4_norm_3_1/beta:0           False     -0.09078       0.14273
# inner_all_4x4_norm_3          inner_all_4x4_norm_3_1/moving_mean:0    False     -1.76302       1.40913
# inner_all_4x4_norm_3          inner_all_4x4_norm_3_1/moving_variance:0False     2.91665        11.96602
# outer_all_norm_1              outer_all_norm_1_1/gamma:0              False     0.91731        1.12058
# outer_all_norm_1              outer_all_norm_1_1/beta:0               False     -0.11533       0.04900
# outer_all_norm_1              outer_all_norm_1_1/moving_mean:0        False     -0.10754       0.25067
# outer_all_norm_1              outer_all_norm_1_1/moving_variance:0    False     0.94590        8.86022
# inner_all_4x4_conv_4          inner_all_4x4_conv_4_3/kernel:0         False     -0.25032       0.23531
# inner_all_4x4_conv_4          inner_all_4x4_conv_4_3/bias:0           False     -0.00584       0.00425
# outer_all_4x4_conv_1          outer_all_4x4_conv_1_3/kernel:0         False     -0.20671       0.28119
# outer_all_4x4_conv_1          outer_all_4x4_conv_1_3/bias:0           False     -0.00387       0.00388
# inner_all_4x4_norm_4          inner_all_4x4_norm_4_1/gamma:0          False     0.94896        1.09412
# inner_all_4x4_norm_4          inner_all_4x4_norm_4_1/beta:0           False     -0.06563       0.10624
# inner_all_4x4_norm_4          inner_all_4x4_norm_4_1/moving_mean:0    False     -2.65376       1.87105
# inner_all_4x4_norm_4          inner_all_4x4_norm_4_1/moving_variance:0False     2.79476        21.23772
# outer_all_4x4_norm_1          outer_all_4x4_norm_1_1/gamma:0          False     0.93164        1.06522
# outer_all_4x4_norm_1          outer_all_4x4_norm_1_1/beta:0           False     -0.10912       0.12303
# outer_all_4x4_norm_1          outer_all_4x4_norm_1_1/moving_mean:0    False     -0.55542       0.33139
# outer_all_4x4_norm_1          outer_all_4x4_norm_1_1/moving_variance:0False     6.89375        10.61942
# inner_all_4x4_conv_5          inner_all_4x4_conv_5_3/kernel:0         False     -0.21069       0.27850
# inner_all_4x4_conv_5          inner_all_4x4_conv_5_3/bias:0           False     -0.00630       0.00428
# outer_all_4x4_conv_2          outer_all_4x4_conv_2_3/kernel:0         False     -0.21082       0.24332
# outer_all_4x4_conv_2          outer_all_4x4_conv_2_3/bias:0           False     -0.00382       0.00370
# inner_all_4x4_norm_5          inner_all_4x4_norm_5_1/gamma:0          False     0.91124        1.08994
# inner_all_4x4_norm_5          inner_all_4x4_norm_5_1/beta:0           False     -0.09018       0.09150
# inner_all_4x4_norm_5          inner_all_4x4_norm_5_1/moving_mean:0    False     -1.92287       2.30260
# inner_all_4x4_norm_5          inner_all_4x4_norm_5_1/moving_variance:0False     2.50477        24.16366
# outer_all_4x4_norm_2          outer_all_4x4_norm_2_1/gamma:0          False     0.93100        1.05565
# outer_all_4x4_norm_2          outer_all_4x4_norm_2_1/beta:0           False     -0.07029       0.10902
# outer_all_4x4_norm_2          outer_all_4x4_norm_2_1/moving_mean:0    False     -1.84918       1.89930
# outer_all_4x4_norm_2          outer_all_4x4_norm_2_1/moving_variance:0False     5.81881        16.55035
# inner_all_4x4_conv_6          inner_all_4x4_conv_6_3/kernel:0         False     -0.22264       0.24902
# inner_all_4x4_conv_6          inner_all_4x4_conv_6_3/bias:0           False     -0.00323       0.00466
# outer_all_4x4_conv_3          outer_all_4x4_conv_3_3/kernel:0         False     -0.23106       0.24433
# outer_all_4x4_conv_3          outer_all_4x4_conv_3_3/bias:0           False     -0.00683       0.00549
# inner_all_4x4_norm_6          inner_all_4x4_norm_6_1/gamma:0          False     0.94020        1.11506
# inner_all_4x4_norm_6          inner_all_4x4_norm_6_1/beta:0           False     -0.07909       0.12462
# inner_all_4x4_norm_6          inner_all_4x4_norm_6_1/moving_mean:0    False     -2.46785       3.40510
# inner_all_4x4_norm_6          inner_all_4x4_norm_6_1/moving_variance:0False     5.17132        52.53843
# outer_all_4x4_norm_3          outer_all_4x4_norm_3_1/gamma:0          False     0.91748        1.07121
# outer_all_4x4_norm_3          outer_all_4x4_norm_3_1/beta:0           False     -0.07354       0.16832
# outer_all_4x4_norm_3          outer_all_4x4_norm_3_1/moving_mean:0    False     -3.35424       1.98564
# outer_all_4x4_norm_3          outer_all_4x4_norm_3_1/moving_variance:0False     6.75562        30.33352
# inner_all_3x3_conv_7          inner_all_3x3_conv_7_3/kernel:0         False     -0.29772       0.28259
# inner_all_3x3_conv_7          inner_all_3x3_conv_7_3/bias:0           False     -0.00396       0.00310
# outer_all_4x4_conv_4          outer_all_4x4_conv_4_3/kernel:0         False     -0.25494       0.25641
# outer_all_4x4_conv_4          outer_all_4x4_conv_4_3/bias:0           False     -0.00364       0.00309
# inner_all_3x3_norm_7          inner_all_3x3_norm_7_1/gamma:0          False     0.88874        1.01322
# inner_all_3x3_norm_7          inner_all_3x3_norm_7_1/beta:0           False     -0.13091       0.08847
# inner_all_3x3_norm_7          inner_all_3x3_norm_7_1/moving_mean:0    False     -2.88674       1.65642
# inner_all_3x3_norm_7          inner_all_3x3_norm_7_1/moving_variance:0False     3.95020        22.01974
# outer_all_4x4_norm_4          outer_all_4x4_norm_4_1/gamma:0          False     0.96280        1.13179
# outer_all_4x4_norm_4          outer_all_4x4_norm_4_1/beta:0           False     -0.06628       0.17878
# outer_all_4x4_norm_4          outer_all_4x4_norm_4_1/moving_mean:0    False     -3.31508       3.56719
# outer_all_4x4_norm_4          outer_all_4x4_norm_4_1/moving_variance:0False     5.07667        44.42422
# input_tau_norm                input_tau_norm/gamma:0                  False     0.61521        1.65496
# input_tau_norm                input_tau_norm/beta:0                   False     -0.01364       0.01397
# input_tau_norm                input_tau_norm/moving_mean:0            False     -631.46832     170.82756
# input_tau_norm                input_tau_norm/moving_variance:0        False     0.00005        232347.12500
# final_dense_1                 final_dense_1_1/kernel:0                False     -0.58101       0.48041
# final_dense_1                 final_dense_1_1/bias:0                  False     -0.00323       0.00314
# final_norm_1                  final_norm_1_1/gamma:0                  False     0.87013        1.17061
# final_norm_1                  final_norm_1_1/beta:0                   False     -0.15611       0.15021
# final_norm_1                  final_norm_1_1/moving_mean:0            False     -1.74748       1.44652
# final_norm_1                  final_norm_1_1/moving_variance:0        False     0.86607        10.67509
# final_dense_2                 final_dense_2_1/kernel:0                False     -0.30675       0.28298
# final_dense_2                 final_dense_2_1/bias:0                  False     -0.00487       0.00400
# final_norm_2                  final_norm_2_1/gamma:0                  False     0.88565        1.16072
# final_norm_2                  final_norm_2_1/beta:0                   False     -0.14705       0.13639
# final_norm_2                  final_norm_2_1/moving_mean:0            False     -5.64261       4.57812
# final_norm_2                  final_norm_2_1/moving_variance:0        False     2.16249        26.96389
# final_dense_3                 final_dense_3_1/kernel:0                False     -0.31338       0.30595
# final_dense_3                 final_dense_3_1/bias:0                  False     -0.00344       0.00326
# final_norm_3                  final_norm_3_1/gamma:0                  False     0.86753        1.15402
# final_norm_3                  final_norm_3_1/beta:0                   False     -0.14515       0.19483
# final_norm_3                  final_norm_3_1/moving_mean:0            False     -3.37849       3.20343
# final_norm_3                  final_norm_3_1/moving_variance:0        False     1.77609        31.26229
# final_dense_4                 final_dense_4_1/kernel:0                False     -0.33113       0.35749
# final_dense_4                 final_dense_4_1/bias:0                  False     -0.00483       0.00579
# final_norm_4                  final_norm_4_1/gamma:0                  False     0.88161        1.15858
# final_norm_4                  final_norm_4_1/beta:0                   False     -0.11225       0.21356
# final_norm_4                  final_norm_4_1/moving_mean:0            False     -3.17156       3.26127
# final_norm_4                  final_norm_4_1/moving_variance:0        False     1.54521        20.18744
# final_dense_5                 final_dense_5_1/kernel:0                False     -0.35930       0.35699
# final_dense_5                 final_dense_5_1/bias:0                  False     -0.00515       0.00604
# final_norm_5                  final_norm_5_1/gamma:0                  False     0.87770        1.15782
# final_norm_5                  final_norm_5_1/beta:0                   False     -0.15546       0.20794
# final_norm_5                  final_norm_5_1/moving_mean:0            False     -3.26450       2.29965
# final_norm_5                  final_norm_5_1/moving_variance:0        False     1.42902        17.05474
# final_dense_6                 final_dense_6_1/kernel:0                False     -0.37079       0.38710
# final_dense_6                 final_dense_6_1/bias:0                  False     -0.00496       0.00492
# final_norm_6                  final_norm_6_1/gamma:0                  False     0.84448        1.14692
# final_norm_6                  final_norm_6_1/beta:0                   False     -0.12610       0.20800
# final_norm_6                  final_norm_6_1/moving_mean:0            False     -1.99573       1.79150
# final_norm_6                  final_norm_6_1/moving_variance:0        False     1.02233        14.05549
# final_dense_7                 final_dense_7_1/kernel:0                False     -0.44715       0.44366
# final_dense_7                 final_dense_7_1/bias:0                  False     -0.00412       0.00551
# final_norm_7                  final_norm_7_1/gamma:0                  False     0.82877        1.17280
# final_norm_7                  final_norm_7_1/beta:0                   False     -0.10106       0.18203
# final_norm_7                  final_norm_7_1/moving_mean:0            False     -2.26035       1.05038
# final_norm_7                  final_norm_7_1/moving_variance:0        False     1.71628        13.22040
# final_dense_8                 final_dense_8_1/kernel:0                False     -0.52240       0.44674
# final_dense_8                 final_dense_8_1/bias:0                  False     -0.00428       0.00412
# final_norm_8                  final_norm_8_1/gamma:0                  False     0.86679        1.18755
# final_norm_8                  final_norm_8_1/beta:0                   False     -0.14110       0.24171
# final_norm_8                  final_norm_8_1/moving_mean:0            False     -1.51469       0.93489
# final_norm_8                  final_norm_8_1/moving_variance:0        False     1.88276        10.87925
# final_dense_9                 final_dense_9_1/kernel:0                False     -0.55454       0.50133
# final_dense_9                 final_dense_9_1/bias:0                  False     -0.00972       0.00495
# final_norm_9                  final_norm_9_1/gamma:0                  False     0.83484        1.20280
# final_norm_9                  final_norm_9_1/beta:0                   False     -0.21121       0.31182
# final_norm_9                  final_norm_9_1/moving_mean:0            False     -1.65699       0.97983
# final_norm_9                  final_norm_9_1/moving_variance:0        False     1.62018        9.56082
# final_dense_10                final_dense_10_1/kernel:0               False     -0.60490       0.65369
# final_dense_10                final_dense_10_1/bias:0                 False     -0.00525       0.00620
# final_norm_10                 final_norm_10_1/gamma:0                 False     0.82226        1.41368
# final_norm_10                 final_norm_10_1/beta:0                  False     -0.24469       0.36671
# final_norm_10                 final_norm_10_1/moving_mean:0           False     -2.12837       0.97625
# final_norm_10                 final_norm_10_1/moving_variance:0       False     1.63964        9.27242
# final_dense_11                final_dense_11_1/kernel:0               False     -0.74113       0.45278
# final_dense_11                final_dense_11_1/bias:0                 False     -0.07648       0.10930

# %%
layer = model.get_layer("outer_muon_conv_1")

# %%
layer.activation(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-c60a51a0a0b8> in <module>()
# ----> 1 layer.activation(2)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/activations.py in selu(x)
#      82     alpha = 1.6732632423543772848170429916717
#      83     scale = 1.0507009873554804934193349852946
# ---> 84     return scale * K.elu(x, alpha)
#      85
#      86
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in elu(x, alpha)
#    3211         A tensor.
#    3212     """
# -> 3213     res = tf.nn.elu(x)
#    3214     if alpha == 1:
#    3215         return res
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in elu(features, name)
#    2774   if _ctx is None or not _ctx._eager_context.is_eager:
#    2775     _, _, _op = _op_def_lib._apply_op_helper(
# -> 2776         "Elu", features=features, name=name)
#    2777     _result = _op.outputs[:]
#    2778     _inputs_flat = _op.inputs
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     607               _SatisfiesTypeConstraint(base_type,
#     608                                        _Attr(op_def, input_arg.type_attr),
# --> 609                                        param_name=input_name)
#     610             attrs[input_arg.type_attr] = attr_value
#     611             inferred_from[input_arg.type_attr] = input_name
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _SatisfiesTypeConstraint(dtype, attr_def, param_name)
#      58           "allowed values: %s" %
#      59           (param_name, dtypes.as_dtype(dtype).name,
# ---> 60            ", ".join(dtypes.as_dtype(x).name for x in allowed_list)))
#      61
#      62
#
# TypeError: Value passed to parameter 'features' has DataType int32 not in list of allowed values: float16, bfloat16, float32, float64

# %%
weight = layer.

# %%
for weight in layer.weights:
    if weight.name != 'outer_muon_conv_1/kernel:0': continue
    w = np.array(sess.run(weight.value()))
    for n in range(w.shape[2]):
        print(n, np.any(np.isnan(w[0, 0, n, :])))
#    for n in range(len(w)):
#        print(n, w[n])
#    has_nans = np.any(np.isnan(w))
#    amin = np.amin(w)
#    amax = np.amax(w)
#    print(layer.name, weight.name, has_nans, amin, amax)
# Out:
# 0 False
# 1 False
# 2 False
# 3 False
# 4 False
# 5 False
# 6 False
# 7 False
# 8 False
# 9 True
# 10 False
# 11 False
# 12 False
# 13 False
# 14 False
# 15 False
# 16 False
# 17 False
# 18 False
# 19 False
# 20 False
# 21 False
# 22 False
# 23 False
# 24 False
# 25 False
# 26 False
# 27 False
# 28 False
# 29 False
# 30 False
# 31 False
# 32 False
# 33 False
# 34 False
# 35 False
# 36 False
# 37 False
# 38 False
