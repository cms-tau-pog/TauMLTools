# %%
import sys
import tensorflow.keras as keras
from tensorflow.keras import backend as K
import tensorflow as tf
import numpy as np
sys.path.insert(0, "../../python")
from common import *

# %%
model = LoadModel('v2_diverged.h5')
# Out:
# WARNING:tensorflow:From C:\Users\konst\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\konst\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\konst\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
sess = K.get_session()

# %%
n = 0
for layer in model.layers:
    for weight in layer.weights:
        w = sess.run(tf.reshape(weight.value(), [-1]))
        has_nans = np.any(np.isnan(w))
        amin = np.amin(w)
        amax = np.amax(w)
        print("{:<30}{:<45}{:<10}{:<15.5f}{:<15.5f}".format(layer.name, weight.name, str(has_nans), amin, amax))
        
    n += 1
# Out:
# inner_cmb_conv_1              inner_cmb_conv_1/kernel:0                    False     -14.66062      15.03908
# inner_cmb_conv_1              inner_cmb_conv_1/bias:0                      False     -0.02061       0.02125
# outer_cmb_conv_1              outer_cmb_conv_1/kernel:0                    False     -11.01904      8.20389
# outer_cmb_conv_1              outer_cmb_conv_1/bias:0                      False     -0.00401       0.00364
# inner_cmb_norm_1              inner_cmb_norm_1/gamma:0                     False     -1.58425       4.71534
# inner_cmb_norm_1              inner_cmb_norm_1/beta:0                      False     -2.53390       2.94079
# inner_cmb_norm_1              inner_cmb_norm_1/moving_mean:0               False     -0.14004       0.17604
# inner_cmb_norm_1              inner_cmb_norm_1/moving_variance:0           False     0.01561        4.69807
# outer_cmb_norm_1              outer_cmb_norm_1/gamma:0                     False     -1.02011       5.78794
# outer_cmb_norm_1              outer_cmb_norm_1/beta:0                      False     -2.32760       2.18893
# outer_cmb_norm_1              outer_cmb_norm_1/moving_mean:0               False     -0.98211       0.93165
# outer_cmb_norm_1              outer_cmb_norm_1/moving_variance:0           False     0.10403        7.92295
# inner_cmb_activation_1        inner_cmb_activation_1/alpha:0               False     -3.67905       2.91821
# outer_cmb_activation_1        outer_cmb_activation_1/alpha:0               False     -3.33381       2.45325
# inner_cmb_conv_2              inner_cmb_conv_2/kernel:0                    False     -4.22688       4.54366
# inner_cmb_conv_2              inner_cmb_conv_2/bias:0                      False     -0.00042       0.00106
# outer_cmb_conv_2              outer_cmb_conv_2/kernel:0                    False     -3.55668       4.17725
# outer_cmb_conv_2              outer_cmb_conv_2/bias:0                      False     -0.00024       0.00022
# inner_cmb_norm_2              inner_cmb_norm_2/gamma:0                     False     -1.46706       5.07307
# inner_cmb_norm_2              inner_cmb_norm_2/beta:0                      False     -3.50646       2.92354
# inner_cmb_norm_2              inner_cmb_norm_2/moving_mean:0               False     -1511.82141    1539.35449
# inner_cmb_norm_2              inner_cmb_norm_2/moving_variance:0           False     3847.01392     1993122.37500
# outer_cmb_norm_2              outer_cmb_norm_2/gamma:0                     False     -1.24100       3.70532
# outer_cmb_norm_2              outer_cmb_norm_2/beta:0                      False     -2.76247       2.33530
# outer_cmb_norm_2              outer_cmb_norm_2/moving_mean:0               False     -617.55981     682.55621
# outer_cmb_norm_2              outer_cmb_norm_2/moving_variance:0           False     4086.40430     726321.81250
# inner_cmb_activation_2        inner_cmb_activation_2/alpha:0               False     -4.31747       4.11262
# outer_cmb_activation_2        outer_cmb_activation_2/alpha:0               False     -3.67672       5.68535
# inner_cmb_conv_3              inner_cmb_conv_3/kernel:0                    False     -4.36039       5.34093
# inner_cmb_conv_3              inner_cmb_conv_3/bias:0                      False     -0.00063       0.00127
# outer_cmb_conv_3              outer_cmb_conv_3/kernel:0                    False     -3.39311       3.61231
# outer_cmb_conv_3              outer_cmb_conv_3/bias:0                      False     -0.00033       0.00026
# inner_cmb_norm_3              inner_cmb_norm_3/gamma:0                     False     -1.25353       4.52640
# inner_cmb_norm_3              inner_cmb_norm_3/beta:0                      False     -3.85086       2.64348
# inner_cmb_norm_3              inner_cmb_norm_3/moving_mean:0               False     -857.91479     875.38593
# inner_cmb_norm_3              inner_cmb_norm_3/moving_variance:0           False     19824.25195    2057416.12500
# outer_cmb_norm_3              outer_cmb_norm_3/gamma:0                     False     -1.11187       3.44535
# outer_cmb_norm_3              outer_cmb_norm_3/beta:0                      False     -4.05306       3.31845
# outer_cmb_norm_3              outer_cmb_norm_3/moving_mean:0               False     -392.08136     567.39417
# outer_cmb_norm_3              outer_cmb_norm_3/moving_variance:0           False     7097.56885     321723.84375
# inner_cmb_activation_3        inner_cmb_activation_3/alpha:0               False     -3.86723       4.72216
# outer_cmb_activation_3        outer_cmb_activation_3/alpha:0               False     -3.89441       4.00246
# inner_cmb_conv_4              inner_cmb_conv_4/kernel:0                    False     -3.72442       4.14326
# inner_cmb_conv_4              inner_cmb_conv_4/bias:0                      False     -0.00104       0.00093
# outer_cmb_conv_4              outer_cmb_conv_4/kernel:0                    False     -3.42731       3.20773
# outer_cmb_conv_4              outer_cmb_conv_4/bias:0                      False     -0.00061       0.00043
# inner_cmb_norm_4              inner_cmb_norm_4/gamma:0                     False     -1.71266       2.93249
# inner_cmb_norm_4              inner_cmb_norm_4/beta:0                      False     -3.87147       2.58693
# inner_cmb_norm_4              inner_cmb_norm_4/moving_mean:0               False     -539.15283     596.35217
# inner_cmb_norm_4              inner_cmb_norm_4/moving_variance:0           False     4632.42871     1176378.25000
# outer_cmb_norm_4              outer_cmb_norm_4/gamma:0                     False     -1.31649       3.14212
# outer_cmb_norm_4              outer_cmb_norm_4/beta:0                      False     -3.31338       2.43924
# outer_cmb_norm_4              outer_cmb_norm_4/moving_mean:0               False     -254.06543     267.10379
# outer_cmb_norm_4              outer_cmb_norm_4/moving_variance:0           False     3188.05322     293403.93750
# inner_cmb_activation_4        inner_cmb_activation_4/alpha:0               False     -3.33386       4.08561
# outer_cmb_activation_4        outer_cmb_activation_4/alpha:0               False     -3.52834       2.46897
# inner_cmb_conv_5              inner_cmb_conv_5/kernel:0                    False     -3.52985       3.55042
# inner_cmb_conv_5              inner_cmb_conv_5/bias:0                      False     -0.00114       0.00171
# outer_cmb_conv_5              outer_cmb_conv_5/kernel:0                    False     -3.51779       3.56619
# outer_cmb_conv_5              outer_cmb_conv_5/bias:0                      False     -0.00043       0.00061
# inner_cmb_norm_5              inner_cmb_norm_5/gamma:0                     False     -1.26522       3.21177
# inner_cmb_norm_5              inner_cmb_norm_5/beta:0                      False     -2.61048       2.11224
# inner_cmb_norm_5              inner_cmb_norm_5/moving_mean:0               False     -322.66168     329.03470
# inner_cmb_norm_5              inner_cmb_norm_5/moving_variance:0           False     2498.69995     386956.18750
# outer_cmb_norm_5              outer_cmb_norm_5/gamma:0                     False     -0.86762       2.91903
# outer_cmb_norm_5              outer_cmb_norm_5/beta:0                      False     -1.60106       1.23910
# outer_cmb_norm_5              outer_cmb_norm_5/moving_mean:0               False     -171.58907     165.06151
# outer_cmb_norm_5              outer_cmb_norm_5/moving_variance:0           False     14598.87109    282770.37500
# inner_cmb_activation_5        inner_cmb_activation_5/alpha:0               False     -2.78372       2.59019
# outer_cmb_activation_5        outer_cmb_activation_5/alpha:0               False     -2.28879       2.15241
# inner_cmb_conv_6              inner_cmb_conv_6/kernel:0                    False     -3.31236       3.55036
# inner_cmb_conv_6              inner_cmb_conv_6/bias:0                      False     -0.00593       0.00151
# outer_cmb_conv_6              outer_cmb_conv_6/kernel:0                    False     -3.21329       3.08245
# outer_cmb_conv_6              outer_cmb_conv_6/bias:0                      False     -0.00078       0.00081
# inner_cmb_norm_6              inner_cmb_norm_6/gamma:0                     False     0.78864        2.95533
# inner_cmb_norm_6              inner_cmb_norm_6/beta:0                      False     -2.01688       1.53258
# inner_cmb_norm_6              inner_cmb_norm_6/moving_mean:0               False     -92.23146      82.45676
# inner_cmb_norm_6              inner_cmb_norm_6/moving_variance:0           False     2518.83105     179803.35938
# outer_cmb_norm_6              outer_cmb_norm_6/gamma:0                     False     0.38876        2.99022
# outer_cmb_norm_6              outer_cmb_norm_6/beta:0                      False     -1.60810       1.13274
# outer_cmb_norm_6              outer_cmb_norm_6/moving_mean:0               False     -50.45795      61.17604
# outer_cmb_norm_6              outer_cmb_norm_6/moving_variance:0           False     3594.49365     153582.48438
# inner_cmb_activation_6        inner_cmb_activation_6/alpha:0               False     -2.53600       2.60346
# outer_cmb_activation_6        outer_cmb_activation_6/alpha:0               False     -1.81042       2.38914
# inner_cmb_conv_7              inner_cmb_conv_7/kernel:0                    False     -2.98274       3.63964
# inner_cmb_conv_7              inner_cmb_conv_7/bias:0                      False     -0.00663       0.00203
# outer_cmb_conv_7              outer_cmb_conv_7/kernel:0                    False     -2.86486       2.60249
# outer_cmb_conv_7              outer_cmb_conv_7/bias:0                      False     -0.00093       0.00073
# inner_cmb_norm_7              inner_cmb_norm_7/gamma:0                     False     0.70414        2.64337
# inner_cmb_norm_7              inner_cmb_norm_7/beta:0                      False     -1.61019       0.90386
# inner_cmb_norm_7              inner_cmb_norm_7/moving_mean:0               False     -25.41730      23.43741
# inner_cmb_norm_7              inner_cmb_norm_7/moving_variance:0           False     11425.94531    87127.90625
# outer_cmb_norm_7              outer_cmb_norm_7/gamma:0                     False     -1.87082       2.55982
# outer_cmb_norm_7              outer_cmb_norm_7/beta:0                      False     -1.09994       1.19748
# outer_cmb_norm_7              outer_cmb_norm_7/moving_mean:0               False     -22.30482      25.46828
# outer_cmb_norm_7              outer_cmb_norm_7/moving_variance:0           False     15077.69141    77811.58594
# inner_cmb_activation_7        inner_cmb_activation_7/alpha:0               False     -1.45708       2.30968
# outer_cmb_activation_7        outer_cmb_activation_7/alpha:0               False     -1.27089       2.32645
# inner_cmb_conv_8              inner_cmb_conv_8/kernel:0                    False     -2.74962       3.26129
# inner_cmb_conv_8              inner_cmb_conv_8/bias:0                      False     -0.00648       0.01035
# outer_cmb_conv_8              outer_cmb_conv_8/kernel:0                    False     -2.81173       2.87793
# outer_cmb_conv_8              outer_cmb_conv_8/bias:0                      False     -0.00104       0.00089
# inner_cmb_norm_8              inner_cmb_norm_8/gamma:0                     False     1.11323        2.55785
# inner_cmb_norm_8              inner_cmb_norm_8/beta:0                      False     -0.43701       0.60968
# inner_cmb_norm_8              inner_cmb_norm_8/moving_mean:0               False     -15.58704      14.07334
# inner_cmb_norm_8              inner_cmb_norm_8/moving_variance:0           False     11832.44238    45776.46875
# outer_cmb_norm_8              outer_cmb_norm_8/gamma:0                     False     1.13407        2.61290
# outer_cmb_norm_8              outer_cmb_norm_8/beta:0                      False     -0.77549       1.00855
# outer_cmb_norm_8              outer_cmb_norm_8/moving_mean:0               False     -22.58277      17.81495
# outer_cmb_norm_8              outer_cmb_norm_8/moving_variance:0           False     16737.99414    37111.78516
# inner_cmb_activation_8        inner_cmb_activation_8/alpha:0               False     -1.73638       2.03284
# outer_cmb_activation_8        outer_cmb_activation_8/alpha:0               False     -1.36089       2.17488
# inner_cmb_conv_9              inner_cmb_conv_9/kernel:0                    False     -2.75654       2.64749
# inner_cmb_conv_9              inner_cmb_conv_9/bias:0                      False     -0.01398       0.00566
# outer_cmb_conv_9              outer_cmb_conv_9/kernel:0                    False     -2.57409       2.72285
# outer_cmb_conv_9              outer_cmb_conv_9/bias:0                      False     -0.00188       0.00098
# inner_cmb_norm_9              inner_cmb_norm_9/gamma:0                     False     1.34253        2.56022
# inner_cmb_norm_9              inner_cmb_norm_9/beta:0                      False     -0.47737       0.43763
# inner_cmb_norm_9              inner_cmb_norm_9/moving_mean:0               False     -6.40010       7.32570
# inner_cmb_norm_9              inner_cmb_norm_9/moving_variance:0           False     11633.92188    32421.52734
# outer_cmb_norm_9              outer_cmb_norm_9/gamma:0                     False     1.15281        2.65294
# outer_cmb_norm_9              outer_cmb_norm_9/beta:0                      False     -0.74354       0.74289
# outer_cmb_norm_9              outer_cmb_norm_9/moving_mean:0               False     -23.22774      18.68611
# outer_cmb_norm_9              outer_cmb_norm_9/moving_variance:0           False     11967.37402    21226.71094
# inner_cmb_activation_9        inner_cmb_activation_9/alpha:0               False     -1.64946       1.92664
# outer_cmb_activation_9        outer_cmb_activation_9/alpha:0               False     -1.49643       1.87427
# inner_cmb_conv_10             inner_cmb_conv_10/kernel:0                   False     -2.48883       2.91180
# inner_cmb_conv_10             inner_cmb_conv_10/bias:0                     False     -0.00731       0.00922
# outer_cmb_conv_10             outer_cmb_conv_10/kernel:0                   False     -2.47719       3.17572
# outer_cmb_conv_10             outer_cmb_conv_10/bias:0                     False     -0.00202       0.00133
# inner_cmb_norm_10             inner_cmb_norm_10/gamma:0                    False     1.30252        2.70861
# inner_cmb_norm_10             inner_cmb_norm_10/beta:0                     False     -0.45156       0.48396
# inner_cmb_norm_10             inner_cmb_norm_10/moving_mean:0              False     -6.03145       4.30333
# inner_cmb_norm_10             inner_cmb_norm_10/moving_variance:0          False     577.98230      17341.18945
# outer_cmb_norm_10             outer_cmb_norm_10/gamma:0                    False     1.25676        2.82412
# outer_cmb_norm_10             outer_cmb_norm_10/beta:0                     False     -0.66662       0.78242
# outer_cmb_norm_10             outer_cmb_norm_10/moving_mean:0              False     -16.77743      13.83570
# outer_cmb_norm_10             outer_cmb_norm_10/moving_variance:0          False     5151.64404     11692.67578
# inner_cmb_activation_10       inner_cmb_activation_10/alpha:0              False     -1.99000       1.90734
# outer_cmb_activation_10       outer_cmb_activation_10/alpha:0              False     -1.36604       1.56651
# inner_all_2x2_conv_1          inner_all_2x2_conv_1/kernel:0                False     -4.38599       4.34048
# inner_all_2x2_conv_1          inner_all_2x2_conv_1/bias:0                  False     -0.00917       0.01538
# outer_all_2x2_conv_1          outer_all_2x2_conv_1/kernel:0                False     -2.83497       3.85273
# outer_all_2x2_conv_1          outer_all_2x2_conv_1/bias:0                  False     -0.00099       0.00102
# inner_all_2x2_norm_1          inner_all_2x2_norm_1/gamma:0                 False     0.46676        3.12536
# inner_all_2x2_norm_1          inner_all_2x2_norm_1/beta:0                  False     -0.55789       0.58302
# inner_all_2x2_norm_1          inner_all_2x2_norm_1/moving_mean:0           False     -39.91239      63.52653
# inner_all_2x2_norm_1          inner_all_2x2_norm_1/moving_variance:0       False     69662.58594    410512.43750
# outer_all_2x2_norm_1          outer_all_2x2_norm_1/gamma:0                 False     0.81895        3.05171
# outer_all_2x2_norm_1          outer_all_2x2_norm_1/beta:0                  False     -0.56350       0.54571
# outer_all_2x2_norm_1          outer_all_2x2_norm_1/moving_mean:0           False     -11.49610      8.14300
# outer_all_2x2_norm_1          outer_all_2x2_norm_1/moving_variance:0       False     11843.28320    99471.72656
# inner_all_2x2_activation_1    inner_all_2x2_activation_1/alpha:0           False     -1.68442       1.76996
# outer_all_2x2_activation_1    outer_all_2x2_activation_1/alpha:0           False     -2.43150       1.42597
# inner_all_2x2_conv_2          inner_all_2x2_conv_2/kernel:0                False     -3.43687       3.79129
# inner_all_2x2_conv_2          inner_all_2x2_conv_2/bias:0                  False     -0.00593       0.00804
# outer_all_2x2_conv_2          outer_all_2x2_conv_2/kernel:0                False     -3.64655       3.87811
# outer_all_2x2_conv_2          outer_all_2x2_conv_2/bias:0                  False     -0.00100       0.00124
# inner_all_2x2_norm_2          inner_all_2x2_norm_2/gamma:0                 False     -1.28518       2.77934
# inner_all_2x2_norm_2          inner_all_2x2_norm_2/beta:0                  False     -0.56358       0.75566
# inner_all_2x2_norm_2          inner_all_2x2_norm_2/moving_mean:0           False     -79.09150      81.29536
# inner_all_2x2_norm_2          inner_all_2x2_norm_2/moving_variance:0       False     3786.80591     174372.32812
# outer_all_2x2_norm_2          outer_all_2x2_norm_2/gamma:0                 False     0.67691        3.69984
# outer_all_2x2_norm_2          outer_all_2x2_norm_2/beta:0                  False     -0.37646       0.50242
# outer_all_2x2_norm_2          outer_all_2x2_norm_2/moving_mean:0           False     -92.48303      86.01357
# outer_all_2x2_norm_2          outer_all_2x2_norm_2/moving_variance:0       False     3117.80469     285265.21875
# inner_all_2x2_activation_2    inner_all_2x2_activation_2/alpha:0           False     -2.59533       2.32240
# outer_all_2x2_activation_2    outer_all_2x2_activation_2/alpha:0           False     -1.92358       3.64314
# inner_all_2x2_conv_3          inner_all_2x2_conv_3/kernel:0                False     -3.17197       3.42411
# inner_all_2x2_conv_3          inner_all_2x2_conv_3/bias:0                  False     -0.00840       0.01064
# outer_all_2x2_conv_3          outer_all_2x2_conv_3/kernel:0                False     -3.43327       3.23791
# outer_all_2x2_conv_3          outer_all_2x2_conv_3/bias:0                  False     -0.00114       0.00118
# inner_all_2x2_norm_3          inner_all_2x2_norm_3/gamma:0                 False     0.30927        2.97534
# inner_all_2x2_norm_3          inner_all_2x2_norm_3/beta:0                  False     -0.50902       0.71345
# inner_all_2x2_norm_3          inner_all_2x2_norm_3/moving_mean:0           False     -60.27721      65.07661
# inner_all_2x2_norm_3          inner_all_2x2_norm_3/moving_variance:0       False     5313.08789     102119.57812
# outer_all_2x2_norm_3          outer_all_2x2_norm_3/gamma:0                 False     -0.97255       3.12104
# outer_all_2x2_norm_3          outer_all_2x2_norm_3/beta:0                  False     -0.51918       1.09301
# outer_all_2x2_norm_3          outer_all_2x2_norm_3/moving_mean:0           False     -41.32789      55.24892
# outer_all_2x2_norm_3          outer_all_2x2_norm_3/moving_variance:0       False     1100.80640     80577.75000
# inner_all_2x2_activation_3    inner_all_2x2_activation_3/alpha:0           False     -0.94310       1.63659
# outer_all_2x2_activation_3    outer_all_2x2_activation_3/alpha:0           False     -1.23446       3.14690
# inner_all_2x2_conv_4          inner_all_2x2_conv_4/kernel:0                False     -3.23904       2.86504
# inner_all_2x2_conv_4          inner_all_2x2_conv_4/bias:0                  False     -0.00754       0.00400
# outer_all_2x2_conv_4          outer_all_2x2_conv_4/kernel:0                False     -3.31297       3.04575
# outer_all_2x2_conv_4          outer_all_2x2_conv_4/bias:0                  False     -0.00162       0.00189
# inner_all_2x2_norm_4          inner_all_2x2_norm_4/gamma:0                 False     0.95052        3.37335
# inner_all_2x2_norm_4          inner_all_2x2_norm_4/beta:0                  False     -1.49891       1.16364
# inner_all_2x2_norm_4          inner_all_2x2_norm_4/moving_mean:0           False     -63.39533      40.00687
# inner_all_2x2_norm_4          inner_all_2x2_norm_4/moving_variance:0       False     911.15564      60110.91406
# outer_all_2x2_norm_4          outer_all_2x2_norm_4/gamma:0                 False     0.76552        3.18083
# outer_all_2x2_norm_4          outer_all_2x2_norm_4/beta:0                  False     -0.81585       1.33082
# outer_all_2x2_norm_4          outer_all_2x2_norm_4/moving_mean:0           False     -76.46496      71.76544
# outer_all_2x2_norm_4          outer_all_2x2_norm_4/moving_variance:0       False     2993.82593     81027.58594
# inner_all_2x2_activation_4    inner_all_2x2_activation_4/alpha:0           False     -2.01978       1.55671
# outer_all_2x2_activation_4    outer_all_2x2_activation_4/alpha:0           False     -1.64334       3.12951
# inner_all_2x2_conv_5          inner_all_2x2_conv_5/kernel:0                False     -3.06281       3.14758
# inner_all_2x2_conv_5          inner_all_2x2_conv_5/bias:0                  False     -0.00532       0.00338
# outer_all_2x2_conv_5          outer_all_2x2_conv_5/kernel:0                False     -3.70135       3.98800
# outer_all_2x2_conv_5          outer_all_2x2_conv_5/bias:0                  False     -0.00126       0.00154
# inner_all_2x2_norm_5          inner_all_2x2_norm_5/gamma:0                 False     0.34471        3.00972
# inner_all_2x2_norm_5          inner_all_2x2_norm_5/beta:0                  False     -0.46989       1.49495
# inner_all_2x2_norm_5          inner_all_2x2_norm_5/moving_mean:0           False     -100.65768     14.77704
# inner_all_2x2_norm_5          inner_all_2x2_norm_5/moving_variance:0       False     2089.70679     71488.90625
# outer_all_2x2_norm_5          outer_all_2x2_norm_5/gamma:0                 False     0.12004        3.05172
# outer_all_2x2_norm_5          outer_all_2x2_norm_5/beta:0                  False     -0.97479       1.66993
# outer_all_2x2_norm_5          outer_all_2x2_norm_5/moving_mean:0           False     -98.44823      98.54597
# outer_all_2x2_norm_5          outer_all_2x2_norm_5/moving_variance:0       False     9632.01465     91918.34375
# inner_all_2x2_activation_5    inner_all_2x2_activation_5/alpha:0           False     -0.97292       1.55787
# outer_all_2x2_activation_5    outer_all_2x2_activation_5/alpha:0           False     -1.19543       3.33266
# inner_all_2x2_conv_6          inner_all_2x2_conv_6/kernel:0                False     -3.07519       2.96627
# inner_all_2x2_conv_6          inner_all_2x2_conv_6/bias:0                  False     -0.00363       0.00191
# outer_all_2x2_conv_6          outer_all_2x2_conv_6/kernel:0                False     -3.38211       3.15742
# outer_all_2x2_conv_6          outer_all_2x2_conv_6/bias:0                  False     -0.00104       0.00133
# inner_all_2x2_norm_6          inner_all_2x2_norm_6/gamma:0                 False     0.46309        3.42684
# inner_all_2x2_norm_6          inner_all_2x2_norm_6/beta:0                  False     -1.24594       1.58959
# inner_all_2x2_norm_6          inner_all_2x2_norm_6/moving_mean:0           False     -102.85854     87.05172
# inner_all_2x2_norm_6          inner_all_2x2_norm_6/moving_variance:0       False     2001.62134     55740.92969
# outer_all_2x2_norm_6          outer_all_2x2_norm_6/gamma:0                 False     -1.54803       3.43907
# outer_all_2x2_norm_6          outer_all_2x2_norm_6/beta:0                  False     -1.38622       2.15038
# outer_all_2x2_norm_6          outer_all_2x2_norm_6/moving_mean:0           False     -144.54184     121.67497
# outer_all_2x2_norm_6          outer_all_2x2_norm_6/moving_variance:0       False     6673.06689     105207.70312
# inner_all_2x2_activation_6    inner_all_2x2_activation_6/alpha:0           False     -1.06375       1.63631
# outer_all_2x2_activation_6    outer_all_2x2_activation_6/alpha:0           False     -1.29749       2.94294
# inner_all_2x2_conv_7          inner_all_2x2_conv_7/kernel:0                False     -3.25134       3.60716
# inner_all_2x2_conv_7          inner_all_2x2_conv_7/bias:0                  False     -0.00161       0.00306
# outer_all_2x2_conv_7          outer_all_2x2_conv_7/kernel:0                False     -3.55130       2.99822
# outer_all_2x2_conv_7          outer_all_2x2_conv_7/bias:0                  False     -0.00165       0.00161
# inner_all_2x2_norm_7          inner_all_2x2_norm_7/gamma:0                 False     0.58244        2.63336
# inner_all_2x2_norm_7          inner_all_2x2_norm_7/beta:0                  False     -0.94058       1.35859
# inner_all_2x2_norm_7          inner_all_2x2_norm_7/moving_mean:0           False     -176.41829     151.36771
# inner_all_2x2_norm_7          inner_all_2x2_norm_7/moving_variance:0       False     2969.63843     94775.68750
# outer_all_2x2_norm_7          outer_all_2x2_norm_7/gamma:0                 False     -0.65737       2.58766
# outer_all_2x2_norm_7          outer_all_2x2_norm_7/beta:0                  False     -3.23765       2.77722
# outer_all_2x2_norm_7          outer_all_2x2_norm_7/moving_mean:0           False     -265.42578     222.29614
# outer_all_2x2_norm_7          outer_all_2x2_norm_7/moving_variance:0       False     8019.49268     62212.84766
# inner_all_2x2_activation_7    inner_all_2x2_activation_7/alpha:0           False     -1.58949       1.37017
# outer_all_2x2_activation_7    outer_all_2x2_activation_7/alpha:0           False     -1.64091       2.79893
# inner_all_2x2_conv_8          inner_all_2x2_conv_8/kernel:0                False     -3.75598       3.24970
# inner_all_2x2_conv_8          inner_all_2x2_conv_8/bias:0                  False     -0.00309       0.00258
# outer_all_2x2_conv_8          outer_all_2x2_conv_8/kernel:0                False     -4.09493       3.09536
# outer_all_2x2_conv_8          outer_all_2x2_conv_8/bias:0                  False     -0.00242       0.00166
# inner_all_2x2_norm_8          inner_all_2x2_norm_8/gamma:0                 False     0.70735        2.91734
# inner_all_2x2_norm_8          inner_all_2x2_norm_8/beta:0                  False     -0.53705       1.14972
# inner_all_2x2_norm_8          inner_all_2x2_norm_8/moving_mean:0           False     -158.50027     120.66353
# inner_all_2x2_norm_8          inner_all_2x2_norm_8/moving_variance:0       False     1857.67651     82046.31250
# outer_all_2x2_norm_8          outer_all_2x2_norm_8/gamma:0                 False     -1.13242       3.41844
# outer_all_2x2_norm_8          outer_all_2x2_norm_8/beta:0                  False     -1.30632       2.66110
# outer_all_2x2_norm_8          outer_all_2x2_norm_8/moving_mean:0           False     -239.48643     181.80136
# outer_all_2x2_norm_8          outer_all_2x2_norm_8/moving_variance:0       False     2059.26465     68992.12500
# inner_all_2x2_activation_8    inner_all_2x2_activation_8/alpha:0           False     -2.33092       1.48088
# outer_all_2x2_activation_8    outer_all_2x2_activation_8/alpha:0           False     -1.36510       2.60680
# inner_all_2x2_conv_9          inner_all_2x2_conv_9/kernel:0                False     -2.96740       3.60816
# inner_all_2x2_conv_9          inner_all_2x2_conv_9/bias:0                  False     -0.00270       0.00215
# outer_all_2x2_conv_9          outer_all_2x2_conv_9/kernel:0                False     -3.60150       3.12880
# outer_all_2x2_conv_9          outer_all_2x2_conv_9/bias:0                  False     -0.00152       0.00205
# inner_all_2x2_norm_9          inner_all_2x2_norm_9/gamma:0                 False     0.70229        2.33559
# inner_all_2x2_norm_9          inner_all_2x2_norm_9/beta:0                  False     -1.00479       1.05501
# inner_all_2x2_norm_9          inner_all_2x2_norm_9/moving_mean:0           False     -88.90854      103.34729
# inner_all_2x2_norm_9          inner_all_2x2_norm_9/moving_variance:0       False     4998.46826     70538.60156
# outer_all_2x2_norm_9          outer_all_2x2_norm_9/gamma:0                 False     -1.85455       2.97746
# outer_all_2x2_norm_9          outer_all_2x2_norm_9/beta:0                  False     -1.48511       1.96965
# outer_all_2x2_norm_9          outer_all_2x2_norm_9/moving_mean:0           False     -161.45038     134.87682
# outer_all_2x2_norm_9          outer_all_2x2_norm_9/moving_variance:0       False     16490.02734    78923.84375
# inner_all_2x2_activation_9    inner_all_2x2_activation_9/alpha:0           False     -2.19025       2.05252
# outer_all_2x2_activation_9    outer_all_2x2_activation_9/alpha:0           False     -1.00523       2.17991
# inner_all_2x2_conv_10         inner_all_2x2_conv_10/kernel:0               False     -3.66699       3.00875
# inner_all_2x2_conv_10         inner_all_2x2_conv_10/bias:0                 False     -0.00211       0.00270
# outer_all_2x2_conv_10         outer_all_2x2_conv_10/kernel:0               False     -3.97583       3.26190
# outer_all_2x2_conv_10         outer_all_2x2_conv_10/bias:0                 False     -0.00170       0.00228
# inner_all_2x2_norm_10         inner_all_2x2_norm_10/gamma:0                False     -0.25028       0.75111
# inner_all_2x2_norm_10         inner_all_2x2_norm_10/beta:0                 False     -0.27103       0.35932
# inner_all_2x2_norm_10         inner_all_2x2_norm_10/moving_mean:0          False     -152.96455     101.96594
# inner_all_2x2_norm_10         inner_all_2x2_norm_10/moving_variance:0      False     3774.48315     95350.89062
# outer_all_2x2_norm_10         outer_all_2x2_norm_10/gamma:0                False     -0.33637       0.34900
# outer_all_2x2_norm_10         outer_all_2x2_norm_10/beta:0                 False     -0.47610       0.13836
# outer_all_2x2_norm_10         outer_all_2x2_norm_10/moving_mean:0          False     -87.72929      59.16585
# outer_all_2x2_norm_10         outer_all_2x2_norm_10/moving_variance:0      False     21562.68555    79969.99219
# inner_all_2x2_activation_10   inner_all_2x2_activation_10/alpha:0          False     -0.48546       1.02496
# outer_all_2x2_activation_10   outer_all_2x2_activation_10/alpha:0          False     -0.63876       0.92226
# final_dense_1                 final_dense_1/kernel:0                       False     -21.72585      10.94205
# final_dense_1                 final_dense_1/bias:0                         False     -0.00840       0.00845
# final_norm_1                  final_norm_1/gamma:0                         False     -0.36303       4.62407
# final_norm_1                  final_norm_1/beta:0                          False     -2.57502       1.10033
# final_norm_1                  final_norm_1/moving_mean:0                   False     -19.07187      19.43850
# final_norm_1                  final_norm_1/moving_variance:0               False     5.38994        999.02966
# final_activation_1            final_activation_1/alpha:0                   False     -2.68144       2.36629
# final_dense_2                 final_dense_2/kernel:0                       False     -6.82106       7.48819
# final_dense_2                 final_dense_2/bias:0                         False     -0.00131       0.00143
# final_norm_2                  final_norm_2/gamma:0                         False     0.11894        3.75879
# final_norm_2                  final_norm_2/beta:0                          False     -1.80555       1.59701
# final_norm_2                  final_norm_2/moving_mean:0                   False     -220.19214     349.00317
# final_norm_2                  final_norm_2/moving_variance:0               False     598.50629      124484.55469
# final_activation_2            final_activation_2/alpha:0                   False     -3.20294       3.37831
# final_dense_3                 final_dense_3/kernel:0                       False     -5.18017       5.80382
# final_dense_3                 final_dense_3/bias:0                         False     -0.00183       0.00200
# final_norm_3                  final_norm_3/gamma:0                         False     0.55513        3.89571
# final_norm_3                  final_norm_3/beta:0                          False     -1.28506       1.77367
# final_norm_3                  final_norm_3/moving_mean:0                   False     -227.33211     208.71790
# final_norm_3                  final_norm_3/moving_variance:0               False     3036.72144     185845.45312
# final_activation_3            final_activation_3/alpha:0                   False     -3.08144       2.33068
# final_dense_4                 final_dense_4/kernel:0                       False     -4.66361       4.26619
# final_dense_4                 final_dense_4/bias:0                         False     -0.00276       0.00263
# final_norm_4                  final_norm_4/gamma:0                         False     1.08207        3.22712
# final_norm_4                  final_norm_4/beta:0                          False     -1.11846       1.19884
# final_norm_4                  final_norm_4/moving_mean:0                   False     -147.72234     139.44304
# final_norm_4                  final_norm_4/moving_variance:0               False     14345.41211    113521.37500
# final_activation_4            final_activation_4/alpha:0                   False     -1.55814       1.96907
# final_dense_5                 final_dense_5/kernel:0                       False     -4.15363       4.27885
# final_dense_5                 final_dense_5/bias:0                         False     -0.00202       0.00235
# final_norm_5                  final_norm_5/gamma:0                         False     1.24149        2.76152
# final_norm_5                  final_norm_5/beta:0                          False     -1.01096       1.06770
# final_norm_5                  final_norm_5/moving_mean:0                   False     -141.42860     130.56377
# final_norm_5                  final_norm_5/moving_variance:0               False     18215.65234    139695.70312
# final_activation_5            final_activation_5/alpha:0                   False     0.60314        1.90789
# final_dense_6                 final_dense_6/kernel:0                       False     -4.26377       3.69806
# final_dense_6                 final_dense_6/bias:0                         False     -0.00239       0.00314
# final_norm_6                  final_norm_6/gamma:0                         False     1.15911        2.44369
# final_norm_6                  final_norm_6/beta:0                          False     -0.92820       1.17066
# final_norm_6                  final_norm_6/moving_mean:0                   False     -101.16768     100.08942
# final_norm_6                  final_norm_6/moving_variance:0               False     8270.63379     75597.32812
# final_activation_6            final_activation_6/alpha:0                   False     0.06117        1.87976
# final_dense_7                 final_dense_7/kernel:0                       False     -3.70126       3.58145
# final_dense_7                 final_dense_7/bias:0                         False     -0.00354       0.00459
# final_norm_7                  final_norm_7/gamma:0                         False     0.76702        3.07304
# final_norm_7                  final_norm_7/beta:0                          False     -0.52056       0.68310
# final_norm_7                  final_norm_7/moving_mean:0                   False     -67.28274      19.35680
# final_norm_7                  final_norm_7/moving_variance:0               False     9073.40820     35994.34375
# final_activation_7            final_activation_7/alpha:0                   False     -0.02014       1.63126
# final_dense_8                 final_dense_8/kernel:0                       False     -3.60106       3.63699
# final_dense_8                 final_dense_8/bias:0                         False     -0.00484       0.00464
# final_norm_8                  final_norm_8/gamma:0                         False     0.10085        0.75478
# final_norm_8                  final_norm_8/beta:0                          False     -0.29874       0.14206
# final_norm_8                  final_norm_8/moving_mean:0                   False     -50.42482      2.87936
# final_norm_8                  final_norm_8/moving_variance:0               False     1990.24414     15194.72949
# final_activation_8            final_activation_8/alpha:0                   False     -1.30568       0.94819
# final_dense_9                 final_dense_9/kernel:0                       False     -1.84034       1.71017
# final_dense_9                 final_dense_9/bias:0                         False     -0.97239       0.70817

# %%
model = LoadModel('DeepTau2017v2p3_step1_final.hdf5')
sess = K.get_session()
# Out:
# WARNING:tensorflow:From C:\Users\konst\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\konst\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\konst\AppData\Roaming\Python\Python36\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
n = 0
for layer in model.layers:
    for weight in layer.weights:
        w = sess.run(tf.reshape(weight.value(), [-1]))
        has_nans = np.any(np.isnan(w))
        amin = np.amin(w)
        amax = np.amax(w)
        print("{:<30}{:<45}{:<10}{:<15.5f}{:<15.5f}".format(layer.name, weight.name, str(has_nans), amin, amax))
        
    n += 1
# Out:
# inner_cmb_conv_1              inner_cmb_conv_1/kernel:0                    False     -14.21618      14.29205
# inner_cmb_conv_1              inner_cmb_conv_1/bias:0                      False     -0.02056       0.02141
# outer_cmb_conv_1              outer_cmb_conv_1/kernel:0                    False     -10.40217      7.65263
# outer_cmb_conv_1              outer_cmb_conv_1/bias:0                      False     -0.00352       0.00375
# inner_cmb_norm_1              inner_cmb_norm_1/gamma:0                     False     -1.47701       4.44011
# inner_cmb_norm_1              inner_cmb_norm_1/beta:0                      False     -2.38419       2.94393
# inner_cmb_norm_1              inner_cmb_norm_1/moving_mean:0               False     -0.14119       0.16351
# inner_cmb_norm_1              inner_cmb_norm_1/moving_variance:0           False     0.01875        4.33161
# outer_cmb_norm_1              outer_cmb_norm_1/gamma:0                     False     -0.98774       5.44849
# outer_cmb_norm_1              outer_cmb_norm_1/beta:0                      False     -2.13284       1.71671
# outer_cmb_norm_1              outer_cmb_norm_1/moving_mean:0               False     -0.93335       0.90793
# outer_cmb_norm_1              outer_cmb_norm_1/moving_variance:0           False     0.08473        7.39473
# inner_cmb_activation_1        inner_cmb_activation_1/alpha:0               False     -3.68934       2.74246
# outer_cmb_activation_1        outer_cmb_activation_1/alpha:0               False     -3.43854       2.33130
# inner_cmb_conv_2              inner_cmb_conv_2/kernel:0                    False     -4.07720       4.21040
# inner_cmb_conv_2              inner_cmb_conv_2/bias:0                      False     -0.00042       0.00106
# outer_cmb_conv_2              outer_cmb_conv_2/kernel:0                    False     -3.59786       3.69547
# outer_cmb_conv_2              outer_cmb_conv_2/bias:0                      False     -0.00024       0.00022
# inner_cmb_norm_2              inner_cmb_norm_2/gamma:0                     False     -1.30504       4.75660
# inner_cmb_norm_2              inner_cmb_norm_2/beta:0                      False     -3.22529       2.76159
# inner_cmb_norm_2              inner_cmb_norm_2/moving_mean:0               False     -1283.25378    1343.76367
# inner_cmb_norm_2              inner_cmb_norm_2/moving_variance:0           False     4079.89111     1672862.50000
# outer_cmb_norm_2              outer_cmb_norm_2/gamma:0                     False     -1.01883       3.79207
# outer_cmb_norm_2              outer_cmb_norm_2/beta:0                      False     -2.77115       2.40389
# outer_cmb_norm_2              outer_cmb_norm_2/moving_mean:0               False     -536.30762     575.66626
# outer_cmb_norm_2              outer_cmb_norm_2/moving_variance:0           False     2562.35889     627978.68750
# inner_cmb_activation_2        inner_cmb_activation_2/alpha:0               False     -4.08852       3.77862
# outer_cmb_activation_2        outer_cmb_activation_2/alpha:0               False     -3.86640       5.60690
# inner_cmb_conv_3              inner_cmb_conv_3/kernel:0                    False     -4.14269       5.18484
# inner_cmb_conv_3              inner_cmb_conv_3/bias:0                      False     -0.00063       0.00127
# outer_cmb_conv_3              outer_cmb_conv_3/kernel:0                    False     -3.21805       3.49257
# outer_cmb_conv_3              outer_cmb_conv_3/bias:0                      False     -0.00033       0.00026
# inner_cmb_norm_3              inner_cmb_norm_3/gamma:0                     False     -1.25815       4.18582
# inner_cmb_norm_3              inner_cmb_norm_3/beta:0                      False     -3.59033       2.51690
# inner_cmb_norm_3              inner_cmb_norm_3/moving_mean:0               False     -763.28192     788.63696
# inner_cmb_norm_3              inner_cmb_norm_3/moving_variance:0           False     23562.09375    1715220.62500
# outer_cmb_norm_3              outer_cmb_norm_3/gamma:0                     False     -0.34246       3.56004
# outer_cmb_norm_3              outer_cmb_norm_3/beta:0                      False     -3.97653       3.06597
# outer_cmb_norm_3              outer_cmb_norm_3/moving_mean:0               False     -298.68524     453.51602
# outer_cmb_norm_3              outer_cmb_norm_3/moving_variance:0           False     7509.84570     344736.93750
# inner_cmb_activation_3        inner_cmb_activation_3/alpha:0               False     -3.71814       4.68924
# outer_cmb_activation_3        outer_cmb_activation_3/alpha:0               False     -3.80690       3.98072
# inner_cmb_conv_4              inner_cmb_conv_4/kernel:0                    False     -3.47970       3.90556
# inner_cmb_conv_4              inner_cmb_conv_4/bias:0                      False     -0.00104       0.00093
# outer_cmb_conv_4              outer_cmb_conv_4/kernel:0                    False     -3.08008       3.14474
# outer_cmb_conv_4              outer_cmb_conv_4/bias:0                      False     -0.00061       0.00044
# inner_cmb_norm_4              inner_cmb_norm_4/gamma:0                     False     -1.40702       2.85776
# inner_cmb_norm_4              inner_cmb_norm_4/beta:0                      False     -3.60540       2.69809
# inner_cmb_norm_4              inner_cmb_norm_4/moving_mean:0               False     -447.81049     483.24982
# inner_cmb_norm_4              inner_cmb_norm_4/moving_variance:0           False     3077.89941     922344.31250
# outer_cmb_norm_4              outer_cmb_norm_4/gamma:0                     False     -1.37924       3.23427
# outer_cmb_norm_4              outer_cmb_norm_4/beta:0                      False     -3.13631       2.27952
# outer_cmb_norm_4              outer_cmb_norm_4/moving_mean:0               False     -246.47159     260.03894
# outer_cmb_norm_4              outer_cmb_norm_4/moving_variance:0           False     5933.97217     294886.84375
# inner_cmb_activation_4        inner_cmb_activation_4/alpha:0               False     -2.90709       3.68912
# outer_cmb_activation_4        outer_cmb_activation_4/alpha:0               False     -3.67304       2.60011
# inner_cmb_conv_5              inner_cmb_conv_5/kernel:0                    False     -3.57824       3.35371
# inner_cmb_conv_5              inner_cmb_conv_5/bias:0                      False     -0.00114       0.00171
# outer_cmb_conv_5              outer_cmb_conv_5/kernel:0                    False     -3.63214       3.37528
# outer_cmb_conv_5              outer_cmb_conv_5/bias:0                      False     -0.00043       0.00062
# inner_cmb_norm_5              inner_cmb_norm_5/gamma:0                     False     -1.24586       2.79630
# inner_cmb_norm_5              inner_cmb_norm_5/beta:0                      False     -2.69420       2.22533
# inner_cmb_norm_5              inner_cmb_norm_5/moving_mean:0               False     -258.19458     266.07257
# inner_cmb_norm_5              inner_cmb_norm_5/moving_variance:0           False     3017.09863     311995.93750
# outer_cmb_norm_5              outer_cmb_norm_5/gamma:0                     False     -0.89778       2.85008
# outer_cmb_norm_5              outer_cmb_norm_5/beta:0                      False     -1.65766       1.29549
# outer_cmb_norm_5              outer_cmb_norm_5/moving_mean:0               False     -180.24257     161.06644
# outer_cmb_norm_5              outer_cmb_norm_5/moving_variance:0           False     13584.25000    295738.03125
# inner_cmb_activation_5        inner_cmb_activation_5/alpha:0               False     -2.52537       2.46156
# outer_cmb_activation_5        outer_cmb_activation_5/alpha:0               False     -2.32593       2.08157
# inner_cmb_conv_6              inner_cmb_conv_6/kernel:0                    False     -3.15415       3.17097
# inner_cmb_conv_6              inner_cmb_conv_6/bias:0                      False     -0.00592       0.00151
# outer_cmb_conv_6              outer_cmb_conv_6/kernel:0                    False     -2.97412       3.06854
# outer_cmb_conv_6              outer_cmb_conv_6/bias:0                      False     -0.00078       0.00081
# inner_cmb_norm_6              inner_cmb_norm_6/gamma:0                     False     0.67306        2.58362
# inner_cmb_norm_6              inner_cmb_norm_6/beta:0                      False     -1.87755       1.40082
# inner_cmb_norm_6              inner_cmb_norm_6/moving_mean:0               False     -75.62116      73.57851
# inner_cmb_norm_6              inner_cmb_norm_6/moving_variance:0           False     3231.89038     144120.06250
# outer_cmb_norm_6              outer_cmb_norm_6/gamma:0                     False     0.33945        2.87882
# outer_cmb_norm_6              outer_cmb_norm_6/beta:0                      False     -1.76518       1.06760
# outer_cmb_norm_6              outer_cmb_norm_6/moving_mean:0               False     -45.62270      60.61527
# outer_cmb_norm_6              outer_cmb_norm_6/moving_variance:0           False     14951.24609    139371.21875
# inner_cmb_activation_6        inner_cmb_activation_6/alpha:0               False     -2.47666       2.32221
# outer_cmb_activation_6        outer_cmb_activation_6/alpha:0               False     -1.69681       2.36949
# inner_cmb_conv_7              inner_cmb_conv_7/kernel:0                    False     -2.91618       3.39785
# inner_cmb_conv_7              inner_cmb_conv_7/bias:0                      False     -0.00663       0.00204
# outer_cmb_conv_7              outer_cmb_conv_7/kernel:0                    False     -2.68220       2.74304
# outer_cmb_conv_7              outer_cmb_conv_7/bias:0                      False     -0.00092       0.00074
# inner_cmb_norm_7              inner_cmb_norm_7/gamma:0                     False     0.88598        2.56182
# inner_cmb_norm_7              inner_cmb_norm_7/beta:0                      False     -1.55354       0.83061
# inner_cmb_norm_7              inner_cmb_norm_7/moving_mean:0               False     -16.42279      18.74510
# inner_cmb_norm_7              inner_cmb_norm_7/moving_variance:0           False     4927.16064     71309.07031
# outer_cmb_norm_7              outer_cmb_norm_7/gamma:0                     False     -1.51851       2.71891
# outer_cmb_norm_7              outer_cmb_norm_7/beta:0                      False     -1.17871       1.07356
# outer_cmb_norm_7              outer_cmb_norm_7/moving_mean:0               False     -23.75097      24.68238
# outer_cmb_norm_7              outer_cmb_norm_7/moving_variance:0           False     13539.29980    64948.25000
# inner_cmb_activation_7        inner_cmb_activation_7/alpha:0               False     -1.55917       2.07445
# outer_cmb_activation_7        outer_cmb_activation_7/alpha:0               False     -1.32100       2.17279
# inner_cmb_conv_8              inner_cmb_conv_8/kernel:0                    False     -2.61657       3.21313
# inner_cmb_conv_8              inner_cmb_conv_8/bias:0                      False     -0.00649       0.01032
# outer_cmb_conv_8              outer_cmb_conv_8/kernel:0                    False     -2.69242       2.92534
# outer_cmb_conv_8              outer_cmb_conv_8/bias:0                      False     -0.00101       0.00088
# inner_cmb_norm_8              inner_cmb_norm_8/gamma:0                     False     1.24080        2.70517
# inner_cmb_norm_8              inner_cmb_norm_8/beta:0                      False     -0.56228       0.53058
# inner_cmb_norm_8              inner_cmb_norm_8/moving_mean:0               False     -12.81088      11.39366
# inner_cmb_norm_8              inner_cmb_norm_8/moving_variance:0           False     8910.76562     38533.04297
# outer_cmb_norm_8              outer_cmb_norm_8/gamma:0                     False     1.12272        2.68789
# outer_cmb_norm_8              outer_cmb_norm_8/beta:0                      False     -0.70041       0.75458
# outer_cmb_norm_8              outer_cmb_norm_8/moving_mean:0               False     -22.02736      20.54420
# outer_cmb_norm_8              outer_cmb_norm_8/moving_variance:0           False     15427.12695    32100.44727
# inner_cmb_activation_8        inner_cmb_activation_8/alpha:0               False     -1.63935       2.24761
# outer_cmb_activation_8        outer_cmb_activation_8/alpha:0               False     -1.32859       2.28130
# inner_cmb_conv_9              inner_cmb_conv_9/kernel:0                    False     -2.52708       2.58451
# inner_cmb_conv_9              inner_cmb_conv_9/bias:0                      False     -0.01399       0.00566
# outer_cmb_conv_9              outer_cmb_conv_9/kernel:0                    False     -2.37129       2.60404
# outer_cmb_conv_9              outer_cmb_conv_9/bias:0                      False     -0.00184       0.00095
# inner_cmb_norm_9              inner_cmb_norm_9/gamma:0                     False     1.25958        2.41032
# inner_cmb_norm_9              inner_cmb_norm_9/beta:0                      False     -0.45002       0.31558
# inner_cmb_norm_9              inner_cmb_norm_9/moving_mean:0               False     -7.25641       9.11757
# inner_cmb_norm_9              inner_cmb_norm_9/moving_variance:0           False     9047.65430     26757.76953
# outer_cmb_norm_9              outer_cmb_norm_9/gamma:0                     False     1.02336        2.45235
# outer_cmb_norm_9              outer_cmb_norm_9/beta:0                      False     -0.80958       0.93388
# outer_cmb_norm_9              outer_cmb_norm_9/moving_mean:0               False     -19.16666      18.88358
# outer_cmb_norm_9              outer_cmb_norm_9/moving_variance:0           False     11098.06055    20085.23633
# inner_cmb_activation_9        inner_cmb_activation_9/alpha:0               False     -1.44269       1.92955
# outer_cmb_activation_9        outer_cmb_activation_9/alpha:0               False     -1.28344       2.10530
# inner_cmb_conv_10             inner_cmb_conv_10/kernel:0                   False     -2.43898       2.81985
# inner_cmb_conv_10             inner_cmb_conv_10/bias:0                     False     -0.00730       0.00922
# outer_cmb_conv_10             outer_cmb_conv_10/kernel:0                   False     -2.36283       2.92785
# outer_cmb_conv_10             outer_cmb_conv_10/bias:0                     False     -0.00201       0.00142
# inner_cmb_norm_10             inner_cmb_norm_10/gamma:0                    False     1.43637        2.83254
# inner_cmb_norm_10             inner_cmb_norm_10/beta:0                     False     -0.57644       0.33116
# inner_cmb_norm_10             inner_cmb_norm_10/moving_mean:0              False     -4.02474       4.61204
# inner_cmb_norm_10             inner_cmb_norm_10/moving_variance:0          False     259.78171      14416.69434
# outer_cmb_norm_10             outer_cmb_norm_10/gamma:0                    False     1.25276        2.91328
# outer_cmb_norm_10             outer_cmb_norm_10/beta:0                     False     -0.59807       0.42424
# outer_cmb_norm_10             outer_cmb_norm_10/moving_mean:0              False     -20.32268      16.45994
# outer_cmb_norm_10             outer_cmb_norm_10/moving_variance:0          False     4880.77197     9521.86426
# inner_cmb_activation_10       inner_cmb_activation_10/alpha:0              False     -1.92363       1.85109
# outer_cmb_activation_10       outer_cmb_activation_10/alpha:0              False     -1.41572       1.54054
# inner_all_2x2_conv_1          inner_all_2x2_conv_1/kernel:0                False     -3.70657       4.02170
# inner_all_2x2_conv_1          inner_all_2x2_conv_1/bias:0                  False     -0.00917       0.01537
# outer_all_2x2_conv_1          outer_all_2x2_conv_1/kernel:0                False     -2.80768       3.66642
# outer_all_2x2_conv_1          outer_all_2x2_conv_1/bias:0                  False     -0.00100       0.00103
# inner_all_2x2_norm_1          inner_all_2x2_norm_1/gamma:0                 False     0.26175        2.90140
# inner_all_2x2_norm_1          inner_all_2x2_norm_1/beta:0                  False     -0.46192       0.37736
# inner_all_2x2_norm_1          inner_all_2x2_norm_1/moving_mean:0           False     -38.39526      64.21111
# inner_all_2x2_norm_1          inner_all_2x2_norm_1/moving_variance:0       False     35959.07422    301550.93750
# outer_all_2x2_norm_1          outer_all_2x2_norm_1/gamma:0                 False     0.77980        2.73401
# outer_all_2x2_norm_1          outer_all_2x2_norm_1/beta:0                  False     -0.41259       0.48054
# outer_all_2x2_norm_1          outer_all_2x2_norm_1/moving_mean:0           False     -6.85784       8.39631
# outer_all_2x2_norm_1          outer_all_2x2_norm_1/moving_variance:0       False     14316.76270    96507.43750
# inner_all_2x2_activation_1    inner_all_2x2_activation_1/alpha:0           False     -1.77008       1.89485
# outer_all_2x2_activation_1    outer_all_2x2_activation_1/alpha:0           False     -1.97619       1.34845
# inner_all_2x2_conv_2          inner_all_2x2_conv_2/kernel:0                False     -3.57598       3.50621
# inner_all_2x2_conv_2          inner_all_2x2_conv_2/bias:0                  False     -0.00591       0.00803
# outer_all_2x2_conv_2          outer_all_2x2_conv_2/kernel:0                False     -3.46554       3.59779
# outer_all_2x2_conv_2          outer_all_2x2_conv_2/bias:0                  False     -0.00102       0.00125
# inner_all_2x2_norm_2          inner_all_2x2_norm_2/gamma:0                 False     -1.02660       2.72592
# inner_all_2x2_norm_2          inner_all_2x2_norm_2/beta:0                  False     -0.61763       0.69128
# inner_all_2x2_norm_2          inner_all_2x2_norm_2/moving_mean:0           False     -62.68748      66.72365
# inner_all_2x2_norm_2          inner_all_2x2_norm_2/moving_variance:0       False     2087.82446     137734.67188
# outer_all_2x2_norm_2          outer_all_2x2_norm_2/gamma:0                 False     0.68721        3.48311
# outer_all_2x2_norm_2          outer_all_2x2_norm_2/beta:0                  False     -0.58056       0.43509
# outer_all_2x2_norm_2          outer_all_2x2_norm_2/moving_mean:0           False     -93.00679      82.78918
# outer_all_2x2_norm_2          outer_all_2x2_norm_2/moving_variance:0       False     3191.91577     255815.26562
# inner_all_2x2_activation_2    inner_all_2x2_activation_2/alpha:0           False     -2.61131       2.18202
# outer_all_2x2_activation_2    outer_all_2x2_activation_2/alpha:0           False     -1.94036       3.30304
# inner_all_2x2_conv_3          inner_all_2x2_conv_3/kernel:0                False     -2.99693       3.25112
# inner_all_2x2_conv_3          inner_all_2x2_conv_3/bias:0                  False     -0.00840       0.01064
# outer_all_2x2_conv_3          outer_all_2x2_conv_3/kernel:0                False     -3.09275       3.27020
# outer_all_2x2_conv_3          outer_all_2x2_conv_3/bias:0                  False     -0.00115       0.00117
# inner_all_2x2_norm_3          inner_all_2x2_norm_3/gamma:0                 False     0.28756        2.95178
# inner_all_2x2_norm_3          inner_all_2x2_norm_3/beta:0                  False     -0.53492       0.68919
# inner_all_2x2_norm_3          inner_all_2x2_norm_3/moving_mean:0           False     -43.57314      57.71193
# inner_all_2x2_norm_3          inner_all_2x2_norm_3/moving_variance:0       False     3752.37305     66999.50781
# outer_all_2x2_norm_3          outer_all_2x2_norm_3/gamma:0                 False     -0.95784       3.06325
# outer_all_2x2_norm_3          outer_all_2x2_norm_3/beta:0                  False     -0.57815       0.90043
# outer_all_2x2_norm_3          outer_all_2x2_norm_3/moving_mean:0           False     -36.94324      43.10780
# outer_all_2x2_norm_3          outer_all_2x2_norm_3/moving_variance:0       False     1272.02490     72147.72656
# inner_all_2x2_activation_3    inner_all_2x2_activation_3/alpha:0           False     -0.87290       1.81267
# outer_all_2x2_activation_3    outer_all_2x2_activation_3/alpha:0           False     -1.20411       3.10479
# inner_all_2x2_conv_4          inner_all_2x2_conv_4/kernel:0                False     -3.23920       2.77702
# inner_all_2x2_conv_4          inner_all_2x2_conv_4/bias:0                  False     -0.00756       0.00400
# outer_all_2x2_conv_4          outer_all_2x2_conv_4/kernel:0                False     -3.09924       2.92431
# outer_all_2x2_conv_4          outer_all_2x2_conv_4/bias:0                  False     -0.00160       0.00188
# inner_all_2x2_norm_4          inner_all_2x2_norm_4/gamma:0                 False     0.90428        3.52649
# inner_all_2x2_norm_4          inner_all_2x2_norm_4/beta:0                  False     -1.68947       0.89849
# inner_all_2x2_norm_4          inner_all_2x2_norm_4/moving_mean:0           False     -52.67554      37.35807
# inner_all_2x2_norm_4          inner_all_2x2_norm_4/moving_variance:0       False     1173.56091     47265.11719
# outer_all_2x2_norm_4          outer_all_2x2_norm_4/gamma:0                 False     0.86060        2.97768
# outer_all_2x2_norm_4          outer_all_2x2_norm_4/beta:0                  False     -0.84484       1.43172
# outer_all_2x2_norm_4          outer_all_2x2_norm_4/moving_mean:0           False     -63.85437      57.09857
# outer_all_2x2_norm_4          outer_all_2x2_norm_4/moving_variance:0       False     2682.92773     67397.20312
# inner_all_2x2_activation_4    inner_all_2x2_activation_4/alpha:0           False     -2.02606       1.60365
# outer_all_2x2_activation_4    outer_all_2x2_activation_4/alpha:0           False     -1.57001       2.95289
# inner_all_2x2_conv_5          inner_all_2x2_conv_5/kernel:0                False     -3.09706       2.98381
# inner_all_2x2_conv_5          inner_all_2x2_conv_5/bias:0                  False     -0.00532       0.00337
# outer_all_2x2_conv_5          outer_all_2x2_conv_5/kernel:0                False     -3.46554       3.69842
# outer_all_2x2_conv_5          outer_all_2x2_conv_5/bias:0                  False     -0.00127       0.00153
# inner_all_2x2_norm_5          inner_all_2x2_norm_5/gamma:0                 False     0.34596        2.96893
# inner_all_2x2_norm_5          inner_all_2x2_norm_5/beta:0                  False     -0.42009       1.89963
# inner_all_2x2_norm_5          inner_all_2x2_norm_5/moving_mean:0           False     -86.81680      12.00164
# inner_all_2x2_norm_5          inner_all_2x2_norm_5/moving_variance:0       False     1621.28186     61409.06641
# outer_all_2x2_norm_5          outer_all_2x2_norm_5/gamma:0                 False     0.10605        2.92810
# outer_all_2x2_norm_5          outer_all_2x2_norm_5/beta:0                  False     -0.92472       1.67057
# outer_all_2x2_norm_5          outer_all_2x2_norm_5/moving_mean:0           False     -83.03524      86.23432
# outer_all_2x2_norm_5          outer_all_2x2_norm_5/moving_variance:0       False     7286.73877     84892.17188
# inner_all_2x2_activation_5    inner_all_2x2_activation_5/alpha:0           False     -1.06997       1.42863
# outer_all_2x2_activation_5    outer_all_2x2_activation_5/alpha:0           False     -0.95014       3.13396
# inner_all_2x2_conv_6          inner_all_2x2_conv_6/kernel:0                False     -3.12339       2.97056
# inner_all_2x2_conv_6          inner_all_2x2_conv_6/bias:0                  False     -0.00364       0.00188
# outer_all_2x2_conv_6          outer_all_2x2_conv_6/kernel:0                False     -3.59067       2.95594
# outer_all_2x2_conv_6          outer_all_2x2_conv_6/bias:0                  False     -0.00104       0.00132
# inner_all_2x2_norm_6          inner_all_2x2_norm_6/gamma:0                 False     0.68804        3.31323
# inner_all_2x2_norm_6          inner_all_2x2_norm_6/beta:0                  False     -1.38039       1.57221
# inner_all_2x2_norm_6          inner_all_2x2_norm_6/moving_mean:0           False     -104.53831     84.98132
# inner_all_2x2_norm_6          inner_all_2x2_norm_6/moving_variance:0       False     2110.80469     47842.54297
# outer_all_2x2_norm_6          outer_all_2x2_norm_6/gamma:0                 False     -1.31328       3.17418
# outer_all_2x2_norm_6          outer_all_2x2_norm_6/beta:0                  False     -1.19334       2.24964
# outer_all_2x2_norm_6          outer_all_2x2_norm_6/moving_mean:0           False     -129.86604     101.93140
# outer_all_2x2_norm_6          outer_all_2x2_norm_6/moving_variance:0       False     4171.30566     78720.10156
# inner_all_2x2_activation_6    inner_all_2x2_activation_6/alpha:0           False     -0.82842       1.38247
# outer_all_2x2_activation_6    outer_all_2x2_activation_6/alpha:0           False     -1.14000       2.97730
# inner_all_2x2_conv_7          inner_all_2x2_conv_7/kernel:0                False     -3.21119       3.38173
# inner_all_2x2_conv_7          inner_all_2x2_conv_7/bias:0                  False     -0.00161       0.00305
# outer_all_2x2_conv_7          outer_all_2x2_conv_7/kernel:0                False     -3.56847       3.01088
# outer_all_2x2_conv_7          outer_all_2x2_conv_7/bias:0                  False     -0.00165       0.00160
# inner_all_2x2_norm_7          inner_all_2x2_norm_7/gamma:0                 False     0.36114        2.30786
# inner_all_2x2_norm_7          inner_all_2x2_norm_7/beta:0                  False     -0.98340       1.40275
# inner_all_2x2_norm_7          inner_all_2x2_norm_7/moving_mean:0           False     -170.21831     137.01930
# inner_all_2x2_norm_7          inner_all_2x2_norm_7/moving_variance:0       False     3224.13379     81319.59375
# outer_all_2x2_norm_7          outer_all_2x2_norm_7/gamma:0                 False     -0.72093       2.77733
# outer_all_2x2_norm_7          outer_all_2x2_norm_7/beta:0                  False     -3.02898       2.49182
# outer_all_2x2_norm_7          outer_all_2x2_norm_7/moving_mean:0           False     -238.90059     199.64021
# outer_all_2x2_norm_7          outer_all_2x2_norm_7/moving_variance:0       False     7470.64893     60671.93750
# inner_all_2x2_activation_7    inner_all_2x2_activation_7/alpha:0           False     -1.60655       1.33519
# outer_all_2x2_activation_7    outer_all_2x2_activation_7/alpha:0           False     -1.53653       2.75263
# inner_all_2x2_conv_8          inner_all_2x2_conv_8/kernel:0                False     -3.38255       2.88048
# inner_all_2x2_conv_8          inner_all_2x2_conv_8/bias:0                  False     -0.00309       0.00259
# outer_all_2x2_conv_8          outer_all_2x2_conv_8/kernel:0                False     -3.97682       3.09763
# outer_all_2x2_conv_8          outer_all_2x2_conv_8/bias:0                  False     -0.00242       0.00166
# inner_all_2x2_norm_8          inner_all_2x2_norm_8/gamma:0                 False     0.85694        2.93418
# inner_all_2x2_norm_8          inner_all_2x2_norm_8/beta:0                  False     -0.60445       1.13328
# inner_all_2x2_norm_8          inner_all_2x2_norm_8/moving_mean:0           False     -147.60811     104.51432
# inner_all_2x2_norm_8          inner_all_2x2_norm_8/moving_variance:0       False     1442.05920     71911.39062
# outer_all_2x2_norm_8          outer_all_2x2_norm_8/gamma:0                 False     -1.37489       3.54267
# outer_all_2x2_norm_8          outer_all_2x2_norm_8/beta:0                  False     -1.41855       2.36205
# outer_all_2x2_norm_8          outer_all_2x2_norm_8/moving_mean:0           False     -229.91339     174.28375
# outer_all_2x2_norm_8          outer_all_2x2_norm_8/moving_variance:0       False     1999.42188     66153.78906
# inner_all_2x2_activation_8    inner_all_2x2_activation_8/alpha:0           False     -2.05528       1.53785
# outer_all_2x2_activation_8    outer_all_2x2_activation_8/alpha:0           False     -1.38399       2.37163
# inner_all_2x2_conv_9          inner_all_2x2_conv_9/kernel:0                False     -2.91951       3.29181
# inner_all_2x2_conv_9          inner_all_2x2_conv_9/bias:0                  False     -0.00270       0.00214
# outer_all_2x2_conv_9          outer_all_2x2_conv_9/kernel:0                False     -3.49186       3.08169
# outer_all_2x2_conv_9          outer_all_2x2_conv_9/bias:0                  False     -0.00152       0.00205
# inner_all_2x2_norm_9          inner_all_2x2_norm_9/gamma:0                 False     0.62996        2.55849
# inner_all_2x2_norm_9          inner_all_2x2_norm_9/beta:0                  False     -0.97123       1.31966
# inner_all_2x2_norm_9          inner_all_2x2_norm_9/moving_mean:0           False     -85.67498      93.17026
# inner_all_2x2_norm_9          inner_all_2x2_norm_9/moving_variance:0       False     4787.78760     63622.78516
# outer_all_2x2_norm_9          outer_all_2x2_norm_9/gamma:0                 False     -1.93373       2.86278
# outer_all_2x2_norm_9          outer_all_2x2_norm_9/beta:0                  False     -1.32514       1.63997
# outer_all_2x2_norm_9          outer_all_2x2_norm_9/moving_mean:0           False     -146.01797     109.17435
# outer_all_2x2_norm_9          outer_all_2x2_norm_9/moving_variance:0       False     10560.83984    80639.58594
# inner_all_2x2_activation_9    inner_all_2x2_activation_9/alpha:0           False     -2.22652       1.70200
# outer_all_2x2_activation_9    outer_all_2x2_activation_9/alpha:0           False     -0.89892       1.99350
# inner_all_2x2_conv_10         inner_all_2x2_conv_10/kernel:0               False     -3.70246       2.72255
# inner_all_2x2_conv_10         inner_all_2x2_conv_10/bias:0                 False     -0.00211       0.00270
# outer_all_2x2_conv_10         outer_all_2x2_conv_10/kernel:0               False     -3.80765       2.87688
# outer_all_2x2_conv_10         outer_all_2x2_conv_10/bias:0                 False     -0.00171       0.00228
# inner_all_2x2_norm_10         inner_all_2x2_norm_10/gamma:0                False     -0.24479       0.69026
# inner_all_2x2_norm_10         inner_all_2x2_norm_10/beta:0                 False     -0.32305       0.37988
# inner_all_2x2_norm_10         inner_all_2x2_norm_10/moving_mean:0          False     -142.46059     87.53692
# inner_all_2x2_norm_10         inner_all_2x2_norm_10/moving_variance:0      False     3156.98999     82097.07812
# outer_all_2x2_norm_10         outer_all_2x2_norm_10/gamma:0                False     -0.37588       0.31928
# outer_all_2x2_norm_10         outer_all_2x2_norm_10/beta:0                 False     -0.49227       0.11093
# outer_all_2x2_norm_10         outer_all_2x2_norm_10/moving_mean:0          False     -67.42406      35.99343
# outer_all_2x2_norm_10         outer_all_2x2_norm_10/moving_variance:0      False     14293.45996    76220.11719
# inner_all_2x2_activation_10   inner_all_2x2_activation_10/alpha:0          False     -0.82565       0.95288
# outer_all_2x2_activation_10   outer_all_2x2_activation_10/alpha:0          False     -0.53590       0.91310
# final_dense_1                 final_dense_1/kernel:0                       False     -20.68030      10.55922
# final_dense_1                 final_dense_1/bias:0                         False     -0.00796       0.00717
# final_norm_1                  final_norm_1/gamma:0                         False     0.03422        4.37808
# final_norm_1                  final_norm_1/beta:0                          False     -2.51950       1.10574
# final_norm_1                  final_norm_1/moving_mean:0                   False     -15.85215      20.16198
# final_norm_1                  final_norm_1/moving_variance:0               False     4.72769        958.20868
# final_activation_1            final_activation_1/alpha:0                   False     -2.47686       2.15584
# final_dense_2                 final_dense_2/kernel:0                       False     -6.66931       7.23069
# final_dense_2                 final_dense_2/bias:0                         False     -0.00131       0.00145
# final_norm_2                  final_norm_2/gamma:0                         False     0.26218        3.69019
# final_norm_2                  final_norm_2/beta:0                          False     -1.73627       1.49088
# final_norm_2                  final_norm_2/moving_mean:0                   False     -162.21779     291.10205
# final_norm_2                  final_norm_2/moving_variance:0               False     410.37103      113323.13281
# final_activation_2            final_activation_2/alpha:0                   False     -2.98619       3.21301
# final_dense_3                 final_dense_3/kernel:0                       False     -5.09067       5.38042
# final_dense_3                 final_dense_3/bias:0                         False     -0.00183       0.00200
# final_norm_3                  final_norm_3/gamma:0                         False     0.62544        3.94386
# final_norm_3                  final_norm_3/beta:0                          False     -1.29298       1.63871
# final_norm_3                  final_norm_3/moving_mean:0                   False     -196.52559     202.14375
# final_norm_3                  final_norm_3/moving_variance:0               False     2178.01123     163612.01562
# final_activation_3            final_activation_3/alpha:0                   False     -3.11715       2.40301
# final_dense_4                 final_dense_4/kernel:0                       False     -4.51443       4.06762
# final_dense_4                 final_dense_4/bias:0                         False     -0.00275       0.00264
# final_norm_4                  final_norm_4/gamma:0                         False     1.08947        3.22982
# final_norm_4                  final_norm_4/beta:0                          False     -0.99813       1.17312
# final_norm_4                  final_norm_4/moving_mean:0                   False     -123.20436     124.60497
# final_norm_4                  final_norm_4/moving_variance:0               False     13007.27051    95055.27344
# final_activation_4            final_activation_4/alpha:0                   False     -1.60218       1.97558
# final_dense_5                 final_dense_5/kernel:0                       False     -3.88989       3.99442
# final_dense_5                 final_dense_5/bias:0                         False     -0.00201       0.00237
# final_norm_5                  final_norm_5/gamma:0                         False     1.15357        2.55288
# final_norm_5                  final_norm_5/beta:0                          False     -0.93506       0.97565
# final_norm_5                  final_norm_5/moving_mean:0                   False     -114.11575     109.98505
# final_norm_5                  final_norm_5/moving_variance:0               False     14351.43164    107288.21094
# final_activation_5            final_activation_5/alpha:0                   False     0.53795        1.91211
# final_dense_6                 final_dense_6/kernel:0                       False     -3.83013       3.45326
# final_dense_6                 final_dense_6/bias:0                         False     -0.00241       0.00314
# final_norm_6                  final_norm_6/gamma:0                         False     1.37547        2.39071
# final_norm_6                  final_norm_6/beta:0                          False     -0.84429       1.15871
# final_norm_6                  final_norm_6/moving_mean:0                   False     -81.63738      80.53072
# final_norm_6                  final_norm_6/moving_variance:0               False     5876.62500     64353.97656
# final_activation_6            final_activation_6/alpha:0                   False     0.09453        1.83251
# final_dense_7                 final_dense_7/kernel:0                       False     -3.55237       3.21395
# final_dense_7                 final_dense_7/bias:0                         False     -0.00350       0.00454
# final_norm_7                  final_norm_7/gamma:0                         False     1.02334        2.81857
# final_norm_7                  final_norm_7/beta:0                          False     -0.75357       0.56536
# final_norm_7                  final_norm_7/moving_mean:0                   False     -55.91205      12.37816
# final_norm_7                  final_norm_7/moving_variance:0               False     7669.84570     23767.75586
# final_activation_7            final_activation_7/alpha:0                   False     0.15669        1.52089
# final_dense_8                 final_dense_8/kernel:0                       False     -3.47035       3.38959
# final_dense_8                 final_dense_8/bias:0                         False     -0.00482       0.00516
# final_norm_8                  final_norm_8/gamma:0                         False     0.22202        0.74091
# final_norm_8                  final_norm_8/beta:0                          False     -0.25598       0.17919
# final_norm_8                  final_norm_8/moving_mean:0                   False     -44.02574      6.42861
# final_norm_8                  final_norm_8/moving_variance:0               False     1131.57959     14535.62207
# final_activation_8            final_activation_8/alpha:0                   False     -1.46619       0.98179
# final_dense_9                 final_dense_9/kernel:0                       False     -1.84371       1.96754
# final_dense_9                 final_dense_9/bias:0                         False     -1.13396       0.85363

# %%
layer = model.get_layer("outer_muon_conv_1")

# %%
layer.activation(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-c60a51a0a0b8> in <module>()
# ----> 1 layer.activation(2)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/activations.py in selu(x)
#      82     alpha = 1.6732632423543772848170429916717
#      83     scale = 1.0507009873554804934193349852946
# ---> 84     return scale * K.elu(x, alpha)
#      85
#      86
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in elu(x, alpha)
#    3211         A tensor.
#    3212     """
# -> 3213     res = tf.nn.elu(x)
#    3214     if alpha == 1:
#    3215         return res
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py in elu(features, name)
#    2774   if _ctx is None or not _ctx._eager_context.is_eager:
#    2775     _, _, _op = _op_def_lib._apply_op_helper(
# -> 2776         "Elu", features=features, name=name)
#    2777     _result = _op.outputs[:]
#    2778     _inputs_flat = _op.inputs
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     607               _SatisfiesTypeConstraint(base_type,
#     608                                        _Attr(op_def, input_arg.type_attr),
# --> 609                                        param_name=input_name)
#     610             attrs[input_arg.type_attr] = attr_value
#     611             inferred_from[input_arg.type_attr] = input_name
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _SatisfiesTypeConstraint(dtype, attr_def, param_name)
#      58           "allowed values: %s" %
#      59           (param_name, dtypes.as_dtype(dtype).name,
# ---> 60            ", ".join(dtypes.as_dtype(x).name for x in allowed_list)))
#      61
#      62
#
# TypeError: Value passed to parameter 'features' has DataType int32 not in list of allowed values: float16, bfloat16, float32, float64

# %%
weight = layer.

# %%
for weight in layer.weights:
    if weight.name != 'outer_muon_conv_1/kernel:0': continue
    w = np.array(sess.run(weight.value()))
    for n in range(w.shape[2]):
        print(n, np.any(np.isnan(w[0, 0, n, :])))
#    for n in range(len(w)):
#        print(n, w[n])
#    has_nans = np.any(np.isnan(w))
#    amin = np.amin(w)
#    amax = np.amax(w)
#    print(layer.name, weight.name, has_nans, amin, amax)
# Out:
# 0 False
# 1 False
# 2 False
# 3 False
# 4 False
# 5 False
# 6 False
# 7 False
# 8 False
# 9 True
# 10 False
# 11 False
# 12 False
# 13 False
# 14 False
# 15 False
# 16 False
# 17 False
# 18 False
# 19 False
# 20 False
# 21 False
# 22 False
# 23 False
# 24 False
# 25 False
# 26 False
# 27 False
# 28 False
# 29 False
# 30 False
# 31 False
# 32 False
# 33 False
# 34 False
# 35 False
# 36 False
# 37 False
# 38 False
