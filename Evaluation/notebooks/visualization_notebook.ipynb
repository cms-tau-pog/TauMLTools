# %%
from utils.visualize import Event
from ipywidgets import widgets
# Out:
# 2022-09-28 11:42:57.167521: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-28 11:42:57.167553: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
event = Event()
# Out:
# 2022-09-28 11:43:30.289330: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-28 11:43:30.289385: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-28 11:43:30.289447: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (naf-cms12.desy.de): /proc/driver/nvidia/version does not exist
# 2022-09-28 11:43:30.289913: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## Widget

# %%
cont1, cont2, g = event.show_widget(example_num=0)
widgets.VBox([cont1, cont2, g])

# %% [markdown]
# ## Attention Score Matrices

# %%
event.show_attn_matrices(layer=0, include_global=True, example_num=0)

# %% [markdown]
# ## Mean Attention of Distance/Momentum Bins in different Heads

# %%
avgs = event.compute_attn_weighted_X(X='distance', layer=0, plot=True, bins=50, example_num=1)

# %%
avgs = event.compute_attn_weighted_X(X='pt', layer=0, plot=True, bins=50, example_num=1)

# %% [markdown]
# ## Mean Distance/Momentum/Global Score/ of Layers (ViT like Plots)

# %%
event.show_meanAttnX_vs_layer(X='distance', plot=True, example_num=0)

# %%
event.show_meanAttnX_vs_layer(X='pt', plot=True, example_num=0)

# %%
event.show_meanAttnX_vs_layer(X='global', plot=True, example_num=0)

# %%
event.show_meanAttnX_vs_layer(X='sd_wo_global', plot=True, example_num=0)

# %%
event.show_meanAttnX_vs_layer(X='sd_all', plot=True, example_num=0)

# %% [markdown]
# ## Mean Distance/Momentum/Global Score of Layers from Multiple Events (ViT like Plots)

# %%
event.show_multiple_meanAttnX_vs_layer(X='distance', num_events=10)

# %%
event.show_multiple_meanAttnX_vs_layer(X='pt', num_events=10)

# %%
event.show_multiple_meanAttnX_vs_layer(X='global', num_events=100)

# %%
event.show_multiple_meanAttnX_vs_layer(X='sd_wo_global', num_events=100)

# %%
event.show_multiple_meanAttnX_vs_layer(X='sd_all', num_events=100)
